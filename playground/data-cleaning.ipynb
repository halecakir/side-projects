# %%
import os
import re
import sys
import inspect
import time
import csv
import requests
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from pandas import ExcelFile

current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parent_dir = os.path.dirname(current_dir)
sys.path.insert(0, parent_dir) 

from utils.io_utils import IOUtils
from utils.nlp_utils import NLPUtils
# Out:
# Using the default treebank "en_ewt" for language "en".
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/huseyinalecakir/Security/source/PermissionDescriptionFidelity/utils/../../../data/models/en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: depparse
# With settings:
# {'model_path': '/home/huseyinalecakir/Security/source/PermissionDescriptionFidelity/utils/../../../data/models/en_ewt_models/en_ewt_parser.pt', 'pretrain_path': '/home/huseyinalecakir/Security/source/PermissionDescriptionFidelity/utils/../../../data/models/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---

# %%
def get_descriptions(id_file, out_file):
    #Get application ids beforehand
    app_infos = {}
    with open(id_file, "r") as target:
        for app_id in target:
            app_infos[app_id.rstrip()] = None

    #Get application descriptions
    base_url = "http://localhost:3000/api/apps/"
    lang = "/?lang=en"
    with open(out_file, "w") as out:
        writer = csv.writer(out)
        writer.writerow(["application_id", "description"])
        for app_id in app_infos:
            response = requests.get(base_url+app_id+lang)
            if response.status_code == 200:
                if "description" in response.json():
                    writer.writerow([app_id, response.json()["description"]])
                    
def get_app_category(app_id):
    base_url = 'http://localhost:3000/api/apps/'
    response = requests.get(base_url+app_id)
    if response.status_code == 200:
        if "genreId" not in response.json():
            print("Not found genre id in", app_id)
            return "NOT_FOUND"
        else:
            gid = response.json()["genreId"].upper()
            return gid
    else:
        print(app_id, " category cannot be found")
        return "NOT_FOUND"

def update_sheets(file_name, sheetname):
    df = pd.read_excel(file_name, sheet_name=sheetname)
    data = []
    for index, row in df.iterrows():
        data.append([row["Count"], row["Sentences"], row["Manually Marked"], row["uses-permission"], row["permission"]])
    updated_data = []
    app_order = 1
    description_tag = None
    for row in data:
        row[1] = str(row[1])
        if row[1].startswith("##"):
            if app_order != 1:
                description_row = [np.nan, "Description Tag", description_tag, np.nan, np.nan]
                updated_data.append(description_row)
            row[0] = "##{}".format(app_order)
            app_order += 1
            app_id = row[1].split("##")[1].strip()
            category = get_app_category(app_id)
            app_category = "CATEGORY/" + category
            category_row = [np.nan, app_category , np.nan, np.nan, np.nan]
            description_tag = row[2]
            row[2] = np.nan
            updated_data.append(row)
            updated_data.append(category_row)
        else:
            updated_data.append(row)
    return updated_data

def write_to_excel(updated_data, output_file):
    def background_apply(value):
        if value.startswith("##") or value.startswith("Description Tag"):
            font_weight = 'bold'
        else:
            font_weight = 'normal'
        return 'font-weight: %s' % font_weight
    
    updated_df = pd.DataFrame(updated_data, columns = ["Count", "Sentences", "Manually Marked", "uses-permission", "permission"])
    styled = updated_df.style.applymap(background_apply, subset=['Sentences'])
    styled.to_excel(output_file, engine='openpyxl')

def clean_play_store_data(file_path):
    """TODO"""
    number_of_apps = 0
    data = {}
    with open(file_path) as stream:
        reader = csv.reader(stream)
        next(reader)
        start_time = time.time()
        for row in reader:
            number_of_apps += 1
            app_id = row[0]
            text = row[1]
            data[app_id] = []
            for sentence in NLPUtils.sentence_tokenization(text):
                data[app_id].append(sentence)
    return data

def remove_given_pattern(regex, data):
    updated_data = {}
    for  key in list(data.keys()):
        new_lines = []
        for line in data[key]:
            updated = re.sub(regex, '', line)
            new_lines.append(updated)
        updated_data[key] = new_lines
    return updated_data

def remove_emoji(data):
    updated_data = {}
    import demoji
    demoji.download_codes()
    for key in list(data.keys()):
        new_lines = []
        for line in data[key]:
            updated = demoji.replace(line, repl="").strip()
            if updated:
                new_lines.append(updated)
        updated_data[key] = new_lines
    return updated_data

def select_given_apps(data, file_path):
    selected_apps = {}
    last_key = None
    with open(file_path) as stream:
        for line in stream:
            line = line.rstrip()
            if line.startswith("%%"):
                last_key = line.split("%%")[1]
                selected_apps[last_key] = {"uses-permission" : [], "permission" : []}
            else:
                if line:
                    if line.startswith("uses-permission"):
                        selected_apps[last_key]["uses-permission"].append(line)
                    elif line.startswith("permission"):
                        selected_apps[last_key]["permission"].append(line)
    new_data = {}
    for app_id in selected_apps:
        if app_id in data:
            new_data[app_id] = {}
            new_data[app_id]["data"] = data[app_id]
            new_data[app_id]["permissions"] = selected_apps[app_id]
    return new_data

def write_excel(data, outfile, eliminated_apps={}, count=1000):
    import xlwt
    header = ["Count", "Sentences", "Manually Marked", "uses-permission", "permission"]
    
    style = xlwt.XFStyle()
    # font
    font = xlwt.Font()
    font.bold = True
    style.font = font
    
    workbook = xlwt.Workbook()
    sheet = workbook.add_sheet('Sheet')
    sheet.write(0, 0, "Count", style=style) 
    sheet.write(0, 1, "Sentences", style=style) 
    sheet.write(0, 2, "Manually Marked", style=style)
    sheet.write(0, 3, "uses-permission", style=style)
    sheet.write(0, 4, "permission", style=style)

    row_number = 1
    app_num = 1
    for idx, app_id in zip(range(count), data):
        if app_id not in eliminated_apps:
            sheet.write(row_number, 0, "#{}".format(app_num), style=style)
            sheet.write(row_number, 1, "##{}".format(app_id), style=style)
            uses_permissions = ":".join(data[app_id]["permissions"]["uses-permission"])
            permissions = ":".join(data[app_id]["permissions"]["permission"])
            sheet.write(row_number, 3, ":{}".format(uses_permissions))
            sheet.write(row_number, 4, ":{}".format(permissions))
            row_number += 1
            for sentence in data[app_id]["data"]:
                sheet.write(row_number, 1, sentence)
                row_number += 1
            app_num += 1
    workbook.save(outfile)


def run(file_name, sheet_name):
    updated_data = update_sheets(file_name, sheet_name)
    write_to_excel(updated_data, file_name)

# %%
DIR_NAME = os.path.abspath('')
ID_PATH = os.path.join(DIR_NAME, "../../../data/play_store_data/Apps_ReadContacts_989_id.txt")
CSV_PATH = os.path.join(DIR_NAME, "../../../data/play_store_data/Apps_ReadContacts_989_id.csv")
PERMISSION_LIST_PATH = os.path.join(DIR_NAME, "../../../data/play_store_data/Apps_ReadContacts_989_permissionsByAAPT.txt")
OUT_PATH = os.path.join(DIR_NAME, "../../../data/play_store_data/Apps_ReadContacts_989_id.xls")

# %%
get_descriptions(ID_PATH, CSV_PATH)

# %%
regex = r"^[^\w\!\?\\\(\)\[\]\“\‘\"]+"
data = clean_play_store_data(CSV_PATH)
data = remove_given_pattern(regex, data)
data = remove_emoji(data)
data = select_given_apps(data, PERMISSION_LIST_PATH)
write_excel(data, OUT_PATH)
run(OUT_PATH,"Sheet")
# Out:
# Downloading emoji data ...
# ... OK (Got response in 0.39 seconds)
# Writing emoji data to /home/huseyinalecakir/.demoji/codes.json ...
# ... OK
# com.narvii.amino.x42 SOCIAL
# com.bijoysingh.clipo PRODUCTIVITY
# coocent.tools.music.ringtonemaker MUSIC_AND_AUDIO
# net.invoice.bee BUSINESS
# com.tgclab.adicon LIFESTYLE
# com.kakao.talk COMMUNICATION
# mega.privacy.android.app PRODUCTIVITY
# com.storypark.families.android EDUCATION
# air.app.scb.breeze.android.main.my.prod FINANCE
# com.zoho.mail PRODUCTIVITY
# com.fi6715.godough FINANCE
# com.mteducare.mtrobomateplus EDUCATION
# com.zepp.zgolf SPORTS
# ws.coverme.im COMMUNICATION
# jim.mykeyboard.myphotokeyboard PHOTOGRAPHY
# com.jpm.sig.android FINANCE
# com.microsoft.office.powerpoint PRODUCTIVITY
# co.village SHOPPING
# ranat.torkia.ranat_torkia.turkish.ringtones MUSIC_AND_AUDIO
# com.careem.acma MAPS_AND_NAVIGATION
# ru.euphoria.doggy SOCIAL
# com.adslinfotech.simpleaccounting FINANCE
# com.hi5.app SOCIAL
# com.tomatomusic.loudrts PERSONALIZATION
# com.narvii.amino.x71 SOCIAL
# com.spanishcoders.pepephone COMMUNICATION
# com.flowdock.jorge BUSINESS
# com.narvii.amino.x51 SOCIAL
# city.russ.alltrackerfamily PARENTING
# finarea.VoipBuster COMMUNICATION
# se.posten.riktigavykort PHOTOGRAPHY
# com.yinzcam.nba.warriors SPORTS
# com.vakifkatilim.mobil FINANCE
# org.skvalex.cr TOOLS
# com.flash.flashtrader BUSINESS
# com.zynga.chess.googleplay GAME_BOARD
# com.smart.color.phone.emoji ENTERTAINMENT
# com.kt.gigagenie.mobile LIFESTYLE
# com.runtastic.android.results.lite HEALTH_AND_FITNESS
# com.invoiceasap.nativeapp BUSINESS
# com.narvii.amino.x233332503 SOCIAL
# com.krakk.android TRAVEL_AND_LOCAL
# com.isharing.isharing COMMUNICATION
# org.bhc.android BUSINESS
# com.droid4you.application.wallet FINANCE
# id.co.bri.myqr FINANCE
# com.sparkpeople.androidtracker HEALTH_AND_FITNESS
# com.redraw.keyboard PERSONALIZATION
# com.mykeyboard.myphotokeyboard PHOTOGRAPHY
# com.subaru.global.infotainment.gen2 MAPS_AND_NAVIGATION
# com.mewe SOCIAL
# kr.co.bsbank.mobilebank FINANCE
# Syamu.Dictionary.Sarada BOOKS_AND_REFERENCE
# org.me.mobiexpensifyg FINANCE
# com.tune.milliy FINANCE
# ree.calendar.schedule.reminder.todo.agenda.note.reminder.alarm LIFESTYLE
# com.cleanmaster.security TOOLS
# net.idt.um.android.bossrevapp COMMUNICATION
# com.TenderTiger.TenderTiger BUSINESS
# com.withings.wiscale2 HEALTH_AND_FITNESS
# com.pb.letstrakpro SOCIAL
# droso.application.nursing PARENTING
# com.flow.topup SHOPPING
# kr.co.wshopping.wshopping SHOPPING
# com.bandsintown MUSIC_AND_AUDIO
# co.switchapp COMMUNICATION
# com.bitrix24.android BUSINESS
# com.mttnow.android.bcd.production TRAVEL_AND_LOCAL
# de.thorstensapps.ttf PRODUCTIVITY
# com.kennedyspacecenter.kscApp TRAVEL_AND_LOCAL
# my.mobi.android.apps4u.btfiletransfer TOOLS
# com.heetch MAPS_AND_NAVIGATION
# com.ngoumotsios.eortologio SOCIAL
# com.newTelDialer COMMUNICATION
# com.minor.pizzacompany FOOD_AND_DRINK
# com.wave.keyboard.theme.treasureanimatedkeyboard PERSONALIZATION
# com.davivienda.daviplataapp FINANCE
# com.photocollage.collagemaker.easycollagepro TOOLS
# logo.com.mbanking FINANCE
# com.silverdialer.app COMMUNICATION
# com.beeweeb.rds MUSIC_AND_AUDIO
# net.malingo.notes TOOLS
# it.bnl.apps.enterprise.bnlpay FINANCE
# com.pnc.ecommerce.mobile FINANCE
# com.clear.highvolumeringtones PERSONALIZATION
# com.sgiggle.production SOCIAL
# com.narvii.amino.x242238269 SOCIAL
# com.asana.app BUSINESS
# com.starfinanz.smob.android.sfinanzstatus FINANCE
# com.juventus.app.android SPORTS
# com.ubercab.driver BUSINESS
# by.st.priormobile FINANCE
# com.vyke.vtl COMMUNICATION
# com.ss.android.ugc.boomlite SOCIAL
# me.bridgefy.main COMMUNICATION
# com.kt.loudestringtones PERSONALIZATION
# com.mail.mobile.android.mail COMMUNICATION
# com.ztnstudio.notepad TOOLS
# dk.nordea.mobilebank FINANCE
# com.niceringtonesapps.loudrts MUSIC_AND_AUDIO
# com.dbs.sg.posbmbanking FINANCE
# gh.busy.selfcare LIFESTYLE
# net.cloudcal.tasks PRODUCTIVITY
# com.tomatomusic.babies ENTERTAINMENT
# com.cellit.flexilist.leye FOOD_AND_DRINK
# com.revolut.revolut FINANCE
# free.call.international.phone.wifi.calling COMMUNICATION
# com.g5e.twinmoonspg.android GAME_ADVENTURE
# com.crazystudio.emoji.kitkat TOOLS
# jp.co.fsi.refills.lite PRODUCTIVITY
# com.sslwireless.fastpay FINANCE
# com.syncplicity.android PRODUCTIVITY
# com.timespread.Timetable2 LIFESTYLE
# com.werilapps.agenda SOCIAL
# com.narvii.amino.x228943914 SOCIAL
# de.hafas.android.nrw TRAVEL_AND_LOCAL
# classicoldringtones2018.oldphoneringtones PERSONALIZATION
# com.netatmo.camera LIFESTYLE
# app.gpsme PARENTING
# jp.co.plusr.android.jintsu PARENTING
# com.amazon.chime BUSINESS
# com.armut.armuthv BUSINESS
# com.revesoft.mobiledialer.zoom_talk_pvt.united_fone COMMUNICATION
# com.emoji.coolkeyboard TOOLS
# jp.simeji.mushroom.contactpicker TOOLS
# com.cozi.androidfree PRODUCTIVITY
# me.togather.wave SOCIAL
# com.yinzcam.nfl.raiders SPORTS
# com.getsamosa SOCIAL
# com.mode.chasetest.ui FINANCE
# com.autodesk.autocadws PRODUCTIVITY
# com.dataswitching.switchdatamobile TOOLS
# com.microsoft.launcher PERSONALIZATION
# com.nighp.babytracker_android PARENTING
# ru.infteh.organizer.trial PRODUCTIVITY
# br.com.kiwano.cuke FINANCE
# com.sc.mobilebanking.bd FINANCE
# com.pipedrive BUSINESS
# com.vdg.callrecorder TOOLS
# com.jrj.telephone PERSONALIZATION
# com.delorme.earthmate TRAVEL_AND_LOCAL
# com.mimecast BUSINESS
# com.cricheroes.cricheroes.alpha SPORTS
# com.mappy.app MAPS_AND_NAVIGATION
# com.tomatomusic.mprts ENTERTAINMENT
# com.rebelvox.voxer COMMUNICATION
# com.lumaticsoft.watchdroidassistant COMMUNICATION
# finarea.VoipYo COMMUNICATION
# kr.kadd.mycalendarlite PRODUCTIVITY
# com.lb.contacts_sync TOOLS
# com.paygo24.paypoint FINANCE
# com.firstbank.firstmobile FINANCE
# ru.revoplus.client FINANCE
# com.xmatters.xmobile BUSINESS
# es.redsys.walletmb.app.laboralkutxa.pro FINANCE
# in.togetu.video VIDEO_PLAYERS
# com.navent.realestate.inmuebles24 LIFESTYLE
# com.th.ringtone.maker MUSIC_AND_AUDIO
# mobi.skred.app COMMUNICATION
# com.s.antivirus TOOLS
# com.minyue.dixiaoqu3 MUSIC_AND_AUDIO
# com.acsofttechnology.ram.clearner.booster.batterysaver TOOLS
# com.universalappsstudio.hanumanringtonesnew MUSIC_AND_AUDIO
# br.com.sportv.times.vasco SPORTS
# com.bomgar.thinclient.android.Samsung BUSINESS
# com.WhatWapp.BeloteLeDefi GAME_CARD
# com.finedigital.finewifiremocon TOOLS
# com.schneider.qrcode.tocase TOOLS
# com.apitador.app SPORTS
# com.avast.android.mobilesecurity TOOLS
# com.hktv.android.hktvmall LIFESTYLE
# com.siemens.industry.onlinesupport BUSINESS
# messenger.social.chat.apps SOCIAL
# com.anddoes.gingerapex PERSONALIZATION
# com.mona_prod.bad FINANCE
# kr.co.futurewiz.gachinet FINANCE
# ch.slf.whiteriskmobile SPORTS
# jp.qricon.app_barcodereader TOOLS
# com.vnpay.bidv FINANCE
# com.google.android.apps.photos PHOTOGRAPHY
# com.google.android.apps.vega BUSINESS
# com.romkuapps.enfree.duedate PARENTING
# com.yollacalls COMMUNICATION
# com.monitisecreate.eubank.smartbank FINANCE
# com.appstar.callrecorder TOOLS
# com.bestringtones.funny PERSONALIZATION
# com.dreamoval.slydepay.android.cruise FINANCE
# com.nick.ringtonemaker MUSIC_AND_AUDIO
# com.com2us.kungfupet.normal2.freefull.google.global.android.common GAME_SIMULATION
# com.applite.adhan.sounds.azan LIFESTYLE
# com.herman.ringpod MUSIC_AND_AUDIO
# com.mbmobile FINANCE
# com.joinkingschat.android COMMUNICATION
# com.my.mail COMMUNICATION
# com.sgbci.prod FINANCE
# com.fitbit.FitbitMobile HEALTH_AND_FITNESS
# com.coinbase.android FINANCE
# com.receiptbank.android FINANCE
# com.narvii.amino.x59184465 SOCIAL
# com.familywall LIFESTYLE
# com.signal.android SOCIAL
# de.hafas.android.vao MAPS_AND_NAVIGATION
# ohi.andre.consolelauncher PERSONALIZATION
# com.transferwise.android FINANCE
# com.sc.betterhalf LIFESTYLE
# com.horadrim.android.sargam MUSIC_AND_AUDIO
# com.sendgroupsms.MobileInvestigation TOOLS
# com.ovuline.pregnancy MEDICAL
# nisd.telegram.messengeruz SOCIAL
# com.khipu.android FINANCE
# com.trfa.animalsound MUSIC_AND_AUDIO
# com.KuraimiBank FINANCE
# is.shortcut PERSONALIZATION
# de.swr.kaffee_oder_tee ENTERTAINMENT
# com.linpusime.android.linpuskbd TOOLS
# com.juphoon.justalk COMMUNICATION
# com.nousmotards.android MAPS_AND_NAVIGATION
# com.maetimes.android.pokekara ENTERTAINMENT
# com.anydo PRODUCTIVITY
# com.iphoneringtone.ringtoneiphone PRODUCTIVITY
# ols.microsoft.com.shiftr PRODUCTIVITY
# com.nymgo.android COMMUNICATION
# com.lucidappeal.appmold SPORTS
# com.softseed.goodcalendar PRODUCTIVITY
# com.niceringtonesapps.fnsmsts PERSONALIZATION
# com.lembark.watch.applock VIDEO_PLAYERS
# com.prankcalllabs.prankcallapp ENTERTAINMENT
# com.whatsapp.w4b COMMUNICATION
# com.beta.bcard PRODUCTIVITY
# com.onewaycab TRAVEL_AND_LOCAL
# finarea.HotVoip SOCIAL
# tw.com.taishinbank.richart FINANCE
# com.cbs.sportsapp.android.psu SPORTS
# com.xero.touch BUSINESS
# com.synergygb.mercantil.Tpago FINANCE
# ch.threema.app.work COMMUNICATION
# app.mywed.android EVENTS
# bestringtones2019.topringtones2020.android LIBRARIES_AND_DEMO
# com.octopuscards.nfc_reader TOOLS
# com.microsoft.office.word PRODUCTIVITY
# com.SmoreGames.WordWinner GAME_WORD
# com.shenyaocn.android.barmaker TOOLS
# fax.app BUSINESS
# mozat.rings.loops SOCIAL
# in.justride TRAVEL_AND_LOCAL
# es.lacaixa.mobile.android.newwapicon FINANCE
# com.alltrails.alltrails HEALTH_AND_FITNESS
# com.sporteasy.android SPORTS
# com.gettechnology.incomeon_income SOCIAL
# com.vipera.chebanca FINANCE
# com.gigaset.elements LIFESTYLE
# com.winrgames.solitaire GAME_CARD
# com.music.ringtone.maker.mp3 TOOLS
# com.pack.myshiftwork PRODUCTIVITY
# com.wf.wellsfargomobile FINANCE
# eu.eleader.mobilebanking.pekao FINANCE
# com.apps.power.super.clean.security.master PRODUCTIVITY
# com.melita.mobile.selfcare PRODUCTIVITY
# com.callerxapp COMMUNICATION
# com.alarm.alarmmobile.android LIFESTYLE
# com.bbva.netcash FINANCE
# com.facebook.work BUSINESS
# com.printeasy.android PRODUCTIVITY
# com.google.android.contacts COMMUNICATION
# com.meunegocio FINANCE
# com.weswap.app TRAVEL_AND_LOCAL
# com.id90travel.id90app TRAVEL_AND_LOCAL
# md.micb.mwb.prod FINANCE
# com.glidetalk.glideapp COMMUNICATION
# com.ijji.gameflip SHOPPING
# com.application.xeropan EDUCATION
# co.ninetynine.android HOUSE_AND_HOME
# ntanic.co.in EDUCATION
# com.catalinagroup.callrecorder TOOLS
# nl.dsw.android.mijndsw MEDICAL
# com.narvii.amino.x6 SOCIAL
# com.alienmanfc6.wheresmyandroid TOOLS
# com.nobroker.app LIFESTYLE
# com.ifs.androidmobilebanking.fiid3808 FINANCE
# com.hike.chat.stickers SOCIAL
# com.tripit TRAVEL_AND_LOCAL
# com.mobikwik.indusind FINANCE
# com.rvappstudios.speed_booster_junk_cleaner TOOLS
# finarea.WebCallDirect COMMUNICATION
# com.polarsteps TRAVEL_AND_LOCAL
# com.kt.telephone PERSONALIZATION
# com.fullcontact.ledene COMMUNICATION
# com.netpulse.mobile.goldsgymmypath HEALTH_AND_FITNESS
# color.notes.note.pad.book.reminder.app PRODUCTIVITY
# com.skype.insiders COMMUNICATION
# com.cityflo.customer MAPS_AND_NAVIGATION
# br.com.sportv.times.botafogo SPORTS
# de.hafas.android.vgs MAPS_AND_NAVIGATION
# com.simplemobiletools.contacts TOOLS
# com.bifit.rncb FINANCE
# com.usefullapps.fakecall TOOLS
# bank.Dhofar FINANCE
# com.avaya.android.flare COMMUNICATION
# com.buildfortheweb.tasks PRODUCTIVITY
# com.urbandroid.inline TOOLS
# com.pushbullet.android PRODUCTIVITY
# me.lyft.android MAPS_AND_NAVIGATION
# finarea.VoipGain COMMUNICATION
# org.medhelp.iamexpecting HEALTH_AND_FITNESS
# galaxys9ringtones.ringtonesfors9.notifications LIBRARIES_AND_DEMO
# com.veri.veri SOCIAL
# com.tlz.tbdress SHOPPING
# com.skype.raider COMMUNICATION
# com.uberconference PRODUCTIVITY
# com.outbound TRAVEL_AND_LOCAL
# com.xerox.mobileprint PRODUCTIVITY
# com.ifs.banking.fiid1454 FINANCE
# com.study.app EDUCATION
# com.tosslab.jandi.app BUSINESS
# com.adodis.taxmann FINANCE
# iApp.Ringtone TOOLS
# com.kitkats.qrscanner PRODUCTIVITY
# com.google.android.apps.docs.editors.sheets PRODUCTIVITY
# com.nandbox.nandbox COMMUNICATION
# vpbank.yolo.pay.naptien FINANCE
# it.rabb.rabbitandroid SOCIAL
# messenger.chat.social.messenger SOCIAL
# com.vijayabank.passbook FINANCE
# com.VCB FINANCE
# sk.vypadni.waypoint TRAVEL_AND_LOCAL
# com.gocanvas PRODUCTIVITY
# com.mobileservice.bookstore BOOKS_AND_REFERENCE
# com.lps.contactmanager.lite PRODUCTIVITY
# com.oovoo SOCIAL
# com.phillit.akeyboard TOOLS
# com.chatbooks PHOTOGRAPHY
# com.maildroid COMMUNICATION
# com.alextern.shortcuthelper TOOLS
# com.insurance.mcustomer FINANCE
# me.discotech EVENTS
# ctt.mobile.android.app.ctt BUSINESS
# com.citc.asap PERSONALIZATION
# net.webis.informant PRODUCTIVITY
# com.bendigi.Mortgage FINANCE
# com.narvii.amino.x83 SOCIAL
# com.creative.birthdaywishes LIFESTYLE
# com.veggup.veggupapp FOOD_AND_DRINK
# com.dynamixsoftware.printershare BUSINESS
# net.geero.prayermate PRODUCTIVITY
# com.ibyteapps.aa12steptoolkit LIFESTYLE
# com.artcom.hoccer PRODUCTIVITY
# com.alshaya.apc LIFESTYLE
# animation.writesmsbyvoice TOOLS
# com.minyue.chinaminnanyu MUSIC_AND_AUDIO
# com.mireo.aznav MAPS_AND_NAVIGATION
# com.dayforce.mobile BUSINESS
# com.applay.overlay PRODUCTIVITY
# com.goformz BUSINESS
# com.gtbank.gtworldv1 FINANCE
# us.zoom.videomeetings BUSINESS
# com.bomgar.thinclient.android BUSINESS
# cl.recorrido.micritodroid TRAVEL_AND_LOCAL
# ru.mkb.mobile FINANCE
# com.ceruleanstudios.trillian.android COMMUNICATION
# com.textmeinc.textme SOCIAL
# dellmont.SipGo COMMUNICATION
# rutherford.apps.raithunestam EDUCATION
# com.jogatina.buracoitaliano GAME_CARD
# com.mikesandroidworkshop.android.tasklist PRODUCTIVITY
# com.zoho.invoice BUSINESS
# com.geozilla.family LIFESTYLE
# com.b3connect.dmf.pistons SPORTS
# com.fitnesskeeper.runkeeper.pro HEALTH_AND_FITNESS
# com.narvii.amino.x133411448 SOCIAL
# com.pqrs.myfitlog HEALTH_AND_FITNESS
# sk.ipndata.meninyamenafree EVENTS
# com.goodreads BOOKS_AND_REFERENCE
# com.lotus.sync.traveler BUSINESS
# com.memoria.photos.gallery PHOTOGRAPHY
# com.bingoringtones.ldrts PERSONALIZATION
# com.contapps.android COMMUNICATION
# de.hafas.android.vbb MAPS_AND_NAVIGATION
# com.sohmware.invoice BUSINESS
# com.actionlauncher.playstore PERSONALIZATION
# com.medisafe.android.client HEALTH_AND_FITNESS
# com.SUPGBGBMobileBankingApp FINANCE
# com.chinatrust.mobilebank FINANCE
# com.weebly.faebir.safebabymontrial PARENTING
# com.rockstar.cloud TOOLS
# com.tcx.sipphone14 COMMUNICATION
# com.anddoes.launcher PERSONALIZATION
# com.mysay.b COMMUNICATION
# com.azure.authenticator BUSINESS
# com.adpdigital.mbs.ayande FINANCE
# com.mail.emailapp.easymail2018 COMMUNICATION
# mn.slide.khaanbank FINANCE
# kr.co.hpoint.hdgm LIFESTYLE
# com.ooma.office2 BUSINESS
# com.MarcosDiez.shareviahttp TOOLS
# com.truefriend.smartnewa FINANCE
# com.YHsoft.OnseiInputVoice TOOLS
# arrudah.vendapro FINANCE
# com.bitspice.automate AUTO_AND_VEHICLES
# es.evobanco.bancamovil FINANCE
# ru.tinkoff.goabroad FINANCE
# com.narvii.amino.x112707892 SOCIAL
# taxi.android.client TRAVEL_AND_LOCAL
# kg.elsom FINANCE
# tv.periscope.android SOCIAL
# creditdebit.creditdebit BUSINESS
# th.co.truemoney.wallet FINANCE
# com.tohsoft.ringtone.maker MUSIC_AND_AUDIO
# com.navyfederal.android FINANCE
# com.smartscore.rawady.smartscore SPORTS
# com.quickheal.platform TOOLS
# com.squareup BUSINESS
# com.fameelee.app LIFESTYLE
# org.vidogram.messenger COMMUNICATION
# ankit.com.ssy FINANCE
# com.cm_prod.bad FINANCE
# com.quranworks.quran BOOKS_AND_REFERENCE
# com.mode.umb.ui FINANCE
# com.ss.launcher2 PERSONALIZATION
# com.saddly FINANCE
# com.mtag.flashcode PRODUCTIVITY
# com.CRFree TOOLS
# com.kidscrape.king PERSONALIZATION
# com.acer.android.acernote PRODUCTIVITY
# com.meesho.supply BUSINESS
# connectappzone.videomeseringtone VIDEO_PLAYERS
# cool.monkey.android SOCIAL
# ru.bcs.premier FINANCE
# com.fnp.audioprofiles TOOLS
# com.yalantis.myday LIFESTYLE
# com.glxy.ringtones MUSIC_AND_AUDIO
# com.revesoft.mobiledialer.z_phone.onefone COMMUNICATION
# au.com.tapstyle BUSINESS
# com.accessbank.accessbankapp FINANCE
# com.sillens.shapeupclub HEALTH_AND_FITNESS
# com.ex.ipst FINANCE
# com.topps.ice SPORTS
# in.android.vyapar BUSINESS
# com.onoffapp.app COMMUNICATION
# com.narvii.amino.x54 SOCIAL
# com.jb.gokeyboard PERSONALIZATION
# kr.co.thecheat.thecheat FINANCE
# com.safeum.android COMMUNICATION
# com.couchsurfing.mobile.android TRAVEL_AND_LOCAL
# de.mail.android.mailapp COMMUNICATION
# com.vivoiz.healofy.patient PARENTING
# cz.mbank FINANCE
# com.servico.relatorios TOOLS
# io.lifestyle.timo FINANCE
# com.sand.airdroid TOOLS
# com.app.nepalipatrocalendar PRODUCTIVITY
# za.co.fnb.connect.itt FINANCE
# com.whatstools.statussaver.directchat.trendingstatus.searchprofile TOOLS
# com.app.cellc COMMUNICATION
# com.sec.android.easyMover TOOLS
# com.mhqapps.pashtoraba.besttones LIFESTYLE
# com.yinzcam.nba.suns SPORTS
# br.com.sportv.times.flamengo SPORTS
# com.InovaSquad.Artinove BUSINESS
# com.qxmd.readbyqxmd MEDICAL
# com.jrj.loudalarm PERSONALIZATION
# com.purehero.bluetooth.share TOOLS
# com.vtb.mobilebank FINANCE
# com.weddingsnap.android PHOTOGRAPHY
# com.vnsolutions.fastappslocker TOOLS
# com.whatsphone.messenger.im COMMUNICATION
# com.charitymilescm.android HEALTH_AND_FITNESS
# com.pearltrees.android.prod PRODUCTIVITY
# com.ToDoReminder.gen PRODUCTIVITY
# com.wahoofitness.boltcompanion HEALTH_AND_FITNESS
# com.kunkunapps.os12.fingerprint TOOLS
# com.acmelabs COMMUNICATION
# com.shinsegae.mobile.froyo SHOPPING
# com.babyfish.policesiren ENTERTAINMENT
# com.airtelmyplan BUSINESS
# com.projectstar.ishredder.android.standard TOOLS
# com.oscprofessionals.sales_assistant BUSINESS
# ru.mw FINANCE
# com.lucidchart.android.chart PRODUCTIVITY
# com.zappoint.zappoint BUSINESS
# com.punchbowl.mobile LIFESTYLE
# com.narvii.amino.x237406644 SOCIAL
# ru.kykyryza FINANCE
# com.colorcall.colorphone.flash.dialer PERSONALIZATION
# com.breezeghana.ui FINANCE
# com.keepcalling.ui COMMUNICATION
# com.callpod.android_apps.keeper PRODUCTIVITY
# com.nudgeyourself.nudge HEALTH_AND_FITNESS
# krk.joker.jokerkeyboard PERSONALIZATION
# haygot.togyah.app EDUCATION
# com.ifs.mobilebanking.fiid3164 FINANCE
# org.myklos.inote PRODUCTIVITY
# com.safetyculture.iauditor BUSINESS
# Not found genre id in com.g5e.smmmtch3pg.android
# com.tomatomusic.birdsrts PERSONALIZATION
# com.opentecheng.paginegialle.dream TRAVEL_AND_LOCAL
# com.intuit.quickbooks BUSINESS
# com.fragileheart.musiccutter MUSIC_AND_AUDIO
# com.narvii.amino.x250948626 SOCIAL
# ardent.androidapps.smart.annoucer TOOLS
# com.wooribank.smart.dream FINANCE
# com.bluestar.media.gps.compass.map TOOLS
# com.google.android.wearable.app COMMUNICATION
# com.e1c.MobileSmallBusiness BUSINESS
# com.facebook.lite SOCIAL
# com.jzz.callerid.name.sms.announcer.free TOOLS
# br.com.passeidireto EDUCATION
# kr.co.quicket SHOPPING
# com.fluidtime.android.avv MAPS_AND_NAVIGATION
# com.prepear.android FOOD_AND_DRINK
# com.askiitians.android.app EDUCATION
# com.br.twelvemin EDUCATION
# com.edmodo.parents EDUCATION
# com.ovuline.parenting MEDICAL
# com.intervale.sendme FINANCE
# com.joaomgcd.join PRODUCTIVITY
# io.flic.app PRODUCTIVITY
# fr.vestiairecollective SHOPPING
# com.kathos.duplicatecontact.contactmerger TOOLS
# sk.martinflorek.wear.feelthewear TOOLS
# com.eaion.power.launcher PERSONALIZATION
# io.rlmax.memorycloud ENTERTAINMENT
# com.tiwa.advogadoag BUSINESS
# net.aramex MAPS_AND_NAVIGATION
# com.grupocajamar.wefferent FINANCE
# com.aadhk.woinvoice BUSINESS
# com.microsoft.xboxone.smartglass ENTERTAINMENT
# com.textmeinc.textme3 COMMUNICATION
# com.digibites.calendar PRODUCTIVITY
# com.everysing.lysn SOCIAL
# com.servico.territorios PRODUCTIVITY
# com.narvii.amino.x224165469 SOCIAL
# com.muthootfinance.imuthoot FINANCE
# com.tomatomusic.newringtones PERSONALIZATION
# com.freedomrewardz LIFESTYLE
# com.splashidandroid PRODUCTIVITY
# air.Prex FINANCE
# ru.ftc.xchange FINANCE
# com.blackberry.infrastructure PRODUCTIVITY
# com.gladtohaveyou.hospitality TRAVEL_AND_LOCAL
# com.ifs.banking.fiid1085 FINANCE
# com.pinssible.fancykey PERSONALIZATION
# com.mirrorai.app ENTERTAINMENT
# com.bvblogic.nimbusnote PRODUCTIVITY
# com.google.android.calendar PRODUCTIVITY
# com.tumblr SOCIAL
# com.musicplayer.playermusic MUSIC_AND_AUDIO
# com.odiosingle.calls COMMUNICATION
# com.formagrid.airtable PRODUCTIVITY
# eu.airpatrol.android TOOLS
# com.interswitchng.www FINANCE
# com.universalappsstudio.saibabaringtonesnewbest MUSIC_AND_AUDIO
# com.shao.Copy2SIM TOOLS
# com.disha.quickride TRAVEL_AND_LOCAL
# com.planday.ninetofiveapp BUSINESS
# com.allringtone.waheguru.ringtone TOOLS
# com.sec.samsungsoundphone ENTERTAINMENT
# com.intermedia.hq GAME_TRIVIA
# com.nhn.android.calendar PRODUCTIVITY
# com.buzzni.android.subapp.shoppingmoa SHOPPING
# com.sandisk.connect PRODUCTIVITY
# lifeisbetteron.com COMMUNICATION
# it.ingdirect.app FINANCE
# app.babychakra.babychakra PARENTING
# co.triller.droid VIDEO_PLAYERS
# com.cardwise.xpenditure BUSINESS
# polis.app.callrecorder COMMUNICATION
# com.belongtail.belong MEDICAL
# com.makeevapps.contactswidget COMMUNICATION
# com.zoho.mail.admin PRODUCTIVITY
# com.narvii.amino.x157296277 SOCIAL
# com.mobikwik_new.bajajfinserv FINANCE
# it.groupintown.android SHOPPING
# com.trulia.android HOUSE_AND_HOME
# com.ingbanktr.ingmobil FINANCE
# com.money91 BUSINESS
# vn.com.msb.smartBanking FINANCE
# app.manoth.fahsai LIFESTYLE
# com.lps.contactmerger TOOLS
# com.vsco.cam PHOTOGRAPHY
# com.nfwebdev.launcher10 PERSONALIZATION
# ovo.id FINANCE
# net.cloudcal.cal PRODUCTIVITY
# com.fotoable.paintlab PHOTOGRAPHY
# co.uk.getmondo FINANCE
# com.wooribank.smart.mwib FINANCE
# us.mitene PARENTING
# com.accusoft.barcodescanner.client SHOPPING
# com.mobimate.cwttogo TRAVEL_AND_LOCAL
# com.not.seen.unseen.no.last.seen.or.read TOOLS
# com.sleeperbot SPORTS
# com.hawk.android.hishare TOOLS
# com.guardian.security.pri TOOLS
# com.tecit.android.barcodekbd.demo PRODUCTIVITY
# com.narvii.amino.x67684557 SOCIAL
# com.telkom.mwallet FINANCE
# com.yinzcam.nfl.cowboys SPORTS
# com.spotluck TRAVEL_AND_LOCAL
# com.remind101 EDUCATION
# de.swr.ard_buffet ENTERTAINMENT
# com.ss.sportido HEALTH_AND_FITNESS
# com.venus.browser SHOPPING
# az.kapitalbank.mbanking FINANCE
# com.classco.marcel MAPS_AND_NAVIGATION
# de.schildbach.oeffi MAPS_AND_NAVIGATION
# com.yunasoft.awesomecal PRODUCTIVITY
# com.adesa.marketplace BUSINESS
# my.com.maybank2u.m2umobile FINANCE
# com.neat.android FINANCE
# com.etisalat.flous BUSINESS
# au.com.suncorp.marketplace FINANCE
# com.lguplus.ltealive ENTERTAINMENT
# com.moon.android.calendar TOOLS
# com.thegrizzlylabs.geniusfax BUSINESS
# com.science.wishboneapp SOCIAL
# pe.com.scotiabank.blpm.android.client FINANCE
# com.jingdong.th.app SHOPPING
# be.classic.oldphoneringtones.com PERSONALIZATION
# com.lakupon SHOPPING
# com.g5e.solitairepg.android GAME_CARD
# com.jabong.android SHOPPING
# br.com.rico.mobile FINANCE
# product.clicklabs.jugnoo MAPS_AND_NAVIGATION
# enbd.mobilebanking FINANCE
# com.facebook.orca COMMUNICATION
# is.smspunch.freesms COMMUNICATION
# com.adobe.echosign BUSINESS
# com.jiochat.jiochatapp COMMUNICATION
# com.narvii.amino.x44486328 SOCIAL
# com.BMCE_prod.bad FINANCE
# com.trfa.loudest ENTERTAINMENT
# id.co.aviana.m_pulsa BUSINESS
# ru.zhuck.webapp FINANCE
# com.gresilab.simplycards PHOTOGRAPHY
# com.bankofamerica.android.webwrapper FINANCE
# com.starhub.happy PRODUCTIVITY
# com.microsoft.dynamics.nav BUSINESS
# my.com.ezcab.ezcab MAPS_AND_NAVIGATION
# com.fmee.fmeeservf TRAVEL_AND_LOCAL
# net.IntouchApp PRODUCTIVITY
# br.com.sportv.times.saopaulo SPORTS
# com.lightx.storyz PHOTOGRAPHY
# com.phonecopy.android PRODUCTIVITY
# hayan.videotomp3.mp3converter.mediaconverter.ringtonemaker.videotomp3converterpro.free MUSIC_AND_AUDIO
# com.ftcash.customer FINANCE
# com.asai24.golf SPORTS
# it.seatpg.paginebianche BOOKS_AND_REFERENCE
# notebook.notepad.color.note.todo.list.memo.post.it LIFESTYLE
# com.justdial.jdlite TRAVEL_AND_LOCAL
# ru.sberbankmobile FINANCE
# com.paypal.android.p2pmobile FINANCE
# com.makeupeditor.makeup.camera.selfie.editor PHOTOGRAPHY
# com.simplemobiletools.calendar TOOLS
# com.ibillstudio.thedaycouple LIFESTYLE
# com.nhl.gc1112.free SPORTS
# com.nop.eortologio LIFESTYLE
# org.qbitpay FINANCE
# com.app.gujaratipanchang PRODUCTIVITY
# com.lps.contactremover PRODUCTIVITY
# com.molinmusic.menggu MUSIC_AND_AUDIO
# com.zoemob.gpstracking PARENTING
# sg.bigo.live SOCIAL
# com.bose.corporation.bosesleep HEALTH_AND_FITNESS
# com.tool.calendar TOOLS
# com.com2us.smon.normal.freefull.google.kr.android.common GAME_ROLE_PLAYING
# com.ifs.banking.fiid3364 FINANCE
# de.hafas.android.vvw MAPS_AND_NAVIGATION
# com.monday.monday PRODUCTIVITY
# com.microsoft.teams BUSINESS
# com.mydream.sarika.chantapp LIFESTYLE
# com.service.reports TOOLS
# com.lge.lifetracker HEALTH_AND_FITNESS
# com.BDI.mobile FINANCE
# com.humanity.apps.humanityV3 BUSINESS
# com.globe.gcash.android FINANCE
# com.antivirus TOOLS
# com.visu.dont.touch.my.phone TOOLS
# com.har.androidapp HOUSE_AND_HOME
# com.narvii.amino.x67 SOCIAL
# com.cloudshop BUSINESS
# com.rebbix.modnakasta SHOPPING
# com.checklist.android PRODUCTIVITY
# com.niceringtonesapps.funnyalarm MUSIC_AND_AUDIO
# com.pdffiller PRODUCTIVITY
# com.yahoo.mobile.client.android.mail COMMUNICATION
# es.bancopopular.nbmpopular FINANCE
# com.telos.app.im COMMUNICATION
# com.idamobile.android.LockoBank FINANCE
# com.gamevilusa.mlbpilive.android.google.global.normal GAME_SPORTS
# com.coolwinks.cwapp SHOPPING
# com.esocialllc.vel FINANCE
# com.pakdata.easyurdu PRODUCTIVITY
# com.music.mp3player.musicplayer MUSIC_AND_AUDIO
# hu.khb FINANCE
# az.pasha.mobilebank FINANCE
# com.bingoringtones.funnyalarm ENTERTAINMENT
# com.customsolutions.android.utl PRODUCTIVITY
# com.ibyteapps.joeandcharliefree LIFESTYLE
# com.trulia.android.rentals HOUSE_AND_HOME
# es.cecabank.ealia2085appstore FINANCE
# cx.ring COMMUNICATION
# com.credicard.app FINANCE
# com.simpler.backup PRODUCTIVITY
# com.ndrive.androidtmndrive TRAVEL_AND_LOCAL
# com.boldbeast.recorder TOOLS
# com.avira.optimizer PRODUCTIVITY
# com.reliableacademy.mpscofficer EDUCATION
# com.ovuline.fertility MEDICAL
# com.emeint.android.mwallet.bm FINANCE
# com.yinzcam.nfl.seahawks SPORTS
# org.telegram.BifToGram COMMUNICATION
# com.appgenix.bizcal PRODUCTIVITY
# com.armut.armutha LIFESTYLE
# com.makelifesimple.duplicatedetector TOOLS
# com.fotoable.faceswap.c403 PHOTOGRAPHY
# com.iledger.book BUSINESS
# br.com.maceda.android.antifurtow TOOLS
# com.ubercab MAPS_AND_NAVIGATION
# com.mykronoz.zefit4 HEALTH_AND_FITNESS
# finarea.Telbo COMMUNICATION
# com.planetfitness HEALTH_AND_FITNESS
# me.swiftgift.swiftgift SHOPPING
# com.rayg.sirens ENTERTAINMENT
# com.applegends.ringtones.free_songs ENTERTAINMENT
# com.momobills.billsapp BUSINESS
# co.alegra.app BUSINESS
# com.jrj.bellsandwhistles PERSONALIZATION
# de.eos.uptrade.android.fahrinfo.berlin MAPS_AND_NAVIGATION
# com.fi7233.godough FINANCE
# com.cisco.im COMMUNICATION
# com.chamberlain.myq.chamberlain LIFESTYLE
# la.droid.qr PRODUCTIVITY
# com.narvii.amino.x231629506 SOCIAL
# com.grandcinema.gcapp.screens ENTERTAINMENT
# Not found genre id in ir.mobillet.app
# com.obhai TRAVEL_AND_LOCAL
# com.timleg.egoTimerLight PRODUCTIVITY
# com.investec.app FINANCE
# com.amazon.clouddrive.photos PHOTOGRAPHY
# com.kimco.anhhungtruyen GAME_ROLE_PLAYING
# ru.ftc.faktura.multibank FINANCE
# com.tamilkeyboard.inputmethod.tamillanguageapp.typing TOOLS
# com.niceringtonesapps.xmasrtswp MUSIC_AND_AUDIO
# com.k7computing.android.security TOOLS
# com.zoosk.zoosk DATING
# id.caller.email COMMUNICATION
# com.g5e.motopg.android GAME_ADVENTURE
# free.call.international.phone.calling COMMUNICATION
# com.techwave.bahaquotearabic PRODUCTIVITY
# com.eg.android.AlipayGphone FINANCE
# sk.henrichg.phoneprofilesplus TOOLS
# com.recommended.videocall COMMUNICATION
# com.metamoji.noteanytime PRODUCTIVITY
# org.Keku COMMUNICATION
# fancy.keyboard.app.kittykeyboard PERSONALIZATION
# com.goibibo TRAVEL_AND_LOCAL
# hk.d100 NEWS_AND_MAGAZINES
# com.revesoft.mobiledialer.dialglobe_communication.nimcalls_99332 COMMUNICATION
# com.sabb FINANCE
# it.hype.app FINANCE
# fr.snapp.fidme SHOPPING
# hd.camera.p7.photo PHOTOGRAPHY
# sisinc.com.sis SOCIAL
# org.ilwt.lagatgram COMMUNICATION
# in.playsimple.wordtrip GAME_WORD
# com.whypay FINANCE
# de.nexxoo.radiob2 MUSIC_AND_AUDIO
# ru.s7.android TRAVEL_AND_LOCAL
# uz.dida.payme FINANCE
# com.ofss.fcdb.mobile.android.phone.BAE.launcher FINANCE
# com.recetasgratisnet.recetasdecocina FOOD_AND_DRINK
# com.purolator.mobileapp BUSINESS
# es.lacaixa.hceicon2 FINANCE
# com.microsoft.emmx COMMUNICATION
# com.skype.m2 COMMUNICATION
# com.mmtstraintimings TRAVEL_AND_LOCAL
# de.eos.uptrade.android.fahrinfo.hamburg MAPS_AND_NAVIGATION
# com.arthurivanets.reminder PRODUCTIVITY
# com.pcnc.bop FINANCE
# com.uaprom.prom BUSINESS
# com.g5e.lettersfromnowherepg.android GAME_CASUAL
# br.com.neon FINANCE
# com.LTGExamPracticePlatform.Prep4SAT EDUCATION
# com.apple.movetoios TOOLS
# com.posteitaliane.postemobilestore TOOLS
# ch.protonmail.android COMMUNICATION
# com.zhiliaoapp.musically SOCIAL
# whatsscan.dualappclone.whatzwebstatussaver COMMUNICATION
# com.keesadens.SIMcardToolManager TOOLS
# com.blackberry.blackberrylauncher PRODUCTIVITY
# com.facemoji.lite.xiaomi.gp PERSONALIZATION
# jp.co.elecom.android.elenote2 PRODUCTIVITY
# com.mizuvoip.mizudroid.app COMMUNICATION
# info.thereisonlywe.planetarytimes LIFESTYLE
# com.aura.ringtones.auraanimals ENTERTAINMENT
# io.huwi.stable ENTERTAINMENT
# com.tmon SHOPPING
# com.gabangmanstudio.psrmanager GAME_RACING
# com.sadadpsp.eva FINANCE
# me.nextplus.smsfreetext.phonecalls COMMUNICATION
# virus.cleaner.antivirus.phone.security.boost TOOLS
# com.advantage.RaiffeisenBank FINANCE
# com.Easy.Arabictyping.Keyboard PRODUCTIVITY
# com.mygate.user LIFESTYLE
# com.deputy.android BUSINESS
# com.golemtechapps.shivasongs MUSIC_AND_AUDIO
# smartroid.pronouncewhoiscalling PRODUCTIVITY
# com.confitek.divemateusb SPORTS
# com.keramidas.TitaniumBackup TOOLS
# kz.atfbanking.atf24 FINANCE
# de.hafas.android.vbn MAPS_AND_NAVIGATION
# com.playfake.fakechat.fakenger ENTERTAINMENT
# com.briniclemobile.wibeetalk COMMUNICATION
# com.narvii.amino.x244304829 SOCIAL
# com.yinzcam.nba.sixers SPORTS
# com.nest.android LIFESTYLE
# com.afl.afl_coll.android SPORTS
# cm.confide.android BUSINESS
# id.co.cimbniaga.mobile.android FINANCE
# com.lge.p2p COMMUNICATION
# com.universalappsstudio.maadurgaringtones MUSIC_AND_AUDIO
# com.jrj.loudsirenringtones ENTERTAINMENT
# ru.babyk.android PARENTING
# co.th.kiatnakin.kkauto FINANCE
# apli.tv.yabadoo ENTERTAINMENT
# com.touchnote.android PHOTOGRAPHY
# be.dkv.dkvbelgium MEDICAL
# com.eventbrite.organizer BUSINESS
# com.jwaala.mobile.redwoodcuorg FINANCE
# com.tinybeans PARENTING
# com.niceringtonesapps.bests9rtswps PERSONALIZATION
# com.grandstream.wave COMMUNICATION
# com.vacationrentals.homeaway TRAVEL_AND_LOCAL
# pl.raiffeisen.nfc FINANCE
# com.truecontext.prontoforms BUSINESS
# pl.mbank FINANCE
# com.universalappsstudio.gurbaniringtonesnewbest MUSIC_AND_AUDIO
# com.taxislibres.conductor MAPS_AND_NAVIGATION
# com.manzy.bellaftervib TOOLS
# ru.simpls.brs2.mobbank FINANCE
# com.docusign.ink PRODUCTIVITY
# com.cibc.android.mobi FINANCE
# in.sweatco.app HEALTH_AND_FITNESS
# com.hyperspeed.rocketclean TOOLS
# com.sberbanktele COMMUNICATION
# com.Spanish.Ringtones LIBRARIES_AND_DEMO
# com.teamunify.ondeck SPORTS
# com.yinzcam.nfl.texans SPORTS
# com.tractive.android.gps LIFESTYLE
# com.penzu.android LIFESTYLE
# com.kakafun.kaka2hand SOCIAL
# com.vtrostudio.classical_ringtone PERSONALIZATION
# com.afl.afl_haw.android SPORTS
# com.guibais.whatsauto COMMUNICATION
# it.creval.bancaperta FINANCE
# org.vom8x8.sipua COMMUNICATION
# com.agerigna.chat COMMUNICATION
# com.rssl.sboldb FINANCE
# com.rauscha.apps.timesheet PRODUCTIVITY
# com.fuze.fuzeapp BUSINESS
# com.flightaware.android.liveFlightTracker TRAVEL_AND_LOCAL
# com.mockup EDUCATION
# com.topps.force ENTERTAINMENT
# pt.nos.selfcare TOOLS
# is.ja.jaapp COMMUNICATION
# it.nogood.container FINANCE
# com.vrbo.android TRAVEL_AND_LOCAL
# com.yinzcam.nfl.jets SPORTS
# com.cisco.wx2.android BUSINESS
# com.narvii.amino.x31 SOCIAL
# com.bestringtonesapps.bestringtonesfree MUSIC_AND_AUDIO
# wit.android.bcpBankingApp.millenniumPL FINANCE
# com.payworld.mobileapp BUSINESS
# sk.mbank FINANCE
# com.msf.kbank.mobile FINANCE
# com.gscandroid.yk ENTERTAINMENT
# by.belinvestbank FINANCE
# com.mfw.roadbook TRAVEL_AND_LOCAL
# com.ukrsibbank.client.android FINANCE
# cn.paperang.international TOOLS
# indian.plusone.phone.launcher PERSONALIZATION
# fast.junk.cleaner.ram.booster.battery.saver.free.fast.cleaner TOOLS
# com.mobillium.papara FINANCE
# com.herzick.houseparty SOCIAL
# deskshare.com.pctomobiletransfer TOOLS
# com.emoji.keyboard.touchpal PERSONALIZATION
# com.amazon.windowshop SHOPPING
# com.agerigna.keyboard TOOLS
# hk.easyvan.app.client MAPS_AND_NAVIGATION
# com.sbs.lamusica MUSIC_AND_AUDIO
# by.bgpb.mbanking FINANCE
# com.techlogix.mobilinkcustomer FINANCE
# com.pandasecurity.pandaav TOOLS
# com.whatsapp COMMUNICATION
# com.its.rto AUTO_AND_VEHICLES
# com.cleevio.spendee FINANCE
# com.taxis99 MAPS_AND_NAVIGATION
# com.propredection.fantasypro ENTERTAINMENT
# cn.futu.trader FINANCE
# com.twogrand.twogrand LIFESTYLE
# co.infinum.nlb FINANCE
# com.sc.breezenigeria.banking FINANCE
# ge.space.app FINANCE
# com.blendr.mobile DATING
# com.sabre.tripcase.android TRAVEL_AND_LOCAL
# nl.negentwee TRAVEL_AND_LOCAL
# com.herokuapp.haikujam SOCIAL
# com.linpusime_tc.android.linpus_tckbd PRODUCTIVITY
# com.zoho.assist PRODUCTIVITY
# kr.go.wetax.android FINANCE
# com.smartertime PRODUCTIVITY
# Not found genre id in com.narvii.amino.x22
# in.vesolve.flyking.activities BUSINESS
# com.conanunciosgratis.conanunciosgratiscars LIFESTYLE
# com.mobileboss.buon.giorno.sena.notte COMICS
# xyz.klinker.messenger COMMUNICATION
# com.redraw.keyboard.theme.newkeyboard20181 PERSONALIZATION
# qrcode.qrcode.scanner.qrcode.reader.pro TOOLS
# de.testo.dmrapp TOOLS
# ru.pochtabank.prometheus FINANCE
# com.ifs.banking.fiid5039 FINANCE
# com.smarterapps.itmanager PRODUCTIVITY
# com.anttek.diary LIFESTYLE
# com.narvii.amino.x38 SOCIAL
# finarea.VoipDiscountCalls COMMUNICATION
# com.facebook.katana SOCIAL
# com.ionicframework.rendafixa997647 FINANCE
# org.jwss.jwplanner.app PRODUCTIVITY
# com.mobile.android.celtics SPORTS
# de.dbware.circlelauncher.light PRODUCTIVITY
# com.revesoft.mobiledialer.vibeplus_49601 COMMUNICATION
# com.mode.bok.ui FINANCE
# com.tcs.interviewready EDUCATION
# uk.co.hsbc.hsbcukmobilebanking FINANCE
# com.narvii.amino.x18 SOCIAL
# com.mediapro.entertainment.ringtone_wallpaper ENTERTAINMENT
# com.bgpworks.beep PRODUCTIVITY
# com.Webbeat.Datumprikker PRODUCTIVITY
# com.eniro TRAVEL_AND_LOCAL
# com.ifs.banking.fiid1425 FINANCE
# com.guruinfomedia.ebook.pdfviewer PRODUCTIVITY
# com.homescreen.phone.theme PRODUCTIVITY
# vn.mobifone.mobifonenext BUSINESS
# ru.gelin.android.sendtosd TOOLS
# cb.ibank FINANCE
# com.paltalk.chat.android SOCIAL
# ua.com.cs.ifobs.mobile.android.otp BUSINESS
# com.nearbuy.nearbuymobile FOOD_AND_DRINK
# com.blocktrail.mywallet FINANCE
# com.naver.nozzle PRODUCTIVITY
# com.niceringtonesapps.funrts PERSONALIZATION
# es.mrcl.app.juasapp ENTERTAINMENT
# com.three60.cabioclient TRAVEL_AND_LOCAL
# com.datainfosys.datamail COMMUNICATION
# com.iflytek.freeringtones MUSIC_AND_AUDIO
# com.s4m FINANCE
# com.tac.woodproof HEALTH_AND_FITNESS
# com.meihillman.ringtonemaker VIDEO_PLAYERS
# com.sony.songpal MUSIC_AND_AUDIO
# com.google.android.apps.tachyon COMMUNICATION
# com.signnow.android PRODUCTIVITY
# tursky.jan.settings TOOLS
# au.com.nab.mobile FINANCE
# nl.afas.pocket2 PRODUCTIVITY
# in.fulldive.shell ENTERTAINMENT
# com.publicbank.PBBVOCA FINANCE
# com.bitdefender.centralmgmt TOOLS
# finarea.VoipStunt SOCIAL
# com.mobiles.numberbookdirectory SOCIAL
# com.malam.caller.name.talker TOOLS
# com.ninefolders.hd3.work BUSINESS
# guru.gnom_dev PRODUCTIVITY
# sk.vub.mobile FINANCE
# app.mcash.my SHOPPING
# com.wizwid SHOPPING
# Not found genre id in wit.android.bcpBankingApp.millennium
# cgd.pt.caixadirectaparticulares FINANCE
# com.sdu.didi.psnger MAPS_AND_NAVIGATION
# np.com.rsubedi.ncellntcservices LIFESTYLE
# com.qrcode.barcode.reader TOOLS
# com.makenow.beautycamera.makeupeditor PHOTOGRAPHY
# com.gnp BUSINESS
# air.com.ssdsoftwaresolutions.clickuz FINANCE
# com.jrj.dogandcat PERSONALIZATION
