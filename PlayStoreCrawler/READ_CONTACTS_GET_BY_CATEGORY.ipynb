# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time
import csv
import random
from time import sleep


def application_list(filename):
    df = pd.read_excel(filename)
    data = set()
    for _, row in df.iterrows():
        if row["Sentences"].startswith("##"):
            app_id = row["Sentences"].split("##")[1]
            data.add(app_id)
    return data

def get_top_free_applications(categories):
    def per_category_top_free(category):
        waiting_urls = set()
        url = 'http://localhost:3000/api/apps/?collection=topselling_free&category={}&lang=en'.format(category)
        #top free applications
        response = requests.get(url)
        if response.status_code == 200:
            for app in response.json()["results"]:
                waiting_urls.add(app["url"])
        else:
            print("Request Error")
        return waiting_urls
    all_top_free_apps = set()
    for category in categories:
        all_top_free_apps.update(per_category_top_free(category))
    return all_top_free_apps

def get_app_category(app_id):
    base_url = 'http://localhost:3000/api/apps/'
    response = requests.get(base_url+app_id)
    if response.status_code == 200:
        gid = response.json()["genreId"].upper()
        return gid
    else:
        print(app_id, " category cannot be found")
        return "NOT_FOUND"
    
    
def is_permission_exist(url):
    response = requests.get(url+"/permissions")
    if response.status_code == 200:
        json = response.json()
        for line in json["results"]:
            if permission_content in line["permission"]:
                return True
        return False
    else:
        print("Permission link is failed")
        
def get_similar_ids(app_id):
    sleep(0.1)
    page = requests.get("https://play.google.com/store/apps/details?id={}".format(app_id))
    soup = BeautifulSoup(page.content, 'html.parser')
    href = soup.find(class_='LkLjZd ScJHi U8Ww7d xjAeve nMZKrb id-track-click ')
    if href != None:
        href = href["href"]
        sleep(0.2)
        page = requests.get(href)
        soup = BeautifulSoup(page.content, 'html.parser')
        similars = []
        for link in soup.find_all(class_="JC71ub"):
            similars.append(link['href'].split("=")[1])
        return similars
    else:
        return []

# %%
permission_type = "READ_CONTACTS"
downloded_file = "SEVIL.xlsx"
categories = {"categories":[{"cat_key":"OVERALL","name":"Overall"},{"cat_key":"APPLICATION","name":"All apps"},{"cat_key":"GAME","name":"All games"},{"cat_key":"ART_AND_DESIGN","name":"Art & Design"},{"cat_key":"AUTO_AND_VEHICLES","name":"Auto & Vehicles"},{"cat_key":"BEAUTY","name":"Beauty"},{"cat_key":"BOOKS_AND_REFERENCE","name":"Books & Reference"},{"cat_key":"BUSINESS","name":"Business"},{"cat_key":"COMICS","name":"Comics"},{"cat_key":"COMMUNICATION","name":"Communication"},{"cat_key":"DATING","name":"Dating"},{"cat_key":"EDUCATION","name":"Education"},{"cat_key":"ENTERTAINMENT","name":"Entertainment"},{"cat_key":"EVENTS","name":"Events"},{"cat_key":"FINANCE","name":"Finance"},{"cat_key":"FOOD_AND_DRINK","name":"Food & Drink"},{"cat_key":"HEALTH_AND_FITNESS","name":"Health & Fitness"},{"cat_key":"HOUSE_AND_HOME","name":"House & Home"},{"cat_key":"LIFESTYLE","name":"Lifestyle"},{"cat_key":"MAPS_AND_NAVIGATION","name":"Maps & Navigation"},{"cat_key":"MEDICAL","name":"Medical"},{"cat_key":"MUSIC_AND_AUDIO","name":"Music & Audio"},{"cat_key":"NEWS_AND_MAGAZINES","name":"News & Magazines"},{"cat_key":"PARENTING","name":"Parenting"},{"cat_key":"PERSONALIZATION","name":"Personalization"},{"cat_key":"PHOTOGRAPHY","name":"Photography"},{"cat_key":"PRODUCTIVITY","name":"Productivity"},{"cat_key":"SHOPPING","name":"Shopping"},{"cat_key":"SOCIAL","name":"Social"},{"cat_key":"SPORTS","name":"Sports"},{"cat_key":"TOOLS","name":"Tools"},{"cat_key":"TRAVEL_AND_LOCAL","name":"Travel & Local"},{"cat_key":"VIDEO_PLAYERS","name":"Video Players & Editors"},{"cat_key":"WEATHER","name":"Weather"},{"cat_key":"LIBRARIES_AND_DEMO","name":"Libraries & Demo"},{"cat_key":"GAME_ARCADE","name":"Arcade"},{"cat_key":"GAME_PUZZLE","name":"Puzzle"},{"cat_key":"GAME_CARD","name":"Cards"},{"cat_key":"GAME_CASUAL","name":"Casual"},{"cat_key":"GAME_RACING","name":"Racing"},{"cat_key":"GAME_SPORTS","name":"Sport Games"},{"cat_key":"GAME_ACTION","name":"Action"},{"cat_key":"GAME_ADVENTURE","name":"Adventure"},{"cat_key":"GAME_BOARD","name":"Board"},{"cat_key":"GAME_CASINO","name":"Casino"},{"cat_key":"GAME_EDUCATIONAL","name":"Educational"},{"cat_key":"GAME_MUSIC","name":"Music Games"},{"cat_key":"GAME_ROLE_PLAYING","name":"Role Playing"},{"cat_key":"GAME_SIMULATION","name":"Simulation"},{"cat_key":"GAME_STRATEGY","name":"Strategy"},{"cat_key":"GAME_TRIVIA","name":"Trivia"},{"cat_key":"GAME_WORD","name":"Word Games"},{"cat_key":"ANDROID_WEAR","name":"Android Wear"},{"cat_key":"FAMILY","name":"Family All Ages"},{"cat_key":"FAMILY_UNDER_5","name":"Family Ages 5 & Under"},{"cat_key":"FAMILY_6_TO_8","name":"Family Ages 6-8"},{"cat_key":"FAMILY_9_AND_UP","name":"Family Ages 9 & Up"},{"cat_key":"FAMILY_ACTION","name":"Family Action"},{"cat_key":"FAMILY_BRAINGAMES","name":"Family Brain Games"},{"cat_key":"FAMILY_CREATE","name":"Family Create"},{"cat_key":"FAMILY_EDUCATION","name":"Family Education"},{"cat_key":"FAMILY_MUSICVIDEO","name":"Family Music & Video"},{"cat_key":"FAMILY_PRETEND","name":"Family Pretend Play"}]}
if permission_type == "RECORD_AUDIO":
    category_keys = ["GAME_TRIVIA", "HEALTH_AND_FITNESS", "PARENTING", "BOOKS_AND_REFERENCE", "GAME_MUSIC", "SPORTS", "GAME_EDUCATIONAL", "MEDICAL", "LIBRARIES_AND_DEMO", "GAME_CARD", "FOOD_AND_DRINK", "GAME_SIMULATION", "GAME_SPORTS", "GAME_ADVENTURE", "EVENTS", "ART_AND_DESIGN", "AUTO_AND_VEHICLES", "GAME_RACING", "GAME_PUZZLE", "NOT_FOUND", "BEAUTY", "COMICS", "GAME_ARCADE"]
else:
    category_keys = [cat["cat_key"] for cat in categories["categories"]]

permission_phrase = "record audio" if permission_type == "RECORD_AUDIO" else "read your contacts"
downloaded_apps_check = True if permission_type == "RECORD_AUDIO" else False

# %%
permission_type = permission_type
check_downloaded_apps = downloaded_apps_check
permission_content = permission_phrase
if check_downloaded_apps:
    dowloaded_list = application_list(downloded_file)

# %%
top_free_apps = get_top_free_applications(category_keys)
# Out:
# Request Error
# Request Error
# Request Error
# Request Error

# %%
init_apps = top_free_apps
waiting_urls = list(init_apps)
random.shuffle(waiting_urls)
waiting_urls_unique_check = set([url for url in waiting_urls])
app_ids = set()


counter = 0
while (len(app_ids) + len(waiting_urls)) < 100000:
    try:
        if counter % 10 == 0:
            print("Total number of apps", len(app_ids) + len(waiting_urls))
            print("Collected app ids", len(app_ids))
        try:
            url = waiting_urls.pop()
            waiting_urls_unique_check.remove(url)
        except Exception:
            print("All linked applications are traversed")
            break

        #add apk id if it is free, popular, and has longer description than 500 characters
        response = requests.get(url)
        print(url, end=" ")
        if response.status_code == 200:
            print("SUCCESS")
            json = response.json()
            if json["minInstalls"] > 10000 and json["priceText"] == "Free" and len(json["description"]) > 500:
                application_id = url.split('/')[-1]
                if application_id not in app_ids:
                    if is_permission_exist(url):
                        print("PERMISSION EXIST")
                        app_ids.add(application_id)
                        cat = get_app_category(application_id)
                        with open("{}/{}.txt".format(permission_type, cat), "a") as target:
                            target.write(application_id + "\n")
                            print("DOWNLOADED NOW")                  
        else:
            print("FAIL")

        #add similar app urls
        for sim_id in get_similar_ids(url.split("/")[-1]):
            sim_id = "http://localhost:3000/api/apps/" + sim_id
            if sim_id not in waiting_urls_unique_check:
                waiting_urls_unique_check.add(sim_id)
                waiting_urls.append(sim_id)
        random.shuffle(waiting_urls)
        counter += 1
    except Exception:
        print("Number of waiting_urls ", len(waiting_urls))
        pass
print("-----------------------------------------------------------------------------------------------------------")
print("TRAVERSING COMPLETED")
for url in waiting_urls:
    print(url, end=" ")
    response = requests.get(url)
    if response.status_code == 200:
        print("SUCCESS")
        json = response.json()
        if json["minInstalls"] > 10000 and json["priceText"] == "Free" and len(json["description"]) > 500:
            application_id = url.split('/')[-1]
            if application_id not in app_ids:
                if is_permission_exist(url):
                    print("PERMISSION EXIST")
                    app_ids.add(application_id )
                    cat = get_app_category(application_id)
                    with open("{}/{}.txt".format(permission_type, cat), "a") as target:
                        target.write(application_id + "\n")
    else:
        print("FAIL")
# Out:
# Total number of apps 3170
# Collected app ids 0
# http://localhost:3000/api/apps/com.manualslib.app SUCCESS
# http://localhost:3000/api/apps/mobile.appBqzeVZ7DIZ SUCCESS
# http://localhost:3000/api/apps/com.crowdcomms.elements SUCCESS
# http://localhost:3000/api/apps/com.ftxgames.twdslots SUCCESS
# http://localhost:3000/api/apps/com.t11.skyviewfree SUCCESS
# http://localhost:3000/api/apps/com.clearcare.clearcareconnect SUCCESS
# http://localhost:3000/api/apps/com.revolverolver.fliptrickster SUCCESS
# http://localhost:3000/api/apps/com.pixelart.coloringbook.colorbynumber SUCCESS
# http://localhost:3000/api/apps/bling.crush.match3.free.android SUCCESS
# http://localhost:3000/api/apps/com.google.android.apps.photos SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# Total number of apps 3444
# Collected app ids 1
# http://localhost:3000/api/apps/com.dreame.reader SUCCESS
# http://localhost:3000/api/apps/com.nordcurrent.sniperarena SUCCESS
# http://localhost:3000/api/apps/com.genewarrior.sunlocator.lite SUCCESS
# http://localhost:3000/api/apps/com.sinyee.babybus.zoo SUCCESS
# http://localhost:3000/api/apps/com.nighp.babytracker_android SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.cougardating.olderwomendating SUCCESS
# http://localhost:3000/api/apps/com.crowdstar.covetHome SUCCESS
# http://localhost:3000/api/apps/fr.two4tea.fightlist SUCCESS
# http://localhost:3000/api/apps/com.zhystudio.FamousLoveRomanceNovels SUCCESS
# http://localhost:3000/api/apps/com.robtopx.geometryjumplite SUCCESS
# Total number of apps 3737
# Collected app ids 2
# http://localhost:3000/api/apps/com.vtm.voicechanger SUCCESS
# http://localhost:3000/api/apps/com.gamehivecorp.taptitans2 SUCCESS
# http://localhost:3000/api/apps/com.lydia.wordsgame.word.talent SUCCESS
# http://localhost:3000/api/apps/com.ga.monster.gorilla.hunting.sniper.shooter SUCCESS
# http://localhost:3000/api/apps/com.disney.thoughtbubbles_goo SUCCESS
# http://localhost:3000/api/apps/com.eyup.MeowMusic SUCCESS
# http://localhost:3000/api/apps/com.curiosity.curiositystream SUCCESS
# http://localhost:3000/api/apps/com.duowan.supervideo SUCCESS
# http://localhost:3000/api/apps/com.babycenter.pregnancytracker SUCCESS
# http://localhost:3000/api/apps/com.rsnapp.moral_stories_in_inglish SUCCESS
# Total number of apps 4081
# Collected app ids 2
# http://localhost:3000/api/apps/com.instacart.client.publix SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.nbcuni.usie.seriesendless SUCCESS
# http://localhost:3000/api/apps/com.affirm.central SUCCESS
# http://localhost:3000/api/apps/com.anansimobile.lt SUCCESS
# http://localhost:3000/api/apps/com.facebook.lite SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.kake.android.weather SUCCESS
# http://localhost:3000/api/apps/com.syf.mysynchrony SUCCESS
# http://localhost:3000/api/apps/com.tap2fun.survivor.prision.escape.breakthejail.prisonstorm SUCCESS
# http://localhost:3000/api/apps/com.fpsshooter.battleroyale SUCCESS
# http://localhost:3000/api/apps/com.isysway.free.alquran SUCCESS
# Total number of apps 4410
# Collected app ids 4
# http://localhost:3000/api/apps/com.aps.crazy.tricky.trail.mega.bike.master SUCCESS
# http://localhost:3000/api/apps/com.efun.encktx SUCCESS
# http://localhost:3000/api/apps/jp.gocro.smartnews.android SUCCESS
# http://localhost:3000/api/apps/com.tbegames.and.best_monster_racing SUCCESS
# http://localhost:3000/api/apps/com.wb.goog.mkx SUCCESS
# http://localhost:3000/api/apps/com.hbo.hbonow SUCCESS
# http://localhost:3000/api/apps/com.clearchannel.iheartradio.controller SUCCESS
# http://localhost:3000/api/apps/com.pnc.ecommerce.mobile SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/ai.kanghealth SUCCESS
# http://localhost:3000/api/apps/air.com.sgn.cookiejam.gp SUCCESS
# Total number of apps 4652
# Collected app ids 5
# http://localhost:3000/api/apps/sandbox.art.sandbox SUCCESS
# http://localhost:3000/api/apps/com.sinyee.babybus.picnic SUCCESS
# http://localhost:3000/api/apps/com.textmeinc.textme SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.orange.coloring.learn.kids SUCCESS
# http://localhost:3000/api/apps/com.im30.ROE.gp SUCCESS
# http://localhost:3000/api/apps/com.ckenterprises.memesoundboard SUCCESS
# http://localhost:3000/api/apps/com.ayogamez.sketchcartoon SUCCESS
# http://localhost:3000/api/apps/io.voodoo.paper2 SUCCESS
# http://localhost:3000/api/apps/com.sweetlovloc.huuppy SUCCESS
# http://localhost:3000/api/apps/com.miniclip.topskater SUCCESS
# Total number of apps 4890
# Collected app ids 6
# http://localhost:3000/api/apps/com.perblue.disneyheroes SUCCESS
# http://localhost:3000/api/apps/com.docusign.ink SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.playgendary.pinatamasters SUCCESS
# http://localhost:3000/api/apps/air.com.winkypinky.babybellabraidedhairsalon SUCCESS
# http://localhost:3000/api/apps/com.sportngin.android SUCCESS
# http://localhost:3000/api/apps/air.com.winkypinky.labradorquadrupletsnewborncaring SUCCESS
# http://localhost:3000/api/apps/com.atomicadd.fotos SUCCESS
# http://localhost:3000/api/apps/co.pamobile.pokemon.cardmaker SUCCESS
# http://localhost:3000/api/apps/com.gameloft.android.ANMP.GloftFWHM SUCCESS
# http://localhost:3000/api/apps/games.mini.sports.bodybuilder.fighting.gym SUCCESS
# Total number of apps 5119
# Collected app ids 7
# http://localhost:3000/api/apps/com.petsmart.consumermobile SUCCESS
# http://localhost:3000/api/apps/com.coffeebeanventures.easyvoicerecorder SUCCESS
# http://localhost:3000/api/apps/com.i2c.mcp.movocash SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/free.music.player.tube.songs.stream SUCCESS
# http://localhost:3000/api/apps/com.wb.goog.hothands SUCCESS
# http://localhost:3000/api/apps/com.rollingstorm.iamflix SUCCESS
# http://localhost:3000/api/apps/com.meme.soundboard.custom.mlg.vennn SUCCESS
# http://localhost:3000/api/apps/air.com.bitrhymes.bingo SUCCESS
# http://localhost:3000/api/apps/com.mcdo.mcdonalds SUCCESS
# http://localhost:3000/api/apps/com.buzzfeed.android SUCCESS
# Total number of apps 5279
# Collected app ids 8
# http://localhost:3000/api/apps/com.microsoft.xboxone.smartglass SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.usatoday.android.news SUCCESS
# http://localhost:3000/api/apps/br.com.tapps.myvirtualpetshop SUCCESS
# http://localhost:3000/api/apps/com.allrecipes.spinner.free SUCCESS
# http://localhost:3000/api/apps/com.BlueeWooTeam.threeDSE SUCCESS
# http://localhost:3000/api/apps/com.looobati.hdwallpaper SUCCESS
# http://localhost:3000/api/apps/com.blackboard.android.bbstudent SUCCESS
# http://localhost:3000/api/apps/com.marylandhealthconnection.mobile SUCCESS
# http://localhost:3000/api/apps/sk.phx.skeeball SUCCESS
# http://localhost:3000/api/apps/com.adobe.lrmobile SUCCESS
# Total number of apps 5538
# Collected app ids 9
# http://localhost:3000/api/apps/com.genewarrior.sunlocator.pro SUCCESS
# http://localhost:3000/api/apps/com.spilgames.UphillRush SUCCESS
# http://localhost:3000/api/apps/com.qiiwi.wordington SUCCESS
# http://localhost:3000/api/apps/com.lemongame.klondike.solitaire SUCCESS
# http://localhost:3000/api/apps/mnn.Android SUCCESS
# http://localhost:3000/api/apps/com.mpb.funny.word.happyword.stu SUCCESS
# http://localhost:3000/api/apps/com.rovio.dream SUCCESS
# http://localhost:3000/api/apps/com.clearchannel.iheartradio.controller SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev341420.app419900 SUCCESS
# http://localhost:3000/api/apps/com.t11.skyview SUCCESS
# Total number of apps 5731
# Collected app ids 9
# http://localhost:3000/api/apps/com.disney.wdw.android SUCCESS
# http://localhost:3000/api/apps/org.jw.jwlibrary.mobile SUCCESS
# http://localhost:3000/api/apps/com.aetnd.svod.lmc SUCCESS
# http://localhost:3000/api/apps/com.ballytechnologies.quickhitslots SUCCESS
# http://localhost:3000/api/apps/net.gogame.dragon SUCCESS
# http://localhost:3000/api/apps/com.outfit7.mytalkingtom2 SUCCESS
# http://localhost:3000/api/apps/com.jdpapps.wordsearch SUCCESS
# http://localhost:3000/api/apps/com.nte.quickcross2 SUCCESS
# http://localhost:3000/api/apps/com.pikpok.dr2.play SUCCESS
# http://localhost:3000/api/apps/com.booking SUCCESS
# Total number of apps 5977
# Collected app ids 9
# http://localhost:3000/api/apps/com.babbel.mobile.android.en SUCCESS
# http://localhost:3000/api/apps/com.sporteasy.android SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.custom.spillit SUCCESS
# http://localhost:3000/api/apps/com.cupidmedia.wrapper.interracialcupid SUCCESS
# http://localhost:3000/api/apps/com.ironhorsegames.idleherodefensefantasydefensetd SUCCESS
# http://localhost:3000/api/apps/com.milliongames.happybikewheels SUCCESS
# http://localhost:3000/api/apps/com.wordstacks.wordcrush.en SUCCESS
# http://localhost:3000/api/apps/com.cookie.cubes.candy.story.pop.crush.free SUCCESS
# http://localhost:3000/api/apps/com.simulationcurriculum.skysafari5 SUCCESS
# http://localhost:3000/api/apps/com.wf.wellsfargomobile SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# Total number of apps 6146
# Collected app ids 11
# http://localhost:3000/api/apps/com.coco.hesi SUCCESS
# http://localhost:3000/api/apps/com.wlex.android.weather SUCCESS
# http://localhost:3000/api/apps/com.colorfree.pixel.number.coloring SUCCESS
# http://localhost:3000/api/apps/com.bandainamcoent.digimon_linkz_ww SUCCESS
# http://localhost:3000/api/apps/appinventor.ai_frankrblog.MyVideos SUCCESS
# http://localhost:3000/api/apps/com.gen.bettermen SUCCESS
# http://localhost:3000/api/apps/com.radiocom SUCCESS
# http://localhost:3000/api/apps/com.inconceptlabs.liveboard SUCCESS
# http://localhost:3000/api/apps/com.alien.shooter.galaxy.attack SUCCESS
# http://localhost:3000/api/apps/cz.digerati.babyfeed SUCCESS
# Total number of apps 6403
# Collected app ids 11
# http://localhost:3000/api/apps/orion.apps.biblesongs SUCCESS
# http://localhost:3000/api/apps/com.tap4fun.seagame.gplay SUCCESS
# http://localhost:3000/api/apps/kr.gerald.dontcrymybaby SUCCESS
# http://localhost:3000/api/apps/com.outlook.e4d48.globglogabgalab SUCCESS
# http://localhost:3000/api/apps/com.infigames.babyphone SUCCESS
# http://localhost:3000/api/apps/com.godaddy.gdm.smartline SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.kau.mykau SUCCESS
# http://localhost:3000/api/apps/com.coparenter.coparenterandroid SUCCESS
# http://localhost:3000/api/apps/com.notdoppler.earntodie2 SUCCESS
# http://localhost:3000/api/apps/com.macrovideo.v380pro SUCCESS
# Total number of apps 6694
# Collected app ids 12
# http://localhost:3000/api/apps/com.xyzmo.signature.standalone SUCCESS
# http://localhost:3000/api/apps/org.buddyapps.mingle SUCCESS
# http://localhost:3000/api/apps/com.pianomarshmello.pianotilesdj SUCCESS
# http://localhost:3000/api/apps/com.microsoft.office.powerpoint SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/jp.gr.java_conf.siranet.sunshine SUCCESS
# http://localhost:3000/api/apps/com.aa.genius.superhero.chilli.mania SUCCESS
# http://localhost:3000/api/apps/com.nbcu.tve.syfy SUCCESS
# http://localhost:3000/api/apps/com.vd.idiomphrases SUCCESS
# http://localhost:3000/api/apps/com.williamking.whattheforecast SUCCESS
# http://localhost:3000/api/apps/com.sport24.android SUCCESS
# Total number of apps 6910
# Collected app ids 13
# http://localhost:3000/api/apps/com.ketchapp.dunkhoop SUCCESS
# http://localhost:3000/api/apps/com.nexttechgamesstudio.meow.cats.sandbox.number.coloring.book.color.by.number.pixel.art SUCCESS
# http://localhost:3000/api/apps/edu.ou.cimms.mping SUCCESS
# http://localhost:3000/api/apps/com.ring.neighborhoods SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.google.android.contacts SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.GoFundMe.GoFundMe SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/net.doo.snap SUCCESS
# http://localhost:3000/api/apps/com.ombiel.campusm.myUON SUCCESS
# http://localhost:3000/api/apps/com.mosalingua.enfree SUCCESS
# http://localhost:3000/api/apps/com.droidhen.defender3 SUCCESS
# Total number of apps 7195
# Collected app ids 16
# http://localhost:3000/api/apps/com.wdaf.android.weather SUCCESS
# http://localhost:3000/api/apps/com.instacart.client.ralphs SUCCESS
# http://localhost:3000/api/apps/in.sweatco.app SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.sentry.pl.customer.dairylandapp SUCCESS
# http://localhost:3000/api/apps/com.fortskin.battle.skin.maker.generator.royale.creator SUCCESS
# http://localhost:3000/api/apps/com.gramgames.mergedragons SUCCESS
# http://localhost:3000/api/apps/com.genewarrior.sunlocator.lite SUCCESS
# http://localhost:3000/api/apps/com.quranmp3.quranmp3offline SUCCESS
# http://localhost:3000/api/apps/com.happybaby.app SUCCESS
# http://localhost:3000/api/apps/com.daily.zodiac.signs.horoscope.palmistry SUCCESS
# Total number of apps 7397
# Collected app ids 17
# http://localhost:3000/api/apps/com.custom.goescape SUCCESS
# http://localhost:3000/api/apps/org.jw.jwevent SUCCESS
# http://localhost:3000/api/apps/com.flashcardinc.teas2 SUCCESS
# http://localhost:3000/api/apps/number.color.sandbox SUCCESS
# http://localhost:3000/api/apps/net.relaxio.babysleep SUCCESS
# http://localhost:3000/api/apps/com.foxsports.videogo SUCCESS
# http://localhost:3000/api/apps/air.au.com.minimega.bonza SUCCESS
# http://localhost:3000/api/apps/com.primaapps.voicerecorder SUCCESS
# http://localhost:3000/api/apps/com.ember.wordz0 SUCCESS
# http://localhost:3000/api/apps/com.jetradar SUCCESS
# Total number of apps 7534
# Collected app ids 17
# http://localhost:3000/api/apps/betrugue.inc.FondosDePantallaFBR SUCCESS
# http://localhost:3000/api/apps/com.expedia.bookings SUCCESS
# http://localhost:3000/api/apps/br.com.aleluiah_apps.bibliasagrada.almeida SUCCESS
# http://localhost:3000/api/apps/com.bitmango.go.bubblepop SUCCESS
# http://localhost:3000/api/apps/com.showmax.app SUCCESS
# http://localhost:3000/api/apps/com.olo.dairyqueen.production SUCCESS
# http://localhost:3000/api/apps/air.com.ironhorse.idlesword2mobile SUCCESS
# http://localhost:3000/api/apps/com.yiyou.game.newtricky SUCCESS
# http://localhost:3000/api/apps/com.nextradiotv.rmcsport SUCCESS
# http://localhost:3000/api/apps/com.medoli.astrohoroscope SUCCESS
# Total number of apps 7784
# Collected app ids 17
# http://localhost:3000/api/apps/com.hltcorp.anaspecialtycertifications SUCCESS
# http://localhost:3000/api/apps/com.gmail.troylyndon.PlayTrivia SUCCESS
# http://localhost:3000/api/apps/mobi.gameguru.racingfevermoto SUCCESS
# http://localhost:3000/api/apps/com.ketchapp.watercave SUCCESS
# http://localhost:3000/api/apps/com.agoda.mobile.consumer SUCCESS
# http://localhost:3000/api/apps/pine.game.skydancer SUCCESS
# http://localhost:3000/api/apps/com.tokyocoldstudio.PrincessWitchStory SUCCESS
# http://localhost:3000/api/apps/com.mobisystems.msdict.embedded.wireless.oxford.idioms SUCCESS
# http://localhost:3000/api/apps/com.diamondlife.slots.vegas.free SUCCESS
# http://localhost:3000/api/apps/com.pronosoft.pronofoot1N2 SUCCESS
# Total number of apps 7980
# Collected app ids 17
# http://localhost:3000/api/apps/com.domobile.messenger SUCCESS
# http://localhost:3000/api/apps/com.Kitchen.coloringbookms SUCCESS
# http://localhost:3000/api/apps/com.crowdcomms.eaes2018 SUCCESS
# http://localhost:3000/api/apps/com.bg.kungfu.ninjafighting.shadowfight.ninjaassassin SUCCESS
# http://localhost:3000/api/apps/com.ouest.france SUCCESS
# http://localhost:3000/api/apps/com.fungames.flightpilot SUCCESS
# http://localhost:3000/api/apps/com.eRepublikLabs.AgeOfLords SUCCESS
# http://localhost:3000/api/apps/com.funeasylearn.phrasebook.english SUCCESS
# http://localhost:3000/api/apps/com.kcbd.android.weather SUCCESS
# http://localhost:3000/api/apps/com.audubon.mobile.android SUCCESS
# Total number of apps 8189
# Collected app ids 17
# http://localhost:3000/api/apps/com.daerisoft.punch SUCCESS
# http://localhost:3000/api/apps/champions.empire.bubble SUCCESS
# http://localhost:3000/api/apps/net.flixster.android SUCCESS
# http://localhost:3000/api/apps/com.geishatokyo.trafficrun SUCCESS
# http://localhost:3000/api/apps/com.mobisystems.msdict.embedded.wireless.oxford.dictionaryofenglish SUCCESS
# http://localhost:3000/api/apps/galaxys9ringtones.ringtonesfors9.notifications SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.archanaskitchen.app SUCCESS
# http://localhost:3000/api/apps/com.sinyee.babybus.bird SUCCESS
# http://localhost:3000/api/apps/com.cheatsforgta5.cheatsforgta5 SUCCESS
# http://localhost:3000/api/apps/com.tencent.ig SUCCESS
# Total number of apps 8388
# Collected app ids 18
# http://localhost:3000/api/apps/com.nexttechgamesstudio.cars.sandbox.number.coloring.book.color.by.number.pixel.art SUCCESS
# http://localhost:3000/api/apps/com.appybuilder.danijedy.Tj_Util_Reuniones_All_in_one SUCCESS
# http://localhost:3000/api/apps/com.ariesapp.elisi.elisiwrapper SUCCESS
# http://localhost:3000/api/apps/starwind.ocarina SUCCESS
# http://localhost:3000/api/apps/com.nascar.nascarmobile SUCCESS
# http://localhost:3000/api/apps/com.crackerbarrel.app SUCCESS
# http://localhost:3000/api/apps/com.coco.massage SUCCESS
# http://localhost:3000/api/apps/com.autaz.pregai SUCCESS
# http://localhost:3000/api/apps/com.kunkunnapps.screenlock SUCCESS
# http://localhost:3000/api/apps/com.optum.mobile.OptumBank SUCCESS
# Total number of apps 8565
# Collected app ids 18
# http://localhost:3000/api/apps/com.gtactiongames.bikestuntracer SUCCESS
# http://localhost:3000/api/apps/com.weathercreative.wildlifeweather SUCCESS
# http://localhost:3000/api/apps/com.timeanddate.countdown SUCCESS
# http://localhost:3000/api/apps/com.uefa.ucl SUCCESS
# http://localhost:3000/api/apps/com.linmedia.newstouch.ksnw SUCCESS
# http://localhost:3000/api/apps/com.skiily.www.phonereveal SUCCESS
# http://localhost:3000/api/apps/com.moneylion SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.nerudapps.communismbutton SUCCESS
# http://localhost:3000/api/apps/com.photolab.sktech SUCCESS
# http://localhost:3000/api/apps/com.fatmaprn SUCCESS
# Total number of apps 8793
# Collected app ids 19
# http://localhost:3000/api/apps/com.scopely.wheeloffortune SUCCESS
# http://localhost:3000/api/apps/bubble.shooter.pop SUCCESS
# http://localhost:3000/api/apps/com.olo.bostonmarket SUCCESS
# http://localhost:3000/api/apps/com.atistudios.italk.zh SUCCESS
# http://localhost:3000/api/apps/sleepsounds.relaxandsleep.whitenoise SUCCESS
# http://localhost:3000/api/apps/com.dripgrind.mindly SUCCESS
# http://localhost:3000/api/apps/via.rider SUCCESS
# http://localhost:3000/api/apps/dun.button.dramatic.dun.chipmunk SUCCESS
# http://localhost:3000/api/apps/com.megameme.memesoundboard SUCCESS
# http://localhost:3000/api/apps/com.superluckycasino.epicjackpot.slots.vegas.android.free SUCCESS
# Total number of apps 8977
# Collected app ids 19
# http://localhost:3000/api/apps/com.nexttechgamesstudio.cars.kids.coloring.book.pages.color.by.number SUCCESS
# http://localhost:3000/api/apps/com.randomvideochat.omegle SUCCESS
# http://localhost:3000/api/apps/com.levraihoroscope SUCCESS
# http://localhost:3000/api/apps/dev.poketype SUCCESS
# http://localhost:3000/api/apps/com.skimble.workouts SUCCESS
# http://localhost:3000/api/apps/com.hpv.audiorecorder SUCCESS
# http://localhost:3000/api/apps/com.wwmt.android.weather SUCCESS
# http://localhost:3000/api/apps/com.mosalingua.frfree SUCCESS
# http://localhost:3000/api/apps/com.vvse.lunasolcal SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev519044.app754376 SUCCESS
# Total number of apps 9151
# Collected app ids 19
# http://localhost:3000/api/apps/com.coloring.kids SUCCESS
# http://localhost:3000/api/apps/com.amazon.avod.thirdpartyclient SUCCESS
# http://localhost:3000/api/apps/rescue.bubble.bird SUCCESS
# http://localhost:3000/api/apps/com.skibapps.wiretapremoval SUCCESS
# http://localhost:3000/api/apps/org.pbskids.gamesapp SUCCESS
# http://localhost:3000/api/apps/net.wordbit.enfr SUCCESS
# http://localhost:3000/api/apps/net.sourceforge.opencamera SUCCESS
# http://localhost:3000/api/apps/com.mobilerealtyapps.crmls SUCCESS
# http://localhost:3000/api/apps/talkenglish.com.standard SUCCESS
# http://localhost:3000/api/apps/com.famousringtones2017.topringtones2017.funnyringtones2018 SUCCESS
# Total number of apps 9445
# Collected app ids 19
# http://localhost:3000/api/apps/com.kabam.marvelbattle SUCCESS
# http://localhost:3000/api/apps/com.rovio.Nibblers SUCCESS
# http://localhost:3000/api/apps/com.netspend.mobileapp.westernunion SUCCESS
# http://localhost:3000/api/apps/com.poshmark.app SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.microsoft.emmx SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.hulu.plus SUCCESS
# http://localhost:3000/api/apps/com.google.android.calendar SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.bitmango.go.bubblepop SUCCESS
# http://localhost:3000/api/apps/com.jndwork.weatherradar.live.alerts SUCCESS
# http://localhost:3000/api/apps/com.google.android.stardroid SUCCESS
# Total number of apps 9614
# Collected app ids 22
# http://localhost:3000/api/apps/com.colorjoy.learn.to.draw.glow.comics SUCCESS
# http://localhost:3000/api/apps/com.bsitapps.weddingcountdowntimer SUCCESS
# http://localhost:3000/api/apps/com.rushcard.android SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.meme.soundboard.custom.mlg.vennn SUCCESS
# http://localhost:3000/api/apps/co.windyapp.android SUCCESS
# http://localhost:3000/api/apps/com.deliveryclub SUCCESS
# http://localhost:3000/api/apps/com.carmax.carmax SUCCESS
# http://localhost:3000/api/apps/com.lemontart.flying.robot.car.transformation SUCCESS
# http://localhost:3000/api/apps/com.wdaf.android.weather SUCCESS
# http://localhost:3000/api/apps/com.cocoplay.cocobunny SUCCESS
# Total number of apps 9771
# Collected app ids 23
# http://localhost:3000/api/apps/com.ndm.learnchinesewriting SUCCESS
# http://localhost:3000/api/apps/com.cbs.etlive SUCCESS
# http://localhost:3000/api/apps/bubbles.superme SUCCESS
# http://localhost:3000/api/apps/com.streema.simpleradio SUCCESS
# http://localhost:3000/api/apps/com.concretesoftware.rapala SUCCESS
# http://localhost:3000/api/apps/com.pmg.speed SUCCESS
# http://localhost:3000/api/apps/com.deemedyainc.dx2 SUCCESS
# http://localhost:3000/api/apps/com.iposedon.bricksbreakerballs SUCCESS
# http://localhost:3000/api/apps/com.ohmgames.paperplane SUCCESS
# http://localhost:3000/api/apps/com.supercell.clashofclans SUCCESS
# Total number of apps 9921
# Collected app ids 23
# http://localhost:3000/api/apps/com.netspend.mobileapp.transact711 SUCCESS
# http://localhost:3000/api/apps/bookaz.storiesbook.williamshakespeare SUCCESS
# http://localhost:3000/api/apps/net.malingo.wortsuchesprachen.android.wordsearch SUCCESS
# http://localhost:3000/api/apps/com.app.zssrguxnyuvwqvktkbpomliqfddlpginxerajtyb SUCCESS
# http://localhost:3000/api/apps/com.vistrav.whiteboard SUCCESS
# http://localhost:3000/api/apps/com.bg.citybus.coachsimulator.passengerdriving.sim2019 SUCCESS
# http://localhost:3000/api/apps/com.code.bluegeny.myhomeview SUCCESS
# http://localhost:3000/api/apps/com.mta.countdown SUCCESS
# http://localhost:3000/api/apps/org.FanMadeCreation.EmoteDance SUCCESS
# http://localhost:3000/api/apps/com.flashkeyboard.leds SUCCESS
# Total number of apps 10129
# Collected app ids 23
# http://localhost:3000/api/apps/com.sofarsogood.incredibox SUCCESS
# http://localhost:3000/api/apps/com.premiereradio.android.rushlimbaugh SUCCESS
# http://localhost:3000/api/apps/com.bilkon.pinkpiano SUCCESS
# http://localhost:3000/api/apps/com.withbuddies.dice.free SUCCESS
# http://localhost:3000/api/apps/com.cosmosforge.photogallery SUCCESS
# http://localhost:3000/api/apps/com.no.draw.color.by.number SUCCESS
# http://localhost:3000/api/apps/com.tapblaze.homecraft SUCCESS
# http://localhost:3000/api/apps/com.desenvdroid.musicboxtosleep SUCCESS
# http://localhost:3000/api/apps/com.loto.france.fdj SUCCESS
# http://localhost:3000/api/apps/ar.com.develup.pasapalabra SUCCESS
# Total number of apps 10323
# Collected app ids 23
# http://localhost:3000/api/apps/com.taiyouxi.jwsus SUCCESS
# http://localhost:3000/api/apps/dofudo.resonanzrechner SUCCESS
# http://localhost:3000/api/apps/com.billiards.city.pool.nation.club SUCCESS
# http://localhost:3000/api/apps/com.flightaware.android.liveFlightTracker SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.radiofmam.freebroadcasters SUCCESS
# http://localhost:3000/api/apps/com.BestGames.PoliceDriverSimulator SUCCESS
# http://localhost:3000/api/apps/com.gamesarena.monster.truck.crash.stunts SUCCESS
# http://localhost:3000/api/apps/com.netease.mrzhna SUCCESS
# http://localhost:3000/api/apps/com.buildfortheweb.tasks SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/es.aroundpixels.hskdictionarylite SUCCESS
# Total number of apps 10454
# Collected app ids 25
# http://localhost:3000/api/apps/com.nexttechgamesstudio.valentine.glitter.color.by.number.sandbox.coloring.adult.coloring.book SUCCESS
# http://localhost:3000/api/apps/com.fstop.photo SUCCESS
# http://localhost:3000/api/apps/com.xacte.eventapp.indymini SUCCESS
# http://localhost:3000/api/apps/com.busuu.android.de SUCCESS
# http://localhost:3000/api/apps/fr.airweb.psg SUCCESS
# http://localhost:3000/api/apps/com.lps.contactremover SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.jailbase.mobile_app SUCCESS
# http://localhost:3000/api/apps/dk.tactile.discoducks SUCCESS
# http://localhost:3000/api/apps/com.funeasylearn.german SUCCESS
# http://localhost:3000/api/apps/com.LM.KBS SUCCESS
# Total number of apps 10664
# Collected app ids 26
# http://localhost:3000/api/apps/io.microwork.tasks SUCCESS
# http://localhost:3000/api/apps/com.indigokids.mimdoctor SUCCESS
# http://localhost:3000/api/apps/com.speedygtgames.motorcycleinfinitydrivingsimulation SUCCESS
# http://localhost:3000/api/apps/com.dailyhoroscopes.net SUCCESS
# http://localhost:3000/api/apps/com.hitbytes.minidiarynotes SUCCESS
# http://localhost:3000/api/apps/com.touringplans.uorlines.android SUCCESS
# http://localhost:3000/api/apps/br.com.ctncardoso.ctncar SUCCESS
# http://localhost:3000/api/apps/com.gotv.nflgamecenter.us.lite SUCCESS
# http://localhost:3000/api/apps/com.tonyjet.EnglishViaY SUCCESS
# http://localhost:3000/api/apps/com.game.bubble.action SUCCESS
# Total number of apps 10845
# Collected app ids 26
# http://localhost:3000/api/apps/com.atistudios.ispeak.en SUCCESS
# http://localhost:3000/api/apps/com.coco2games.glorysword SUCCESS
# http://localhost:3000/api/apps/com.nextgames.android.ourworld SUCCESS
# http://localhost:3000/api/apps/com.frenzygames.motorbike.beach.stunts.master SUCCESS
# http://localhost:3000/api/apps/shooter.spinner SUCCESS
# http://localhost:3000/api/apps/com.digidust.elokence.akinator.freemium SUCCESS
# http://localhost:3000/api/apps/haircolour.hairstyle.photoeditor.haircolorchanger SUCCESS
# http://localhost:3000/api/apps/com.lift.taxi SUCCESS
# http://localhost:3000/api/apps/ah.creativecodeapps.tiempo SUCCESS
# http://localhost:3000/api/apps/com.nomadeducation.nomadeducation SUCCESS
# Total number of apps 10955
# Collected app ids 26
# http://localhost:3000/api/apps/com.qurandownload.downloadalquran SUCCESS
# http://localhost:3000/api/apps/com.rubenmayayo.timecounter SUCCESS
# http://localhost:3000/api/apps/com.PepiPlay.PepiHospital SUCCESS
# http://localhost:3000/api/apps/com.tocaboca.tocakitchen SUCCESS
# http://localhost:3000/api/apps/com.smile.jewel.google SUCCESS
# http://localhost:3000/api/apps/com.joyo.classicsolitaire SUCCESS
# http://localhost:3000/api/apps/com.upopa.hopelessheroes SUCCESS
# http://localhost:3000/api/apps/com.nanosoft.holy.quran SUCCESS
# http://localhost:3000/api/apps/com.hyperfame_police.car.racing2019 SUCCESS
# http://localhost:3000/api/apps/com.chinese.keyboard.for.android SUCCESS
# Total number of apps 11145
# Collected app ids 26
# http://localhost:3000/api/apps/com.yinzcam.lfp.spo SUCCESS
# http://localhost:3000/api/apps/com.dg.turbonuke.bingo.quest.summer.garden SUCCESS
# http://localhost:3000/api/apps/com.webshinobis.actlikeaman SUCCESS
# http://localhost:3000/api/apps/com.sesameworkshop.alphabetkitchen.play SUCCESS
# http://localhost:3000/api/apps/com.live.radar.accu.wea.widget.app SUCCESS
# http://localhost:3000/api/apps/com.dpcorp.whyyoualwayslying SUCCESS
# http://localhost:3000/api/apps/com.euronews.express SUCCESS
# http://localhost:3000/api/apps/com.tpmsnetwork.tpmspartfinder SUCCESS
# http://localhost:3000/api/apps/com.trulia.android.rentals SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.magiplay.solitaire.tripeaks.farm.harvest SUCCESS
# Total number of apps 11356
# Collected app ids 27
# http://localhost:3000/api/apps/com.rachelle.bbqright SUCCESS
# http://localhost:3000/api/apps/com.carvana.carvana SUCCESS
# http://localhost:3000/api/apps/com.dailyforecast.weather SUCCESS
# http://localhost:3000/api/apps/com.bravolol.bravolang.englishchinesecdictionary SUCCESS
# http://localhost:3000/api/apps/com.lock_screen.zedge.wallpaper.maker.themes SUCCESS
# http://localhost:3000/api/apps/com.sportforecasts.perfectbet SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev27966.app209539 SUCCESS
# http://localhost:3000/api/apps/com.activision.boz SUCCESS
# http://localhost:3000/api/apps/sa.muthiq.app SUCCESS
# http://localhost:3000/api/apps/com.t440.keypad SUCCESS
# Total number of apps 11610
# Collected app ids 27
# http://localhost:3000/api/apps/com.postmates.android SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/sk.forbis.messenger SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/uni.unseengallery.ke SUCCESS
# http://localhost:3000/api/apps/com.colouringbooks.eastercoloringpages SUCCESS
# http://localhost:3000/api/apps/net.wargaming.wows.blitz SUCCESS
# http://localhost:3000/api/apps/com.desenvemax.lullaby SUCCESS
# http://localhost:3000/api/apps/com.pearmobile.apps.holybible SUCCESS
# http://localhost:3000/api/apps/com.abodo.ABODO SUCCESS
# http://localhost:3000/api/apps/com.smartexpenditure SUCCESS
# http://localhost:3000/api/apps/com.readercompany.pdf.reader SUCCESS
# Total number of apps 11774
# Collected app ids 29
# http://localhost:3000/api/apps/com.disney.djappisodesmmchrr_goo SUCCESS
# http://localhost:3000/api/apps/net.konos.mbtatracker SUCCESS
# http://localhost:3000/api/apps/de.nextsol.deeparteffects.app SUCCESS
# http://localhost:3000/api/apps/com.kcnc.android.weather SUCCESS
# http://localhost:3000/api/apps/com.livelike.vr.fsgo.cardboard SUCCESS
# http://localhost:3000/api/apps/com.tapclap.spellblast SUCCESS
# http://localhost:3000/api/apps/com.live.wallpaper.free.background.phone.launcher.theme.gravity.water.astronaut SUCCESS
# http://localhost:3000/api/apps/com.pavahainc.effectsartpro SUCCESS
# http://localhost:3000/api/apps/com.vitotechnology.StarWalk2 SUCCESS
# http://localhost:3000/api/apps/com.textmeinc.textme3 SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# Total number of apps 11940
# Collected app ids 30
# http://localhost:3000/api/apps/com.sevenlogics.weddingplanner SUCCESS
# http://localhost:3000/api/apps/com.ulyapps.glassplayformadden17 SUCCESS
# http://localhost:3000/api/apps/com.olo.dairyqueen.production SUCCESS
# http://localhost:3000/api/apps/dk.tactile.discoducks SUCCESS
# http://localhost:3000/api/apps/com.appgeneration.itunerpro SUCCESS
# http://localhost:3000/api/apps/com.fullcontact.ledene SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.autopten.cheapcarsforsale SUCCESS
# http://localhost:3000/api/apps/com.rooh.learn_french SUCCESS
# http://localhost:3000/api/apps/com.broniboy.client SUCCESS
# http://localhost:3000/api/apps/biz.webcreation.boulevoyance SUCCESS
# Total number of apps 12119
# Collected app ids 31
# http://localhost:3000/api/apps/com.Lutalica.StudyAmbience SUCCESS
# http://localhost:3000/api/apps/com.outfit7.tomsbubbles SUCCESS
# http://localhost:3000/api/apps/com.fujifilm.wifi SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/exsate.goldenhour SUCCESS
# http://localhost:3000/api/apps/com.diablins.android.leagueofquiz SUCCESS
# http://localhost:3000/api/apps/com.clockwatchers.oceansolitaire SUCCESS
# http://localhost:3000/api/apps/com.ngajiapp.murottal.alquran.mishary.rasyid.alafasy.quran.mp3.offline SUCCESS
# http://localhost:3000/api/apps/com.ejr.mctstracker SUCCESS
# http://localhost:3000/api/apps/org.pbskids.danieltigerforparents SUCCESS
# http://localhost:3000/api/apps/com.bigheadtechies.diary SUCCESS
# Total number of apps 12273
# Collected app ids 32
# http://localhost:3000/api/apps/com.firstbank.mobilebanking SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.elegantsolutions.media.videoplatform.baby SUCCESS
# http://localhost:3000/api/apps/com.channel.weather.forecast SUCCESS
# http://localhost:3000/api/apps/easy.sudoku.puzzle.solver.free SUCCESS
# http://localhost:3000/api/apps/com.jasonshah.ctatracker SUCCESS
# http://localhost:3000/api/apps/com.fueled.afterlight SUCCESS
# http://localhost:3000/api/apps/com.edatalia.signply SUCCESS
# http://localhost:3000/api/apps/video.player.videoplayer SUCCESS
# http://localhost:3000/api/apps/com.sinyee.babybus.coffee SUCCESS
# http://localhost:3000/api/apps/com.bistudio.minidayz SUCCESS
# Total number of apps 12509
# Collected app ids 33
# http://localhost:3000/api/apps/com.upopa.hopeless2 SUCCESS
# http://localhost:3000/api/apps/com.nexttechgamesstudio.coloringsandbox SUCCESS
# http://localhost:3000/api/apps/com.servico.relatorios SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/org.pbskids.jurassicjr SUCCESS
# http://localhost:3000/api/apps/com.freakingfreegames.anaconda.snake.sim SUCCESS
# http://localhost:3000/api/apps/com.samsung.android.videolist SUCCESS
# http://localhost:3000/api/apps/com.elsayad.footballfixturespro SUCCESS
# http://localhost:3000/api/apps/com.sinyee.babybus.adventure SUCCESS
# http://localhost:3000/api/apps/nl.thijswijnen.r6stickerpack SUCCESS
# http://localhost:3000/api/apps/com.jdpapps.escoba SUCCESS
# Total number of apps 12634
# Collected app ids 34
# http://localhost:3000/api/apps/com.takescoop.android.scoopandroid SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.tribeplay.pandapet SUCCESS
# http://localhost:3000/api/apps/com.seaworld.mobile SUCCESS
# http://localhost:3000/api/apps/com.impossible.crazy.car.driving.stunts SUCCESS
# http://localhost:3000/api/apps/com.motionlab.darts2 SUCCESS
# http://localhost:3000/api/apps/cn.wps.moffice_eng SUCCESS
# http://localhost:3000/api/apps/com.nexttechgamesstudio.meow.cats.sandbox.number.coloring.book.color.by.number.pixel.art SUCCESS
# http://localhost:3000/api/apps/com.allfootball.barcelona.news SUCCESS
# http://localhost:3000/api/apps/com.cocoplay.fashion.style SUCCESS
# http://localhost:3000/api/apps/com.hebbarskitchen.android SUCCESS
# Total number of apps 12743
# Collected app ids 35
# http://localhost:3000/api/apps/br.biblia SUCCESS
# http://localhost:3000/api/apps/com.meisterlabs.meistertask.native SUCCESS
# http://localhost:3000/api/apps/com.futureplay.minecraft SUCCESS
# http://localhost:3000/api/apps/com.taplane.logoquizm SUCCESS
# http://localhost:3000/api/apps/air.com.tutotoons.app.powergirlssupercity.free SUCCESS
# http://localhost:3000/api/apps/com.samsung.android.lool SUCCESS
# http://localhost:3000/api/apps/com.Infinity.huskypuppies SUCCESS
# http://localhost:3000/api/apps/com.alexandriabookseng.ebook032 SUCCESS
# http://localhost:3000/api/apps/com.ojassoft.Horoscope2012 SUCCESS
# http://localhost:3000/api/apps/com.kunalapps.kidspoems SUCCESS
# Total number of apps 12928
# Collected app ids 35
# http://localhost:3000/api/apps/com.garboz.dope SUCCESS
# http://localhost:3000/api/apps/com.himoment.app SUCCESS
# http://localhost:3000/api/apps/com.trex.lovegg SUCCESS
# http://localhost:3000/api/apps/com.alinma.openaccount.android SUCCESS
# http://localhost:3000/api/apps/com.thesecret.rhonda.book SUCCESS
# http://localhost:3000/api/apps/com.nobluffdating.com.app SUCCESS
# http://localhost:3000/api/apps/com.timuzsolutions.rollercoastersimulator SUCCESS
# http://localhost:3000/api/apps/com.gamesentity.halloween.zombie.dead.target2 SUCCESS
# http://localhost:3000/api/apps/com.tutotoons.app.hannahsfashionworld.free SUCCESS
# http://localhost:3000/api/apps/com.vn.learn.english.grammar.rule SUCCESS
# Total number of apps 13123
# Collected app ids 35
# http://localhost:3000/api/apps/com.vk.podcast.topics.talkright SUCCESS
# http://localhost:3000/api/apps/com.ketchapp.stairs SUCCESS
# http://localhost:3000/api/apps/com.yodo1.crossyroad SUCCESS
# http://localhost:3000/api/apps/com.photo.gallery SUCCESS
# http://localhost:3000/api/apps/com.atentertainment.learningenglishbyparagraph SUCCESS
# http://localhost:3000/api/apps/com.ztnstudio.notepad SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.trimble.fsm.fieldmaster SUCCESS
# http://localhost:3000/api/apps/com.b8ak.b8akapp SUCCESS
# http://localhost:3000/api/apps/com.service.reports SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.andromo.dev628657.app616871 SUCCESS
# Total number of apps 13324
# Collected app ids 37
# http://localhost:3000/api/apps/com.real.street.thug.robber.city.chase.gangster.mafia SUCCESS
# http://localhost:3000/api/apps/com.cootek.smartinputv5.skin.keyboard_theme_pink_diamond_princess SUCCESS
# http://localhost:3000/api/apps/com.seeking.lianxi_pinying SUCCESS
# http://localhost:3000/api/apps/habibet.baba.mama SUCCESS
# http://localhost:3000/api/apps/com.odnklassac.weatherdarks SUCCESS
# http://localhost:3000/api/apps/com.bit.mahjong2019 SUCCESS
# http://localhost:3000/api/apps/com.aussieman.robot.ring.fight SUCCESS
# http://localhost:3000/api/apps/com.xacte.eventapp.elhm SUCCESS
# http://localhost:3000/api/apps/com.heartfull.forms SUCCESS
# http://localhost:3000/api/apps/com.vons.shop SUCCESS
# Total number of apps 13485
# Collected app ids 37
# http://localhost:3000/api/apps/net.bible.android.activity SUCCESS
# http://localhost:3000/api/apps/com.ninemgames.tennis2.google SUCCESS
# http://localhost:3000/api/apps/slo.lesnik SUCCESS
# http://localhost:3000/api/apps/com.wordloco.wordchallenge SUCCESS
# http://localhost:3000/api/apps/com.topfreegames.bikeracefreeworld SUCCESS
# http://localhost:3000/api/apps/com.lemontart.demolition.derby.car.racing.stunts SUCCESS
# http://localhost:3000/api/apps/com.roblox.cookie.dolls.swirl.surprise.videos.game SUCCESS
# http://localhost:3000/api/apps/info.ytc.hchoice SUCCESS
# http://localhost:3000/api/apps/com.kooup.kooup SUCCESS
# http://localhost:3000/api/apps/com.moodle.moodlemobile SUCCESS
# Total number of apps 13614
# Collected app ids 37
# http://localhost:3000/api/apps/com.bibliadeestudo SUCCESS
# http://localhost:3000/api/apps/com.orbit.orbitsmarthome SUCCESS
# http://localhost:3000/api/apps/com.whimmusic2018.android SUCCESS
# http://localhost:3000/api/apps/com.brunoschalch.timeuntil SUCCESS
# http://localhost:3000/api/apps/com.marco.soundboard.jojosoundboard SUCCESS
# http://localhost:3000/api/apps/jp.sn.alonesoft.simplehandwritingmemo SUCCESS
# http://localhost:3000/api/apps/com.taplane.emojisquiz SUCCESS
# http://localhost:3000/api/apps/com.mbfs.mymbfsus.android.phone SUCCESS
# http://localhost:3000/api/apps/nelt.descargar SUCCESS
# http://localhost:3000/api/apps/es.mediaset.gh14 SUCCESS
# Total number of apps 13793
# Collected app ids 37
# http://localhost:3000/api/apps/com.grand.casino.robbery.game SUCCESS
# http://localhost:3000/api/apps/com.talkenglish.englishvocab SUCCESS
# http://localhost:3000/api/apps/free.fun.card.game.solitaire.klondike.freecell.uno SUCCESS
# http://localhost:3000/api/apps/com.moniday.ear.spy.pro SUCCESS
# http://localhost:3000/api/apps/com.offroad.jeep.driving.simulator SUCCESS
# http://localhost:3000/api/apps/com.hasan.ahmad.EnglishTense SUCCESS
# http://localhost:3000/api/apps/com.jpma.EBTShopper SUCCESS
# http://localhost:3000/api/apps/bubble.ball.eight SUCCESS
# http://localhost:3000/api/apps/ru.ykt.eda SUCCESS
# http://localhost:3000/api/apps/com.cardgame.solitaire.full SUCCESS
# Total number of apps 13888
# Collected app ids 37
# http://localhost:3000/api/apps/com.applegends.ringtones.free_songs SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.vasiliyzhemchugov.horoscope SUCCESS
# http://localhost:3000/api/apps/com.tester.arejay.tester1 SUCCESS
# http://localhost:3000/api/apps/com.game.wifiwebcam SUCCESS
# http://localhost:3000/api/apps/com.ndmdict.trungviet SUCCESS
# http://localhost:3000/api/apps/com.signal.android SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.pixeleyes.quiz.ged.free SUCCESS
# http://localhost:3000/api/apps/com.gokids.bphone1 SUCCESS
# http://localhost:3000/api/apps/com.superbox.aos.sweetfruit SUCCESS
# http://localhost:3000/api/apps/com.game.motorsportmanager SUCCESS
# Total number of apps 14069
# Collected app ids 39
# http://localhost:3000/api/apps/com.huckleberry_labs.app SUCCESS
# http://localhost:3000/api/apps/com.wobblemonkey.speedygram SUCCESS
# http://localhost:3000/api/apps/com.berniiiiiiii.palabrascruzadas SUCCESS
# http://localhost:3000/api/apps/com.ape.camera.docscan SUCCESS
# http://localhost:3000/api/apps/com.picsart.animate SUCCESS
# http://localhost:3000/api/apps/com.flaregames.zgs SUCCESS
# http://localhost:3000/api/apps/com.selfhealing.candle11 SUCCESS
# http://localhost:3000/api/apps/com.latest_thoughts SUCCESS
# http://localhost:3000/api/apps/com.babbel.mobile.android.eng SUCCESS
# http://localhost:3000/api/apps/com.mindtwisted.kanjistudy SUCCESS
# Total number of apps 14225
# Collected app ids 39
# http://localhost:3000/api/apps/com.cube.arc.hfa SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.hostelworld.app SUCCESS
# http://localhost:3000/api/apps/com.muzmatch.muzmatchapp SUCCESS
# http://localhost:3000/api/apps/com.nest.android SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.bubbleshoot.colorbubble.free SUCCESS
# http://localhost:3000/api/apps/com.graytv.android.kxiinews SUCCESS
# http://localhost:3000/api/apps/com.circlegate.tt.ezride.dallas SUCCESS
# http://localhost:3000/api/apps/ru.mail.games.android.JungleHeat SUCCESS
# http://localhost:3000/api/apps/cc.forestapp SUCCESS
# http://localhost:3000/api/apps/baltibabaa.hamoudaft.jamessilver.com.hamoudaftbalti_baba SUCCESS
# Total number of apps 14409
# Collected app ids 41
# http://localhost:3000/api/apps/com.bhai4you.bullmux SUCCESS
# http://localhost:3000/api/apps/com.vd.onewordsubstitution SUCCESS
# http://localhost:3000/api/apps/com.mm.android.direct.gdmssphone SUCCESS
# http://localhost:3000/api/apps/com.devcom.english.grammarandtestnewver SUCCESS
# http://localhost:3000/api/apps/taurus.horoscope.daily.free SUCCESS
# http://localhost:3000/api/apps/hathoute.com.wallpapers SUCCESS
# http://localhost:3000/api/apps/com.Gseeds.JekyllAndHyde SUCCESS
# http://localhost:3000/api/apps/com.Beauty.coloringbookms SUCCESS
# http://localhost:3000/api/apps/com.startwithwhy SUCCESS
# http://localhost:3000/api/apps/pop.ocean SUCCESS
# Total number of apps 14599
# Collected app ids 41
# http://localhost:3000/api/apps/com.wvue.android.weather SUCCESS
# http://localhost:3000/api/apps/com.kthv.android.weather SUCCESS
# http://localhost:3000/api/apps/videoplayer.videoplayerhd.fullhdvideoplayer SUCCESS
# http://localhost:3000/api/apps/com.bubadu.bubburestaurant SUCCESS
# http://localhost:3000/api/apps/com.ea.gp.pvzheroes SUCCESS
# http://localhost:3000/api/apps/com.coco.cadmv SUCCESS
# http://localhost:3000/api/apps/com.keyboardstyle.easychinese.keyboard SUCCESS
# http://localhost:3000/api/apps/com.duplicatefilefixer SUCCESS
# http://localhost:3000/api/apps/com.radiosonline.radiofmitalia SUCCESS
# http://localhost:3000/api/apps/com.hollar.android SUCCESS
# Total number of apps 14780
# Collected app ids 41
# http://localhost:3000/api/apps/com.cb.slimemaking SUCCESS
# http://localhost:3000/api/apps/com.yinzcam.nfl.seahawks SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.qvc SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.intuit.quickbooks SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/ah.creativecodeapps.tiempo SUCCESS
# http://localhost:3000/api/apps/softcompany.johncmaxwell.teaching SUCCESS
# http://localhost:3000/api/apps/com.blackwhitemeet SUCCESS
# http://localhost:3000/api/apps/tech.simpleapps.pokecalculator SUCCESS
# http://localhost:3000/api/apps/com.comed.mobile SUCCESS
# http://localhost:3000/api/apps/com.adnfxmobile.discovery.libra SUCCESS
# Total number of apps 14912
# Collected app ids 44
# http://localhost:3000/api/apps/top.flightboard.departures SUCCESS
# http://localhost:3000/api/apps/de.lotum.whatsinthefoto.fr SUCCESS
# http://localhost:3000/api/apps/com.zdp72.audio.book.songs.baby6.childre.lullaby SUCCESS
# http://localhost:3000/api/apps/com.rooh.learn_chinese SUCCESS
# http://localhost:3000/api/apps/com.embarcadero.AuroraForecast3D SUCCESS
# http://localhost:3000/api/apps/com.turner.pocketmorties SUCCESS
# http://localhost:3000/api/apps/com.spacegame.basic5 SUCCESS
# http://localhost:3000/api/apps/com.southwestairlines.mobile SUCCESS
# http://localhost:3000/api/apps/org.kde.kstars.lite SUCCESS
# http://localhost:3000/api/apps/fr.two4tea.fightlist SUCCESS
# Total number of apps 15080
# Collected app ids 44
# http://localhost:3000/api/apps/com.pocketprep.massage SUCCESS
# http://localhost:3000/api/apps/com.foggybus.battletime SUCCESS
# http://localhost:3000/api/apps/com.budgestudios.googleplay.BarbieDreamhouse SUCCESS
# http://localhost:3000/api/apps/com.everlance SUCCESS
# http://localhost:3000/api/apps/com.alinma.AlinmaTadawulApp SUCCESS
# http://localhost:3000/api/apps/com.supercodegames.dinosaurs.hunter.survival.island SUCCESS
# http://localhost:3000/api/apps/com.photoupload SUCCESS
# http://localhost:3000/api/apps/com.istan.AlQuranTerjemahIndonesia SUCCESS
# http://localhost:3000/api/apps/com.hostelbookers.HBApp SUCCESS
# http://localhost:3000/api/apps/bubbleshooter.puzzle SUCCESS
# Total number of apps 15219
# Collected app ids 44
# http://localhost:3000/api/apps/com.andromo.dev585695.app722364 SUCCESS
# http://localhost:3000/api/apps/com.JonsRonaldo.Wallpapers2018 SUCCESS
# http://localhost:3000/api/apps/com.allfootball.manchester.united.news SUCCESS
# http://localhost:3000/api/apps/com.tmobile.pr.mytmobile SUCCESS
# http://localhost:3000/api/apps/net.traveldeals24.main SUCCESS
# http://localhost:3000/api/apps/com.holotype.wallpapers.joker SUCCESS
# http://localhost:3000/api/apps/com.biglion SUCCESS
# http://localhost:3000/api/apps/com.elearning.englishspeaking SUCCESS
# http://localhost:3000/api/apps/com.noviris.radiopeyi SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev337735.app648042 SUCCESS
# Total number of apps 15407
# Collected app ids 44
# http://localhost:3000/api/apps/tech.ula SUCCESS
# http://localhost:3000/api/apps/bubbles.pop.power SUCCESS
# http://localhost:3000/api/apps/com.rep.android SUCCESS
# http://localhost:3000/api/apps/com.enlightment.voicerecorder SUCCESS
# http://localhost:3000/api/apps/com.zayaninfotech.english.grammar SUCCESS
# http://localhost:3000/api/apps/co.pamobile.clashroyale.cardmaker SUCCESS
# http://localhost:3000/api/apps/com.opera.browser.beta SUCCESS
# http://localhost:3000/api/apps/com.coderays.abcdforkids SUCCESS
# http://localhost:3000/api/apps/za.co.primedia.capetalk SUCCESS
# http://localhost:3000/api/apps/com.immediasemi.android.blink SUCCESS
# Total number of apps 15589
# Collected app ids 44
# http://localhost:3000/api/apps/com.zynga.empires2 SUCCESS
# http://localhost:3000/api/apps/com.hm.goe SUCCESS
# http://localhost:3000/api/apps/com.oa.gameapp.loadoutrandomiser SUCCESS
# http://localhost:3000/api/apps/io.voodoo.paperio SUCCESS
# http://localhost:3000/api/apps/com.twobrothers.kids_numbers_and_english_alphabets_learning SUCCESS
# http://localhost:3000/api/apps/com.robtopx.geometrydashworld SUCCESS
# http://localhost:3000/api/apps/de.wetteronline.wetterapppro SUCCESS
# http://localhost:3000/api/apps/com.amfam.myamfam SUCCESS
# http://localhost:3000/api/apps/net.peakgames.lostjewels SUCCESS
# http://localhost:3000/api/apps/com.sinyee.babybus.logical SUCCESS
# Total number of apps 15743
# Collected app ids 44
# http://localhost:3000/api/apps/com.pavahainc.girlhairstyles SUCCESS
# http://localhost:3000/api/apps/moldesbrothers.miradioit SUCCESS
# http://localhost:3000/api/apps/it.junglestudios.cookieclickers SUCCESS
# http://localhost:3000/api/apps/org.spielerplus.web SUCCESS
# http://localhost:3000/api/apps/com.photoeditor.videopiccollage SUCCESS
# http://localhost:3000/api/apps/cjvg.santabiblia SUCCESS
# http://localhost:3000/api/apps/com.games2win.superschooldriver SUCCESS
# http://localhost:3000/api/apps/com.rkr87.dicethronecompanionv3 SUCCESS
# http://localhost:3000/api/apps/com.xodo.pdf.reader SUCCESS
# PERMISSION EXIST
# DOWNLOADED NOW
# http://localhost:3000/api/apps/com.spotterlook.driverstartny2 SUCCESS
# Total number of apps 16011
# Collected app ids 45
# http://localhost:3000/api/apps/mureung.obdproject SUCCESS
# ...
# http://localhost:3000/api/apps/com.irbgetintorugby.app SUCCESS
# http://localhost:3000/api/apps/com.gologota.ethiodan.gologota SUCCESS
# http://localhost:3000/api/apps/br.com.tunglabs.bibliasagrada.reinavalera.mujer SUCCESS
# http://localhost:3000/api/apps/com.csk.project1 SUCCESS
# http://localhost:3000/api/apps/jazzmusic.hitsjazzfree SUCCESS
# http://localhost:3000/api/apps/com.hutchgames.hotwheels SUCCESS
# http://localhost:3000/api/apps/com.edb.taxi.askerbaerumtaxi SUCCESS
# http://localhost:3000/api/apps/com.gameloft.android.ANMP.GloftOLHM SUCCESS
# http://localhost:3000/api/apps/com.skyinfoway.valentinesdayphotoframe SUCCESS
# http://localhost:3000/api/apps/ch.admin.meteoswiss SUCCESS
# http://localhost:3000/api/apps/com.mrd.ghiwane SUCCESS
# http://localhost:3000/api/apps/com.Level5.LaytonMJNAsp SUCCESS
# http://localhost:3000/api/apps/com.hemisoft.happytest.whatcatbreedareyou SUCCESS
# http://localhost:3000/api/apps/ie.irishindependent.areader SUCCESS
# http://localhost:3000/api/apps/com.dragoma.mlen SUCCESS
# http://localhost:3000/api/apps/com.codekonditor.venus SUCCESS
# http://localhost:3000/api/apps/com.watch.richface.casual SUCCESS
# http://localhost:3000/api/apps/com.kelloggs.suitupwithspidermanar SUCCESS
# http://localhost:3000/api/apps/org.roxycinemas.com SUCCESS
# http://localhost:3000/api/apps/com.class11.cbsenotes SUCCESS
# http://localhost:3000/api/apps/az.pasha.mobilebank SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/com.krupal.jindgina.anubhav SUCCESS
# http://localhost:3000/api/apps/com.sevenactivestudio.medicaltuts SUCCESS
# http://localhost:3000/api/apps/com.microsoft.launcher SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/com.minyue.chinaminnanyu SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/org.coast360fcu.mobile SUCCESS
# http://localhost:3000/api/apps/nl.burgernet SUCCESS
# http://localhost:3000/api/apps/mobile.visuals.digitalt.lotust SUCCESS
# http://localhost:3000/api/apps/com.sinotrack SUCCESS
# http://localhost:3000/api/apps/com.ninchanese.app SUCCESS
# http://localhost:3000/api/apps/org.artsplanet.android.mochipanwallpaper SUCCESS
# http://localhost:3000/api/apps/com.gpsroutefinder.locationtracker.free SUCCESS
# http://localhost:3000/api/apps/com.mobdub.channel.KBMT SUCCESS
# http://localhost:3000/api/apps/com.spice.memusic SUCCESS
# http://localhost:3000/api/apps/com.discount.locator SUCCESS
# http://localhost:3000/api/apps/com.dawateislami.hajiimranattari SUCCESS
# http://localhost:3000/api/apps/mobi.MediaSekolahApps.RumusExcelLengkap SUCCESS
# http://localhost:3000/api/apps/com.dg.livewallpaper.beach.hdbackground.starfish SUCCESS
# http://localhost:3000/api/apps/io.kodular.barrionoevo.piscininha SUCCESS
# http://localhost:3000/api/apps/ek.kiransscreasoning SUCCESS
# http://localhost:3000/api/apps/vpn.privateme SUCCESS
# http://localhost:3000/api/apps/com.brave.guardians SUCCESS
# http://localhost:3000/api/apps/com.dlna.asus2 SUCCESS
# http://localhost:3000/api/apps/com.tres24 SUCCESS
# http://localhost:3000/api/apps/com.irving.cartasdeamor SUCCESS
# http://localhost:3000/api/apps/com.gmail.ebdaaapp.learnenglish SUCCESS
# http://localhost:3000/api/apps/com.zm.krasota SUCCESS
# http://localhost:3000/api/apps/com.q2e.horizon3318android.horizonbank.uwnmobile SUCCESS
# http://localhost:3000/api/apps/com.fiberlink.maas360.android.secureviewer SUCCESS
# http://localhost:3000/api/apps/kidslearning_by_robinraina.kidslearning SUCCESS
# http://localhost:3000/api/apps/com.dealabs.apps.android SUCCESS
# http://localhost:3000/api/apps/com.inno.imagelocker SUCCESS
# http://localhost:3000/api/apps/com.ofss.digx.mobile.android SUCCESS
# http://localhost:3000/api/apps/com.application.necromencer.gezgin SUCCESS
# http://localhost:3000/api/apps/com.artkidstudio.driverlicense SUCCESS
# http://localhost:3000/api/apps/sound.meter SUCCESS
# http://localhost:3000/api/apps/io.voodoo.firedup SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev391844.app756869 SUCCESS
# http://localhost:3000/api/apps/dukani.app.com.dukani SUCCESS
# http://localhost:3000/api/apps/com.vydia.app SUCCESS
# http://localhost:3000/api/apps/com.progfinance.progressivemobile SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/com.epiderflix.mahmoud_layti SUCCESS
# http://localhost:3000/api/apps/com.tju.android.radar SUCCESS
# http://localhost:3000/api/apps/ignidroid.trainingdiary SUCCESS
# http://localhost:3000/api/apps/org.owntracks.android SUCCESS
# http://localhost:3000/api/apps/com.kigle.project.pororocon.songgame19.lite.kor SUCCESS
# http://localhost:3000/api/apps/com.glowingapps.herbalhakeem SUCCESS
# http://localhost:3000/api/apps/com.babyfirst.balloon SUCCESS
# http://localhost:3000/api/apps/com.andromo.dev531271.app488215 SUCCESS
# http://localhost:3000/api/apps/com.zdn35.music.songs.audio.spamusicandrelaxmusicsparelaxation SUCCESS
# http://localhost:3000/api/apps/com.emAPPetizer.first SUCCESS
# http://localhost:3000/api/apps/com.coolstickers.wastickerappslove SUCCESS
# http://localhost:3000/api/apps/com.astromobile.stickers.dogs SUCCESS
# http://localhost:3000/api/apps/com.neulion.efl0037 SUCCESS
# http://localhost:3000/api/apps/com.cking.rcpes SUCCESS
# http://localhost:3000/api/apps/bos.consoar.imagestitch SUCCESS
# http://localhost:3000/api/apps/carp.Baseball.news.apps SUCCESS
# http://localhost:3000/api/apps/apps.pandoutah.radio.bangladesh SUCCESS
# http://localhost:3000/api/apps/com.waow.android.weather SUCCESS
# http://localhost:3000/api/apps/sumit.location.map SUCCESS
# http://localhost:3000/api/apps/com.BG.SubnetCalculator SUCCESS
# http://localhost:3000/api/apps/zikr.arabic.uz.zikrlar SUCCESS
# http://localhost:3000/api/apps/com.folieapps.tiernasdeamor SUCCESS
# http://localhost:3000/api/apps/com.klawapps.revisapp SUCCESS
# http://localhost:3000/api/apps/com.acctron.roverlandsea SUCCESS
# http://localhost:3000/api/apps/diary.plus.plus SUCCESS
# http://localhost:3000/api/apps/com.idmobile.worldmeteo SUCCESS
# http://localhost:3000/api/apps/com.ukuleletabs SUCCESS
# http://localhost:3000/api/apps/com.mistertyre.android.client SUCCESS
# http://localhost:3000/api/apps/com.blablacast.multiradio SUCCESS
# http://localhost:3000/api/apps/com.StrongWomenQuotesWithImages.hannapp SUCCESS
# http://localhost:3000/api/apps/net.WAStickerApps.teddybearcutes SUCCESS
# http://localhost:3000/api/apps/com.indesignfirm.doctorscare.release SUCCESS
# http://localhost:3000/api/apps/com.nexttechgamesstudio.poly.art.glitter.number.coloring.book.color.by.number.pixel.art SUCCESS
# http://localhost:3000/api/apps/br.com.sportv.times.figueirense SUCCESS
# http://localhost:3000/api/apps/com.flurv.android SUCCESS
# http://localhost:3000/api/apps/net.kairosoft.android.gamecenter_ja SUCCESS
# http://localhost:3000/api/apps/com.HnSoft.PhoenixLWP3D SUCCESS
# http://localhost:3000/api/apps/com.whsoftware.instacodelive SUCCESS
# http://localhost:3000/api/apps/com.at.resistor.calc SUCCESS
# http://localhost:3000/api/apps/com.worldgn.lifestyleindex SUCCESS
# http://localhost:3000/api/apps/com.tsm.xxl SUCCESS
# http://localhost:3000/api/apps/com.sotofware.superbatterylife SUCCESS
# http://localhost:3000/api/apps/com.edupad.app.grade4.science SUCCESS
# http://localhost:3000/api/apps/air.ABCcards SUCCESS
# http://localhost:3000/api/apps/com.phoenix.cuteprincesslivewallpaper SUCCESS
# http://localhost:3000/api/apps/com.karmagroups SUCCESS
# http://localhost:3000/api/apps/in.ac.vtu.conn SUCCESS
# http://localhost:3000/api/apps/com.hardrockmusic.hardrockradio SUCCESS
# http://localhost:3000/api/apps/com.taiyouxi.jwsus SUCCESS
# http://localhost:3000/api/apps/com.vishal.allquotes SUCCESS
# http://localhost:3000/api/apps/com.transatel.selfcare.ubigi SUCCESS
# http://localhost:3000/api/apps/com.kone.kcolapp SUCCESS
# http://localhost:3000/api/apps/com.samesystem SUCCESS
# http://localhost:3000/api/apps/com.korloy.mobile.kts SUCCESS
# http://localhost:3000/api/apps/com.ubisoft.horsehaven.adventures SUCCESS
# http://localhost:3000/api/apps/sweetchat.localdatingtinder.meet SUCCESS
# http://localhost:3000/api/apps/jaikalki.biomagzine.com.k11bhotikincertsol SUCCESS
# http://localhost:3000/api/apps/com.linmedia.newstouch.wpri SUCCESS
# http://localhost:3000/api/apps/com.assysto.android.plumb_bob SUCCESS
# http://localhost:3000/api/apps/com.sas.whatswebpro SUCCESS
# http://localhost:3000/api/apps/com.app.canifa SUCCESS
# http://localhost:3000/api/apps/com.bbg.tiwdroid SUCCESS
# http://localhost:3000/api/apps/me.disconnect.pro SUCCESS
# http://localhost:3000/api/apps/com.nesthotel.android SUCCESS
# http://localhost:3000/api/apps/com.mogparadio.radio SUCCESS
# http://localhost:3000/api/apps/my.lisekodroid.bslight SUCCESS
# http://localhost:3000/api/apps/cz.rohlik.app SUCCESS
# http://localhost:3000/api/apps/io.thesunentertainment24h.dontrunmysweety SUCCESS
# http://localhost:3000/api/apps/io.bolt.mibwallet SUCCESS
# http://localhost:3000/api/apps/com.bharti.arthvyavas SUCCESS
# http://localhost:3000/api/apps/com.tafayor.killall SUCCESS
# http://localhost:3000/api/apps/com.letstango.mobile SUCCESS
# http://localhost:3000/api/apps/pixelab.camart.cartoon SUCCESS
# http://localhost:3000/api/apps/tech.chitwansoft.emergencyinformation SUCCESS
# http://localhost:3000/api/apps/com.eaglecs.learningkorean SUCCESS
# http://localhost:3000/api/apps/com.canalguidesystems.tracker.csa SUCCESS
# http://localhost:3000/api/apps/ru.hivecompany.hivetaxidriverapp.protaxi SUCCESS
# http://localhost:3000/api/apps/com.ls.msa.alghad_fm SUCCESS
# http://localhost:3000/api/apps/pro.mwallet.tezsum SUCCESS
# http://localhost:3000/api/apps/com.ischgl SUCCESS
# http://localhost:3000/api/apps/jp.blogspot.halnablue.halnamind SUCCESS
# http://localhost:3000/api/apps/org.thoughtcrime.securesms SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/sa.gov.moi SUCCESS
# http://localhost:3000/api/apps/com.canada.canadaimmigrationutility SUCCESS
# http://localhost:3000/api/apps/de.konsole_labs.kultur SUCCESS
# http://localhost:3000/api/apps/com.inigral.schoolsapp SUCCESS
# http://localhost:3000/api/apps/com.joedevapp.live4dresult SUCCESS
# http://localhost:3000/api/apps/com.grupet.web.app SUCCESS
# http://localhost:3000/api/apps/com.malauzai.cbot SUCCESS
# http://localhost:3000/api/apps/com.AntonBergov.Poteshki SUCCESS
# http://localhost:3000/api/apps/com.hoehenmesser.cjp SUCCESS
# http://localhost:3000/api/apps/com.intellijoy.kids.math SUCCESS
# http://localhost:3000/api/apps/com.skgames.trafficrider SUCCESS
# http://localhost:3000/api/apps/ismartsolution.ayurvedic.gharelu.nuskhe SUCCESS
# http://localhost:3000/api/apps/esrith.meawms SUCCESS
# http://localhost:3000/api/apps/com.f2r.rallyTripMeter SUCCESS
# http://localhost:3000/api/apps/com.ikeyboard.theme.love.hearts SUCCESS
# http://localhost:3000/api/apps/net.micrositios.cremil SUCCESS
# http://localhost:3000/api/apps/com.citizen.calclite SUCCESS
# http://localhost:3000/api/apps/com.music.rai.Cheb_Hasni SUCCESS
# http://localhost:3000/api/apps/com.appsfreestations.rcusco SUCCESS
# http://localhost:3000/api/apps/com.intellijoy.kids.math.lite SUCCESS
# http://localhost:3000/api/apps/nh.smart.allonebank SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/com.capty.wedbox SUCCESS
# http://localhost:3000/api/apps/com.adboosters.sexuados SUCCESS
# http://localhost:3000/api/apps/me.JR.holybibleAMPEnglish SUCCESS
# http://localhost:3000/api/apps/com.tamfamtv.app SUCCESS
# http://localhost:3000/api/apps/com.kaya.musicapp SUCCESS
# http://localhost:3000/api/apps/com.theappcentral.quranforall SUCCESS
# http://localhost:3000/api/apps/com.wifiaudio.EDGE SUCCESS
# http://localhost:3000/api/apps/com.notification.ringtones.cool.sounds SUCCESS
# http://localhost:3000/api/apps/com.jasonkung.launcher3 SUCCESS
# http://localhost:3000/api/apps/com.androidappsvilla.duroodetaaj SUCCESS
# http://localhost:3000/api/apps/com.wdtinc.android.mwr SUCCESS
# http://localhost:3000/api/apps/li.yapp.app5AA031FB SUCCESS
# http://localhost:3000/api/apps/com.norght.echallanahmedabad.echallanahmedabad SUCCESS
# http://localhost:3000/api/apps/com.particlelivewallpaper.particlefluidsgalaxy SUCCESS
# http://localhost:3000/api/apps/com.sir.racing.ultimatecardrivingsimulator SUCCESS
# http://localhost:3000/api/apps/com.appselite.oldschoolmusicradio SUCCESS
# http://localhost:3000/api/apps/com.kiri.quotamp SUCCESS
# http://localhost:3000/api/apps/com.o_taiji.digitimer4 SUCCESS
# http://localhost:3000/api/apps/com.mobileapp.myrechargefranchise SUCCESS
# http://localhost:3000/api/apps/com.aigames.worldblitz SUCCESS
# http://localhost:3000/api/apps/com.goelectricstations.nextcharge SUCCESS
# http://localhost:3000/api/apps/com.tmsoft.playapod SUCCESS
# http://localhost:3000/api/apps/god.bhjans.vishnu SUCCESS
# http://localhost:3000/api/apps/com.shohokari SUCCESS
# http://localhost:3000/api/apps/com.oromnet.Arabic_Amharic_Conversation SUCCESS
# http://localhost:3000/api/apps/com.varsitytutors.learningtools.appsychology SUCCESS
# http://localhost:3000/api/apps/com.ltmoneycenter_android.PROD SUCCESS
# http://localhost:3000/api/apps/com.midlandeurope.bttalk SUCCESS
# http://localhost:3000/api/apps/com.redantz.game.battle SUCCESS
# http://localhost:3000/api/apps/com.vs.appmarket.myanmar SUCCESS
# http://localhost:3000/api/apps/com.app.p1956AF SUCCESS
# http://localhost:3000/api/apps/rudy.android.yoyo SUCCESS
# http://localhost:3000/api/apps/se.exest.trafficcross SUCCESS
# http://localhost:3000/api/apps/com.muslim.rap.bahadev SUCCESS
# http://localhost:3000/api/apps/net.hubalek.android.apps.barometer SUCCESS
# http://localhost:3000/api/apps/com.haaretz SUCCESS
# http://localhost:3000/api/apps/com.appFactory.bts SUCCESS
# http://localhost:3000/api/apps/com.japharr.tvdlite SUCCESS
# http://localhost:3000/api/apps/com.gamescapes.car.parking.simulator SUCCESS
# http://localhost:3000/api/apps/net.IntouchApp SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/com.pikpok.ax.play SUCCESS
# http://localhost:3000/api/apps/io.shiftee.app SUCCESS
# http://localhost:3000/api/apps/com.eatonly.orderingapp SUCCESS
# http://localhost:3000/api/apps/io.coindreams.coindreams SUCCESS
# http://localhost:3000/api/apps/bg.abv.andro.emailapp SUCCESS
# http://localhost:3000/api/apps/com.taxis99 SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/com.giri.albums.vishnu SUCCESS
# http://localhost:3000/api/apps/iwopi.iwopiandroid SUCCESS
# http://localhost:3000/api/apps/ru.omdevelopment.ref.biblelug.free SUCCESS
# http://localhost:3000/api/apps/com.directv.navigator SUCCESS
# http://localhost:3000/api/apps/com.knighttrans.mobile SUCCESS
# http://localhost:3000/api/apps/com.vishvadev.jankib SUCCESS
# http://localhost:3000/api/apps/com.themelauncher.greennature SUCCESS
# http://localhost:3000/api/apps/npsquare.marathi.prempatra SUCCESS
# http://localhost:3000/api/apps/com.flash.flashtrader SUCCESS
# PERMISSION EXIST
# http://localhost:3000/api/apps/cordova.code.play SUCCESS
# http://localhost:3000/api/apps/com.cocoplay.cocobunny SUCCESS
# http://localhost:3000/api/apps/com.rr.logical.whatsdirect SUCCESS
# http://localhost:3000/api/apps/virosoft.gofamint.hymnal SUCCESS
# http://localhost:3000/api/apps/com.ausichenko.spritzbubble SUCCESS
# http://localhost:3000/api/apps/br.com.tapps.elephantevolution SUCCESS
# http://localhost:3000/api/apps/com.copyharuki.hanjakoreandictionaries SUCCESS
# http://localhost:3000/api/apps/golesfpc.co.embajador SUCCESS
# http://localhost:3000/api/apps/alldictdict.alldict.cses SUCCESS
# http://localhost:3000/api/apps/com.joysoft.unidict SUCCESS
# http://localhost:3000/api/apps/com.app.makano SUCCESS
# PERMISSION EXIST
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-42ba91dc66cb> in <module>()
#      63                     print("PERMISSION EXIST")
#      64                     app_ids.add(application_id )
# ---> 65                     cat = get_app_category(application_id)
#      66                     with open("{}/{}.txt".format(permission_type, cat), "a") as target:
#      67                         target.write(application_id + "\n")
#
# <ipython-input-2-c2fe1722dce1> in get_app_category(app_id)
#      38     response = requests.get(base_url+app_id)
#      39     if response.status_code == 200:
# ---> 40         gid = response.json()["genreId"].upper()
#      41         return gid
#      42     else:
#
# KeyError: 'genreId'

# %%
print("-----------------------------------------------------------------------------------------------------------")
print("TRAVERSING COMPLETED")
for url in waiting_urls:
    response = requests.get(url)
    if response.status_code == 200:
        json = response.json()
        if json["minInstalls"] > 10000 and json["priceText"] == "Free" and len(json["description"]) > 500:
            application_id = url.split('/')[-1]
            if application_id not in app_ids:
                if is_permission_exist(url):
                    print(url, end=" ")
                    print("SUCCESS")
                    print("PERMISSION EXIST")
                    app_ids.add(application_id )
                    cat = get_app_category(application_id)
                    with open("{}/{}.txt".format(permission_type, cat), "a") as target:
                        target.write(application_id + "\n")
                        print("DOWNLOADED NOW")
              
                
    else:
        print("FAIL")
# Out:
# -----------------------------------------------------------------------------------------------------------
# TRAVERSING COMPLETED
# FAIL
# FAIL
# FAIL
# Permission link is failed
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# Permission link is failed
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
# FAIL
