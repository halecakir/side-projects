# %%
import requests
import time
import csv
import random
from time import sleep

# %%
categories = {"categories":[{"cat_key":"OVERALL","name":"Overall"},{"cat_key":"APPLICATION","name":"All apps"},{"cat_key":"GAME","name":"All games"},{"cat_key":"ART_AND_DESIGN","name":"Art & Design"},{"cat_key":"AUTO_AND_VEHICLES","name":"Auto & Vehicles"},{"cat_key":"BEAUTY","name":"Beauty"},{"cat_key":"BOOKS_AND_REFERENCE","name":"Books & Reference"},{"cat_key":"BUSINESS","name":"Business"},{"cat_key":"COMICS","name":"Comics"},{"cat_key":"COMMUNICATION","name":"Communication"},{"cat_key":"DATING","name":"Dating"},{"cat_key":"EDUCATION","name":"Education"},{"cat_key":"ENTERTAINMENT","name":"Entertainment"},{"cat_key":"EVENTS","name":"Events"},{"cat_key":"FINANCE","name":"Finance"},{"cat_key":"FOOD_AND_DRINK","name":"Food & Drink"},{"cat_key":"HEALTH_AND_FITNESS","name":"Health & Fitness"},{"cat_key":"HOUSE_AND_HOME","name":"House & Home"},{"cat_key":"LIFESTYLE","name":"Lifestyle"},{"cat_key":"MAPS_AND_NAVIGATION","name":"Maps & Navigation"},{"cat_key":"MEDICAL","name":"Medical"},{"cat_key":"MUSIC_AND_AUDIO","name":"Music & Audio"},{"cat_key":"NEWS_AND_MAGAZINES","name":"News & Magazines"},{"cat_key":"PARENTING","name":"Parenting"},{"cat_key":"PERSONALIZATION","name":"Personalization"},{"cat_key":"PHOTOGRAPHY","name":"Photography"},{"cat_key":"PRODUCTIVITY","name":"Productivity"},{"cat_key":"SHOPPING","name":"Shopping"},{"cat_key":"SOCIAL","name":"Social"},{"cat_key":"SPORTS","name":"Sports"},{"cat_key":"TOOLS","name":"Tools"},{"cat_key":"TRAVEL_AND_LOCAL","name":"Travel & Local"},{"cat_key":"VIDEO_PLAYERS","name":"Video Players & Editors"},{"cat_key":"WEATHER","name":"Weather"},{"cat_key":"LIBRARIES_AND_DEMO","name":"Libraries & Demo"},{"cat_key":"GAME_ARCADE","name":"Arcade"},{"cat_key":"GAME_PUZZLE","name":"Puzzle"},{"cat_key":"GAME_CARD","name":"Cards"},{"cat_key":"GAME_CASUAL","name":"Casual"},{"cat_key":"GAME_RACING","name":"Racing"},{"cat_key":"GAME_SPORTS","name":"Sport Games"},{"cat_key":"GAME_ACTION","name":"Action"},{"cat_key":"GAME_ADVENTURE","name":"Adventure"},{"cat_key":"GAME_BOARD","name":"Board"},{"cat_key":"GAME_CASINO","name":"Casino"},{"cat_key":"GAME_EDUCATIONAL","name":"Educational"},{"cat_key":"GAME_MUSIC","name":"Music Games"},{"cat_key":"GAME_ROLE_PLAYING","name":"Role Playing"},{"cat_key":"GAME_SIMULATION","name":"Simulation"},{"cat_key":"GAME_STRATEGY","name":"Strategy"},{"cat_key":"GAME_TRIVIA","name":"Trivia"},{"cat_key":"GAME_WORD","name":"Word Games"},{"cat_key":"ANDROID_WEAR","name":"Android Wear"},{"cat_key":"FAMILY","name":"Family All Ages"},{"cat_key":"FAMILY_UNDER_5","name":"Family Ages 5 & Under"},{"cat_key":"FAMILY_6_TO_8","name":"Family Ages 6-8"},{"cat_key":"FAMILY_9_AND_UP","name":"Family Ages 9 & Up"},{"cat_key":"FAMILY_ACTION","name":"Family Action"},{"cat_key":"FAMILY_BRAINGAMES","name":"Family Brain Games"},{"cat_key":"FAMILY_CREATE","name":"Family Create"},{"cat_key":"FAMILY_EDUCATION","name":"Family Education"},{"cat_key":"FAMILY_MUSICVIDEO","name":"Family Music & Video"},{"cat_key":"FAMILY_PRETEND","name":"Family Pretend Play"}]}

# %%
#category_keys = [cat["cat_key"] for cat in categories["categories
category_keys = ["GAME_TRIVIA", "HEALTH_AND_FITNESS", "PARENTING", "BOOKS_AND_REFERENCE", "GAME_MUSIC", "SPORTS", "GAME_EDUCATIONAL", "MEDICAL", "LIBRARIES_AND_DEMO", "GAME_CARD", "FOOD_AND_DRINK", "GAME_SIMULATION", "GAME_SPORTS", "GAME_ADVENTURE", "EVENTS", "ART_AND_DESIGN", "AUTO_AND_VEHICLES", "GAME_RACING", "GAME_PUZZLE", "NOT_FOUND", "BEAUTY", "COMICS", "GAME_ARCADE"]

# %%
def get_top_free_applications(categories):
    def per_category_top_free(category):
        waiting_urls = set()
        url = 'http://localhost:3000/api/apps/?collection=topselling_free&category={}&lang=en'.format(category)
        #top free applications
        response = requests.get(url)
        if response.status_code == 200:
            for app in response.json()["results"]:
                waiting_urls.add(app["url"])
        else:
            print("Request Error")
        return waiting_urls
    all_top_free_apps = set()
    for category in categories:
        all_top_free_apps.update(per_category_top_free(category))
    return all_top_free_apps

# %%
def get_app_category(app_id):
    base_url = 'http://localhost:3000/api/apps/'
    response = requests.get(base_url+app_id)
    if response.status_code == 200:
        gid = response.json()["genreId"].upper()
        return gid
    else:
        print(app_id, " category cannot be found")
        return "NOT_FOUND"

# %%
import pandas as pd
def application_list(filename, sheetname):
    df = pd.read_excel(filename, sheet_name=sheetname)
    data = set()
   
    for index, row in df.iterrows():
        if row["Sentences"].startswith("##"):
            app_id = row["Sentences"].split("##")[1]
            data.add(app_id)
    return data

# %%
dowloaded_list = application_list("SEVIL.xlsx", "Sheet1")

# %%
top_free_apps = get_top_free_applications(category_keys)
# Out:
# Request Error

# %%
top_free_apps
# Out:
# {'http://localhost:3000/api/apps/com.stx.cutit',
#  'http://localhost:3000/api/apps/com.bitmango.go.blockpuzzlestarfinder',
#  'http://localhost:3000/api/apps/com.starbucks.mobilecard',
#  'http://localhost:3000/api/apps/com.arbys.android.arbysapp',
#  'http://localhost:3000/api/apps/com.marykay.skinsight.android.flavorProd',
#  'http://localhost:3000/api/apps/com.ty.driftycar',
#  'http://localhost:3000/api/apps/com.magic.music.tiles.piano.dream',
#  'http://localhost:3000/api/apps/com.coldapp.at50rooms1',
#  'http://localhost:3000/api/apps/com.gos.futuristiccity.bikeriding.stuntsimulator',
#  'http://localhost:3000/api/apps/com.subway.ryan.runner.toys.us',
#  'http://localhost:3000/api/apps/com.flipps.fitetv',
#  'http://localhost:3000/api/apps/com.sadpuppy.lemmings',
#  'http://localhost:3000/api/apps/in.fulldive.applicationslauncher',
#  'http://localhost:3000/api/apps/pl.swiatquizu.disneyquiz.android',
#  'http://localhost:3000/api/apps/com.namcobandaigames.pacmantournaments',
#  'http://localhost:3000/api/apps/com.army.counter.attack',
#  'http://localhost:3000/api/apps/com.impp.truck.simulator.rescueexcavator',
#  'http://localhost:3000/api/apps/com.cardgame.spider.fishdom',
#  'http://localhost:3000/api/apps/com.lolsurprise.pixelart.free',
#  'http://localhost:3000/api/apps/com.topfreegames.bikeracefreeworld',
#  'http://localhost:3000/api/apps/com.nomonkeys.ballblast',
#  'http://localhost:3000/api/apps/com.olo.elpolloloco',
#  'http://localhost:3000/api/apps/com.mxtech.ffmpeg.v7_vfpv3d16',
#  'http://localhost:3000/api/apps/com.foodtec.marcos',
#  'http://localhost:3000/api/apps/com.aim.racing',
#  'http://localhost:3000/api/apps/com.me2zen.tripeaks',
#  'http://localhost:3000/api/apps/com.myquest',
#  'http://localhost:3000/api/apps/mobile.appQtFr7tPuCv',
#  'http://localhost:3000/api/apps/com.orange.kidspiano.music.songs',
#  'http://localhost:3000/api/apps/com.espn.score_center',
#  'http://localhost:3000/api/apps/com.google.android.apps.books',
#  'http://localhost:3000/api/apps/com.zoemob.gpstracking',
#  'http://localhost:3000/api/apps/com.teladoc.members',
#  'http://localhost:3000/api/apps/com.specialyg.ippro',
#  'http://localhost:3000/api/apps/fashionapp.com.teenoutfitideas',
#  'http://localhost:3000/api/apps/com.main.gopuff',
#  'http://localhost:3000/api/apps/com.miniclip.archery',
#  'http://localhost:3000/api/apps/com.miniclip.plagueinc',
#  'http://localhost:3000/api/apps/us.mitene',
#  'http://localhost:3000/api/apps/com.andromo.dev759880.app845507',
#  'http://localhost:3000/api/apps/com.ulta',
#  'http://localhost:3000/api/apps/mobi.mangatoon.comics.aphone',
#  'http://localhost:3000/api/apps/com.qidian.Int.reader',
#  'http://localhost:3000/api/apps/co.thefabulous.app',
#  'http://localhost:3000/api/apps/com.amanotes.classicalpiano',
#  'http://localhost:3000/api/apps/app.quiktrip.com.quiktrip',
#  'http://localhost:3000/api/apps/com.arcsoft.perfect365',
#  'http://localhost:3000/api/apps/com.cardgame.pyramid.fishdom',
#  'http://localhost:3000/api/apps/com.imangi.templerun',
#  'http://localhost:3000/api/apps/com.slicelife.storefront',
#  'http://localhost:3000/api/apps/com.gramgames.mergedragons',
#  'http://localhost:3000/api/apps/com.msi.logogame',
#  'http://localhost:3000/api/apps/org.iggymedia.periodtracker',
#  'http://localhost:3000/api/apps/com.dotnbeat.dancing.music.rhythm.handspeed',
#  'http://localhost:3000/api/apps/com.gifs.flowers',
#  'http://localhost:3000/api/apps/com.sweetandbeautyhdcameras.stepstepmakeup',
#  'http://localhost:3000/api/apps/com.tomdxs.symafpv',
#  'http://localhost:3000/api/apps/com.aestheticphotomaker.vaporwavestickers.glitcheffectzone',
#  'http://localhost:3000/api/apps/com.europosit.pixelcoloring',
#  'http://localhost:3000/api/apps/com.cardgame.solitaire',
#  'http://localhost:3000/api/apps/com.taplane.triviaquizm',
#  'http://localhost:3000/api/apps/com.kamagames.blackjack',
#  'http://localhost:3000/api/apps/com.naqt.apps.nationals',
#  'http://localhost:3000/api/apps/com.ubercab.eats',
#  'http://localhost:3000/api/apps/com.panera.bread',
#  'http://localhost:3000/api/apps/com.orbitalknight.castlewreck',
#  'http://localhost:3000/api/apps/com.kidgame.supermarket',
#  'http://localhost:3000/api/apps/com.mizo.stealth.robot.transformation',
#  'http://localhost:3000/api/apps/com.ticketlite.Ticketclub',
#  'http://localhost:3000/api/apps/com.kwalee.drawit',
#  'http://localhost:3000/api/apps/com.milliongames.motocrossracing',
#  'http://localhost:3000/api/apps/air.com.sgn.cookiejam.gp',
#  'http://localhost:3000/api/apps/com.cb.myvacation.realadventure',
#  'http://localhost:3000/api/apps/com.advocate.myadvocate',
#  'http://localhost:3000/api/apps/com.woebot',
#  'http://localhost:3000/api/apps/com.unation.app',
#  'http://localhost:3000/api/apps/mytown.beautycontest.free',
#  'http://localhost:3000/api/apps/com.etermax.trivia.preguntados2',
#  'http://localhost:3000/api/apps/com.nbcsports.mobile.rsnlocalsports',
#  'http://localhost:3000/api/apps/com.dfstream.mlb',
#  'http://localhost:3000/api/apps/co.pamobile.pokemon.cardmaker',
#  'http://localhost:3000/api/apps/com.Best.Ringtones',
#  'http://localhost:3000/api/apps/com.madcat.easyposer',
#  'http://localhost:3000/api/apps/com.gamestr.light.speed.hero.city.rescue',
#  'http://localhost:3000/api/apps/com.gismart.guitar',
#  'http://localhost:3000/api/apps/com.gen.workoutme',
#  'http://localhost:3000/api/apps/com.custom.spillit',
#  'http://localhost:3000/api/apps/com.droidlinkedcodenw.duo',
#  'http://localhost:3000/api/apps/com.sagagames.crime.fighter.action.kill.hero',
#  'http://localhost:3000/api/apps/com.glu.stardomkim',
#  'http://localhost:3000/api/apps/com.coldapp.hometownadventure',
#  'http://localhost:3000/api/apps/com.mobilemirror.app2018.mirror',
#  'http://localhost:3000/api/apps/com.tgs.MultiSpiderRobot.AmazingSpider.GrandRobotBattle',
#  'http://localhost:3000/api/apps/com.healint.migraineapp',
#  'http://localhost:3000/api/apps/com.bettertomorrowapps.camerablockfree',
#  'http://localhost:3000/api/apps/es.socialpoint.DragonCity',
#  'http://localhost:3000/api/apps/com.mmobile.app.event',
#  'http://localhost:3000/api/apps/com.gc.android',
#  'http://localhost:3000/api/apps/de.moodpath.android',
#  'http://localhost:3000/api/apps/com.sinyee.babybus.babyhospital',
#  'http://localhost:3000/api/apps/com.spacegame.basic3',
#  'http://localhost:3000/api/apps/com.dokdoapps.mybabyfirework',
#  'http://localhost:3000/api/apps/games.onebutton.golfbattle',
#  'http://localhost:3000/api/apps/com.azurgames.stackball',
#  'http://localhost:3000/api/apps/de.unp3rf3ct.JoinsTheBattleGenerator',
#  'http://localhost:3000/api/apps/me.discotech',
#  'http://localhost:3000/api/apps/com.dalcomsoft.ssb',
#  'http://localhost:3000/api/apps/com.infokombinat.coloringanime',
#  'http://localhost:3000/api/apps/co.ritual.app',
#  'http://localhost:3000/api/apps/com.mcdonalds.mobileapp',
#  'http://localhost:3000/api/apps/com.styleseat.promobile',
#  'http://localhost:3000/api/apps/com.ea.games.r3_na',
#  'http://localhost:3000/api/apps/com.siplay.tourneymachine_android',
#  'http://localhost:3000/api/apps/com.sinyee.babybus.tailor',
#  'http://localhost:3000/api/apps/com.medicalutilitytools.bloodpressure.diary.bp.info.chart.log',
#  'http://localhost:3000/api/apps/com.ea.game.maddenmobile15_row',
#  'http://localhost:3000/api/apps/com.nbadigital.gametimelite',
#  'http://localhost:3000/api/apps/com.sinyee.babybus.dailysafety',
#  'http://localhost:3000/api/apps/com.informa.DallasFanDays',
#  'http://localhost:3000/api/apps/com.rovio.dream',
#  'http://localhost:3000/api/apps/com.gen.betterwalking',
#  'http://localhost:3000/api/apps/com.colorbynumber.unicorn.pixel.art.panda.draw.paintbynumber',
#  'http://localhost:3000/api/apps/com.Gseeds.JekyllAndHyde',
#  'http://localhost:3000/api/apps/com.amanotes.reborn',
#  'http://localhost:3000/api/apps/com.joyjourney.PianoWhiteLittle',
#  'http://localhost:3000/api/apps/com.dna.solitaireapp',
#  'http://localhost:3000/api/apps/com.fingersoft.hillclimb',
#  'http://localhost:3000/api/apps/com.clean.road',
#  'http://localhost:3000/api/apps/com.sir.racing.ultimatecardrivingsimulatorclassics',
#  'http://localhost:3000/api/apps/com.gpp.beefactory',
#  'http://localhost:3000/api/apps/com.heapsol.spanishenglishtranslator',
#  'http://localhost:3000/api/apps/com.fgol.HungrySharkEvolution',
#  'http://localhost:3000/api/apps/com.brainium.solitairefree',
#  'http://localhost:3000/api/apps/com.music.game.bluesky.xxxtentacion',
#  'http://localhost:3000/api/apps/com.horseracesnow.android',
#  'http://localhost:3000/api/apps/com.zerofasting.zero',
#  'http://localhost:3000/api/apps/com.bonbongame.crazy.dentist.doctor',
#  'http://localhost:3000/api/apps/ai.kanghealth',
#  'http://localhost:3000/api/apps/com.prettysimple.criminalcaseandroid',
#  'http://localhost:3000/api/apps/com.bimiboo.playandlearn',
#  'http://localhost:3000/api/apps/com.goodreads',
#  'http://localhost:3000/api/apps/com.lowestmed.android',
#  'http://localhost:3000/api/apps/com.mgc.runnergame',
#  'http://localhost:3000/api/apps/com.locker.kids',
#  'http://localhost:3000/api/apps/com.tutotoons.app.mybabyunicorn.free',
#  'http://localhost:3000/api/apps/com.dd.doordash',
#  'http://localhost:3000/api/apps/com.crazylabs.sausage.run',
#  'http://localhost:3000/api/apps/com.draftkings.dknativermgGP',
#  'http://localhost:3000/api/apps/kr.caramel.quiz_stickman',
#  'http://localhost:3000/api/apps/com.sesameworkshop.alphabetkitchen.play',
#  'http://localhost:3000/api/apps/com.cmplay.tiles2',
#  'http://localhost:3000/api/apps/com.dofu.nba',
#  'http://localhost:3000/api/apps/com.xxxtentacion.keyboardsad',
#  'http://localhost:3000/api/apps/com.sched.penguicon2019.single',
#  'http://localhost:3000/api/apps/emoji.photo.editor',
#  'http://localhost:3000/api/apps/com.kongregate.mobile.throwdown.google',
#  'http://localhost:3000/api/apps/com.webmd.android',
#  'http://localhost:3000/api/apps/com.kicksonfire.android',
#  'http://localhost:3000/api/apps/com.appspouch.medicaldictionary',
#  'http://localhost:3000/api/apps/com.americanwell.android.member.amwell',
#  'http://localhost:3000/api/apps/com.goodrx.krogerrxsc',
#  'http://localhost:3000/api/apps/net.booksy.business',
#  'http://localhost:3000/api/apps/com.mylaps.eventapp.flyingpigevents',
#  'http://localhost:3000/api/apps/com.figuromo.colorminiscollections',
#  'http://localhost:3000/api/apps/com.BlueeWooTeam.threeDSE',
#  'http://localhost:3000/api/apps/com.timuzgames.bikeracing2018',
#  'http://localhost:3000/api/apps/com.mobilityware.solitaire',
#  'http://localhost:3000/api/apps/com.tutotoons.app.animalhairsalonaustralia.free',
#  'http://localhost:3000/api/apps/com.candysmashmania.sweetcrush.free',
#  'http://localhost:3000/api/apps/com.vizorapps.klondike',
#  'http://localhost:3000/api/apps/com.halfbrick.fruitninjafree',
#  'http://localhost:3000/api/apps/com.vivian.lawofattraction',
#  'http://localhost:3000/api/apps/com.drizly.Drizly',
#  'http://localhost:3000/api/apps/com.musicplayer.svmteam',
#  'http://localhost:3000/api/apps/com.cuteandtinybabygames.twinkleunicorncatprincess.free',
#  'http://localhost:3000/api/apps/com.nyxcosmetics.nyx',
#  'http://localhost:3000/api/apps/newking.james.version.BIBLE',
#  'http://localhost:3000/api/apps/ps.battle.royale',
#  'http://localhost:3000/api/apps/com.senegence.android.senelooks',
#  'http://localhost:3000/api/apps/com.autopten.cheapcarsforsale',
#  'http://localhost:3000/api/apps/com.sgn.pandapop.gp',
#  'http://localhost:3000/api/apps/vivino.web.app',
#  'http://localhost:3000/api/apps/com.bigduckgames.flow',
#  'http://localhost:3000/api/apps/com.sonypicturestelevision.jeopardy2',
#  'http://localhost:3000/api/apps/com.mobilityware.CastleSolitaire',
#  'http://localhost:3000/api/apps/com.games2win.superschooldriver',
#  'http://localhost:3000/api/apps/com.hcsc.android.providerfindertx',
#  'http://localhost:3000/api/apps/pcm.light.crown.photo.editor',
#  'http://localhost:3000/api/apps/org.jw.jwlibrary.mobile',
#  'http://localhost:3000/api/apps/zonek.design.boyngirl',
#  'http://localhost:3000/api/apps/com.timeanddate.countdown',
#  'http://localhost:3000/api/apps/com.mapmyrun.android2',
#  'http://localhost:3000/api/apps/com.pink.piano.kid.flower.real.tiles',
#  'http://localhost:3000/api/apps/com.contorra.golfpad',
#  'http://localhost:3000/api/apps/com.volumebooster.music.equalizer.svmteam',
#  'http://localhost:3000/api/apps/com.tomdxs.symafpv180209',
#  'http://localhost:3000/api/apps/com.groundspeak.geocaching.intro',
#  'http://localhost:3000/api/apps/com.fitbit.FitbitMobile',
#  'http://localhost:3000/api/apps/com.razmobi.monstertrucks2',
#  'http://localhost:3000/api/apps/br.com.ctncardoso.ctncar',
#  'http://localhost:3000/api/apps/com.nutanix.events',
#  'http://localhost:3000/api/apps/com.firsttouchgames.dls3',
#  'http://localhost:3000/api/apps/bn.ereader',
#  'http://localhost:3000/api/apps/com.games_for_rest.drum_kit_free',
#  'http://localhost:3000/api/apps/com.tocaboca.tocakitchen2',
#  'http://localhost:3000/api/apps/com.mcdonalds.app',
#  'http://localhost:3000/api/apps/com.outback.tampa',
#  'http://localhost:3000/api/apps/com.vectorunit.purple.googleplay',
#  'http://localhost:3000/api/apps/com.fitstar.pt',
#  'http://localhost:3000/api/apps/com.blizzard.wtcg.hearthstone',
#  'http://localhost:3000/api/apps/com.nurx',
#  'http://localhost:3000/api/apps/com.bitmango.go.blockhexapuzzle',
#  'http://localhost:3000/api/apps/com.urbansitter.android',
#  'http://localhost:3000/api/apps/com.milliongames.cardrivingsimulator',
#  'http://localhost:3000/api/apps/com.sinyee.babybus.policemen',
#  'http://localhost:3000/api/apps/com.johny.johnyjohnyyespapa',
#  'http://localhost:3000/api/apps/com.perfectcorp.ycn',
#  'http://localhost:3000/api/apps/com.us.police.cargo.transporter',
#  'http://localhost:3000/api/apps/com.zplay.Mrbow',
#  'http://localhost:3000/api/apps/mobi.firedepartment',
#  'http://localhost:3000/api/apps/com.tutotoons.app.kikififipethotel.free',
#  'http://localhost:3000/api/apps/com.cylonblast.homemadebeautyguidesfacialcare',
#  'http://localhost:3000/api/apps/com.weplaydots.twodotsandroid',
#  'http://localhost:3000/api/apps/man.workout.abs.fitness.loseweight',
#  'http://localhost:3000/api/apps/com.punchh.mod',
#  'http://localhost:3000/api/apps/com.charlie_names.charlies_names',
#  'http://localhost:3000/api/apps/com.hitcents.drawastickmanepic2free',
#  'http://localhost:3000/api/apps/armworkout.armworkoutformen.armexercises',
#  'http://localhost:3000/api/apps/com.sports.real.golf.rival.online',
#  'http://localhost:3000/api/apps/com.chad.wild.wallpaper.lol.studio',
#  'http://localhost:3000/api/apps/easy.to.read.kjv.bible',
#  'http://localhost:3000/api/apps/com.ga.monster.gorilla.hunting.sniper.shooter',
#  'http://localhost:3000/api/apps/com.google.android.stardroid',
#  'http://localhost:3000/api/apps/com.hyperfame.car.transporter_truck2019simulator_free',
#  'http://localhost:3000/api/apps/com.archery.champ.king.bow',
#  'http://localhost:3000/api/apps/com.creative.colorfit.mandala.coloring.book',
#  'http://localhost:3000/api/apps/tv.telepathic.hooked',
#  'http://localhost:3000/api/apps/com.vividgames.realboxing',
#  'http://localhost:3000/api/apps/com.aofl.adventureacademy',
#  'http://localhost:3000/api/apps/provapi.wallpaper.xxxtentacion',
#  'http://localhost:3000/api/apps/air.com.tutotoons.app.sweetbabygirlsummerfun2.free',
#  'http://localhost:3000/api/apps/mahjong.games.mahjong.classic.free',
#  'http://localhost:3000/api/apps/com.taplane.logoquiz',
#  'http://localhost:3000/api/apps/com.dolphingames.us.police.prisoner.transport.bus.driving',
#  'http://localhost:3000/api/apps/io.voodoo.paper2',
#  'http://localhost:3000/api/apps/com.studiowildcard.wardrumstudios.ark',
#  'http://localhost:3000/api/apps/desktop.colorbynumbers.pixelmoon',
#  'http://localhost:3000/api/apps/com.lego.superheroes.dccomicsmightymicros',
#  'http://localhost:3000/api/apps/com.langqi.myshoppingmall',
#  'http://localhost:3000/api/apps/com.combineinc.streetracing.driftthreeD',
#  'http://localhost:3000/api/apps/com.bleacherreport.android.teamstream',
#  'http://localhost:3000/api/apps/com.games2win.drivingacademy2',
#  'http://localhost:3000/api/apps/com.tinybeans',
#  'http://localhost:3000/api/apps/com.grand.prison.escape.game',
#  'http://localhost:3000/api/apps/com.pennypop.dance',
#  'http://localhost:3000/api/apps/net.peakgames.mobile.spades.android',
#  'http://localhost:3000/api/apps/com.tellurionmobile.realmcraft',
#  'http://localhost:3000/api/apps/com.robot.ring.fighting',
#  'http://localhost:3000/api/apps/com.brokendiamond.car.parking.games.offroad.glory',
#  'http://localhost:3000/api/apps/com.upmc.enterprises.myupmc',
#  'http://localhost:3000/api/apps/net.mobigame.zombietsunami',
#  'http://localhost:3000/api/apps/mytown.home',
#  'http://localhost:3000/api/apps/com.google.android.projection.gearhead',
#  'http://localhost:3000/api/apps/com.brainium.spiderfree',
#  'http://localhost:3000/api/apps/easy.sudoku.puzzle.solver.free',
#  'http://localhost:3000/api/apps/com.mgc.miami.crime.simulator.two',
#  'http://localhost:3000/api/apps/com.tacobell.ordering',
#  'http://localhost:3000/api/apps/com.mhlhdmi.two',
#  'http://localhost:3000/api/apps/com.crowdstar.covetHome',
#  'http://localhost:3000/api/apps/com.overdrive.mobile.android.libby',
#  'http://localhost:3000/api/apps/com.jardogs.fmhmobile',
#  'http://localhost:3000/api/apps/com.lego.duplo.trains',
#  'http://localhost:3000/api/apps/dk.resound.smart3d',
#  'http://localhost:3000/api/apps/com.andromo.dev628657.app764218',
#  'http://localhost:3000/api/apps/com.optum.rx',
#  'http://localhost:3000/api/apps/aasuited.net.word',
#  'http://localhost:3000/api/apps/com.amanotes.db',
#  'http://localhost:3000/api/apps/com.amazon.tahoe',
#  'http://localhost:3000/api/apps/com.learn.bibliavalera',
#  'http://localhost:3000/api/apps/com.babycare.grow.feeding.pregnancy.tracker',
#  'http://localhost:3000/api/apps/com.wifiaudio.FABRIQ',
#  'http://localhost:3000/api/apps/com.eyup.MeowMusic',
#  'http://localhost:3000/api/apps/com.mobilityware.freecell',
#  'http://localhost:3000/api/apps/com.e3games.numbercoloring.pixelart',
#  'http://localhost:3000/api/apps/com.mizo.moto.bike.racing',
#  'http://localhost:3000/api/apps/com.rovio.angrybirdsgo',
#  'http://localhost:3000/api/apps/kjv.offline.holy.bible.king.james',
#  'http://localhost:3000/api/apps/com.fungames.flightpilot',
#  'http://localhost:3000/api/apps/topringtones.newringtones.sonneries',
#  'http://localhost:3000/api/apps/com.gametime.gametime',
#  'http://localhost:3000/api/apps/mobile.appcq8cCTCGnF',
#  'http://localhost:3000/api/apps/com.PixelStudio',
#  'http://localhost:3000/api/apps/com.diveomedia.little.stories.bedtime.books.kids',
#  'http://localhost:3000/api/apps/com.us.wouldyourather.trivia.adults',
#  'http://localhost:3000/api/apps/br.com.tapps.donotdisturb',
#  'http://localhost:3000/api/apps/com.destotechgames.offroad.horse.taxi.sim',
#  'http://localhost:3000/api/apps/pedometer.stepcounter.calorieburner.pedometerforwalking',
#  'http://localhost:3000/api/apps/com.sched.crosscutfestival2019.single',
#  'http://localhost:3000/api/apps/valencia.magic.selfie.makeup.camer.photo.editor',
#  'http://localhost:3000/api/apps/com.thronerush.mobilekingdomwar',
#  'http://localhost:3000/api/apps/com.samsung.rms.retailagent.proxy',
#  'http://localhost:3000/api/apps/com.soccer.football.fifa.worldcup.mobile.pes',
#  'http://localhost:3000/api/apps/com.ninetyfour.degrees.app',
#  'http://localhost:3000/api/apps/com.metajoy.puzzlegame.dragnmerge',
#  'http://localhost:3000/api/apps/pedometer.steptracker.calorieburner.stepcounter',
#  'http://localhost:3000/api/apps/com.pescapps.gamekids5',
#  'http://localhost:3000/api/apps/com.vblast.flipaclip',
#  'http://localhost:3000/api/apps/periodtracker.pregnancy.ovulationtracker',
#  'http://localhost:3000/api/apps/com.gameloft.android.ANMP.GloftA9HM',
#  'http://localhost:3000/api/apps/com.huddleinc.GoFan',
#  'http://localhost:3000/api/apps/cc.pacer.androidapp',
#  'http://localhost:3000/api/apps/com.notiondigital.biblemania',
#  'http://localhost:3000/api/apps/com.disney.emojimatch_goo',
#  'http://localhost:3000/api/apps/com.seven.eleven.phoenix',
#  'http://localhost:3000/api/apps/com.tocaboca.tocalifeworld',
#  'http://localhost:3000/api/apps/com.google.android.apps.fitness',
#  'http://localhost:3000/api/apps/com.televisa.deportes.android',
#  'http://localhost:3000/api/apps/com.freakingfreegames.crocodile.family.sim',
#  'http://localhost:3000/api/apps/com.ubisoft.dance.justdance2015companion',
#  'http://localhost:3000/api/apps/com.anysoftkeyboard.languagepack.spain',
#  'http://localhost:3000/api/apps/heart.piano.tiles.gacha.gasha',
#  'http://localhost:3000/api/apps/com.tgs.FlashSuperhero.SpeedStar',
#  'http://localhost:3000/api/apps/com.sinyee.babybus.food',
#  'http://localhost:3000/api/apps/com.eyewind.paperone',
#  'http://localhost:3000/api/apps/wp.wattpad',
#  'http://localhost:3000/api/apps/com.funnyplaygames.formulacarinfinity',
#  'http://localhost:3000/api/apps/nano.lab.app.pregmum',
#  'http://localhost:3000/api/apps/com.labstyle.darioandroid',
#  'http://localhost:3000/api/apps/com.iconology.comics',
#  'http://localhost:3000/api/apps/com.pnixgames.bowlingking',
#  'http://localhost:3000/api/apps/com.skgames.trafficrider',
#  'http://localhost:3000/api/apps/com.bigfishgames.fairwaysolitaireuniversalf2pgoogle',
#  'http://localhost:3000/api/apps/anime.face.changer.cartoon.photo_editor',
#  'http://localhost:3000/api/apps/com.easybrain.jigsaw.puzzles',
#  'http://localhost:3000/api/apps/com.recreativestudios.ultimatecornhole3d',
#  'http://localhost:3000/api/apps/spec.com.givling',
#  'http://localhost:3000/api/apps/com.futureappz.passiveincome',
#  'http://localhost:3000/api/apps/com.sleekbit.dormi',
#  'http://localhost:3000/api/apps/com.grdhmae.gameandtoysfamilyfunny',
#  'http://localhost:3000/api/apps/com.rappidstudios.simulatorbattlephysics',
#  'http://localhost:3000/api/apps/com.everythingforpeople.twinefor30days',
#  'http://localhost:3000/api/apps/com.hudl.hudroid',
#  'http://localhost:3000/api/apps/neon.light.photo.editor',
#  'http://localhost:3000/api/apps/com.tester.arejay.tester1',
#  'http://localhost:3000/api/apps/freedom.bubble',
#  'http://localhost:3000/api/apps/com.sinyee.babybus.cosmetology',
#  'http://localhost:3000/api/apps/wb.mobile.cx.client.droid',
#  'http://localhost:3000/api/apps/com.daily.fitness.workout',
#  'http://localhost:3000/api/apps/com.musicheroesrevenge.pianochallenge2',
#  'http://localhost:3000/api/apps/com.crazylabs.hotel.transylvania.adventure',
#  'http://localhost:3000/api/apps/com.mobilityware.TriPeaksFree',
#  'http://localhost:3000/api/apps/com.gamin47.helixmarsh',
#  'http://localhost:3000/api/apps/com.aetna.aetnahealth',
#  'http://localhost:3000/api/apps/com.motionvolt.flipbounce',
#  'http://localhost:3000/api/apps/com.gismart.realpianofree',
#  'http://localhost:3000/api/apps/com.medibang.android.paint.tablet',
#  'http://localhost:3000/api/apps/com.budgestudios.googleplay.BarbieDreamhouse',
#  'http://localhost:3000/api/apps/com.gsn.android.tripeaks',
#  'http://localhost:3000/api/apps/amplified.bible.free.OFFLINE',
#  'http://localhost:3000/api/apps/fr.two4tea.fightlist',
#  'http://localhost:3000/api/apps/com.play.io.police.moto.bike.gangster.chase.games',
#  'http://localhost:3000/api/apps/com.brainapp.alllanguagesquizgame',
#  'http://localhost:3000/api/apps/com.crazylabs.light.it.up',
#  'http://localhost:3000/api/apps/ptv.bein.ui',
#  'http://localhost:3000/api/apps/jp.ne.ibis.ibispaintx.app',
#  'http://localhost:3000/api/apps/com.tinytouchtales.cardthief',
#  'http://localhost:3000/api/apps/com.popcore.foldingblocks',
#  'http://localhost:3000/api/apps/com.crowdcompass.appRlu4oSX2JZ',
#  'http://localhost:3000/api/apps/com.MixerStudio.SuperHearingSecretVoicesRecorderFREE',
#  'http://localhost:3000/api/apps/com.zeptolab.ctr.ads',
#  'http://localhost:3000/api/apps/com.edmtrain.edmtracks',
#  'http://localhost:3000/api/apps/com.saby.babymonitor3g',
#  'http://localhost:3000/api/apps/com.gamestr.city.traffic.taxi.parking.driving.rush',
#  'http://localhost:3000/api/apps/com.doublejump.mergetd',
#  'http://localhost:3000/api/apps/org.pbskids.danieltigerforparents',
#  'http://localhost:3000/api/apps/com.skgames.trafficracer',
#  'http://localhost:3000/api/apps/com.mobirate.rovercraft.gplay',
#  'http://localhost:3000/api/apps/com.mp3musicdownloader607.musica',
#  'http://localhost:3000/api/apps/com.splathaircolor.android',
#  'http://localhost:3000/api/apps/com.shell.sitibv.motorist.america',
#  'http://localhost:3000/api/apps/com.housepaint.game',
#  'http://localhost:3000/api/apps/bestringtones2019.topringtones2020.android',
#  'http://localhost:3000/api/apps/com.spilgames.OperateNow2',
#  'http://localhost:3000/api/apps/com.planetfitness',
#  'http://localhost:3000/api/apps/com.lego.legohouse',
#  'http://localhost:3000/api/apps/com.spreadsong.freebooks',
#  'http://localhost:3000/api/apps/com.cardfree.android.redlobster',
#  'http://localhost:3000/api/apps/com.walmart.sparkCity',
#  'http://localhost:3000/api/apps/com.easymobs.pregnancy',
#  'http://localhost:3000/api/apps/com.playgendary.pinatamasters',
#  'http://localhost:3000/api/apps/com.iboattech.avatar.cute',
#  'http://localhost:3000/api/apps/com.grillgames.guitarrockhero',
#  'http://localhost:3000/api/apps/com.mobirix.fishinghook',
#  'http://localhost:3000/api/apps/com.tutotoons.app.jungleanimalhairsalon2.free',
#  'http://localhost:3000/api/apps/com.equalizer.volume.music.bass.booster.tool',
#  'http://localhost:3000/api/apps/com.g5e.hiddencity.android',
#  'http://localhost:3000/api/apps/cm.pt.barkparent',
#  'http://localhost:3000/api/apps/com.aa.genius.superhero.chilli.mania',
#  'http://localhost:3000/api/apps/com.gameloft.android.ANMP.GloftDYHM',
#  'http://localhost:3000/api/apps/com.ubisoft.redlynx.trialsfrontier.ggp',
#  'http://localhost:3000/api/apps/com.viagogo.consumer.viagogo.playstore',
#  'http://localhost:3000/api/apps/com.hutchgames.hilldash2',
#  'http://localhost:3000/api/apps/com.dunkinbrands.otgo',
#  'http://localhost:3000/api/apps/com.spinmaster.enterprise.colleggtibles',
#  'http://localhost:3000/api/apps/com.ubisoft.dance.JustDance',
#  'http://localhost:3000/api/apps/com.upmaps.skyblocks',
#  'http://localhost:3000/api/apps/com.joyjourney.PianoWhiteGo',
#  'http://localhost:3000/api/apps/com.chic.policelights',
#  'http://localhost:3000/api/apps/com.game.tqsolitaire',
#  'http://localhost:3000/api/apps/com.sandboxol.indiegame.eggwars',
#  'http://localhost:3000/api/apps/com.tencent.wecomic',
#  'http://localhost:3000/api/apps/com.kwalee.looper',
#  'http://localhost:3000/api/apps/com.addictedapp.addicted',
#  'http://localhost:3000/api/apps/com.ffgames.racingincar2',
#  'http://localhost:3000/api/apps/com.brian.marblerace',
#  'http://localhost:3000/api/apps/com.BossDigitalMedia.QuizApp',
#  'http://localhost:3000/api/apps/com.merriamwebster',
#  'http://localhost:3000/api/apps/com.ovz.carscanner',
#  'http://localhost:3000/api/apps/com.sports.live.football.tv',
#  'http://localhost:3000/api/apps/uk.co.yakuto.DartsOfFury',
#  'http://localhost:3000/api/apps/com.contacts1800.ecomapp',
#  'http://localhost:3000/api/apps/com.music.tap.tap.tile',
#  'http://localhost:3000/api/apps/com.talkingparents.tpandroid',
#  'http://localhost:3000/api/apps/com.sec.android.app.shealth',
#  'http://localhost:3000/api/apps/com.netease.ko',
#  'http://localhost:3000/api/apps/com.bamnetworks.mobile.android.ballpark',
#  'http://localhost:3000/api/apps/com.te.speed.boat.racing.challenge',
#  'http://localhost:3000/api/apps/com.xings.angryanimals.city.smasher',
#  'http://localhost:3000/api/apps/com.zakg.scaryteacher.hellgame',
#  'http://localhost:3000/api/apps/com.fungames.blockcraft',
#  'http://localhost:3000/api/apps/com.sinyee.babybus.earthquake',
#  'http://localhost:3000/api/apps/com.haegin.homerunclash',
#  'http://localhost:3000/api/apps/com.eyu.piano',
#  'http://localhost:3000/api/apps/com.standylan.dunkhit',
#  'http://localhost:3000/api/apps/com.kiwi.joyride',
#  'http://localhost:3000/api/apps/com.cerner.iris.play',
#  'http://localhost:3000/api/apps/com.tff2017.android',
#  'http://localhost:3000/api/apps/com.ketchapp.dunkhoop',
#  'http://localhost:3000/api/apps/com.seatgeek.android',
#  'http://localhost:3000/api/apps/bammo.lyft.taxi',
#  'http://localhost:3000/api/apps/com.purefliptix',
#  'http://localhost:3000/api/apps/com.Latest.Fashion.Trends',
#  'http://localhost:3000/api/apps/com.heliogames.westland',
#  'http://localhost:3000/api/apps/com.glu.baseball19',
#  'http://localhost:3000/api/apps/com.kabukgames.igniss',
#  'http://localhost:3000/api/apps/com.injaamuraissassineropixelgun3d',
#  'http://localhost:3000/api/apps/dh3games.doeshelikeme',
#  'http://localhost:3000/api/apps/com.blogspot.euapps.marshmelloalonelauchpad',
#  'http://localhost:3000/api/apps/com.perfectcorp.amb',
#  'http://localhost:3000/api/apps/com.neulion.smartphone.ufc.android',
#  'http://localhost:3000/api/apps/eu.smartpatient.mytherapy',
#  'http://localhost:3000/api/apps/com.mini.sports.world.boxing.tour.game',
#  'http://localhost:3000/api/apps/air.com.aceviral.motox3m',
#  'http://localhost:3000/api/apps/com.ppa.real.shooting.strike',
#  'http://localhost:3000/api/apps/com.gpp.sushibar',
#  'http://localhost:3000/api/apps/com.genesisblue01.verfutbolonlineguia',
#  'http://localhost:3000/api/apps/com.nordcurrent.canteenhd',
#  'http://localhost:3000/api/apps/com.rcgames.megarampfree.carstunts',
#  'http://localhost:3000/api/apps/com.gempro.MahjongEmpires',
#  'http://localhost:3000/api/apps/women.workout.female.fitness',
#  'http://localhost:3000/api/apps/air.com.pixelfederation.diggy',
#  'http://localhost:3000/api/apps/com.rvappstudios.abc_kids_toddler_tracing_phonics',
#  'http://localhost:3000/api/apps/com.ohmgames.chambouletout',
#  'http://localhost:3000/api/apps/com.robuxskymedia.howtogetrobux4.robloxadvice',
#  'http://localhost:3000/api/apps/com.zadeveloper.update.software.play.store.info',
#  'http://localhost:3000/api/apps/com.custom.pickmeup',
#  'http://localhost:3000/api/apps/com.dreamtechstudio.dinotransprtertruck',
#  'http://localhost:3000/api/apps/fr.two4tea.petitbac',
#  'http://localhost:3000/api/apps/com.appstrend.policerobot.speedster.hero',
#  'http://localhost:3000/api/apps/com.brokenreality.bigcapitalist3.android',
#  'http://localhost:3000/api/apps/com.notabasement.mangarock.android.titan',
#  'http://localhost:3000/api/apps/com.ovuline.fertility',
#  'http://localhost:3000/api/apps/com.GachLife.ttricksxx',
#  'http://localhost:3000/api/apps/com.pacific.wildlands',
#  'http://localhost:3000/api/apps/com.dolphingames.fearless.jetski.racing',
#  'http://localhost:3000/api/apps/us.kr.baseballnine',
#  'http://localhost:3000/api/apps/com.home.workout.health.fit.abs',
#  'http://localhost:3000/api/apps/com.blondeagames.art.coloring.book',
#  'http://localhost:3000/api/apps/com.lecohapp.magicmarshmellopianogame',
#  'http://localhost:3000/api/apps/com.kiloo.subwaysurf',
#  'http://localhost:3000/api/apps/com.lemontart.flying.robot.car.transformation',
#  'http://localhost:3000/api/apps/com.tbegames.and.best_monster_racing',
#  'http://localhost:3000/api/apps/com.mindbodyonline.connect',
#  'http://localhost:3000/api/apps/org.blueletterbible.blb',
#  'http://localhost:3000/api/apps/com.onehundredpics.onehundredpicsquiz',
#  'http://localhost:3000/api/apps/com.calm.android',
#  'http://localhost:3000/api/apps/bible.kingjamesbiblelite',
#  'http://localhost:3000/api/apps/com.x3m.tx4',
#  'http://localhost:3000/api/apps/com.femalefitness.workoutwoman.weightloss',
#  'http://localhost:3000/api/apps/com.applisto.appcloner.premium',
#  'http://localhost:3000/api/apps/stretching.stretch.exercises.back',
#  'http://localhost:3000/api/apps/com.ohbibi.sup',
#  'http://localhost:3000/api/apps/loseweight.weightloss.workout.fitness',
#  'http://localhost:3000/api/apps/com.mxtech.ffmpeg.v7_neon',
#  'http://localhost:3000/api/apps/com.banananadco.blackjack',
#  'http://localhost:3000/api/apps/com.dreamlabentertainment.wouldyourather',
#  'http://localhost:3000/api/apps/org.nm.mobile.myNM',
#  'http://localhost:3000/api/apps/com.sevelina.sweetvampire',
#  'http://localhost:3000/api/apps/com.beautysystemsgroup.stylist',
#  'http://localhost:3000/api/apps/com.abcya.android.games',
#  'http://localhost:3000/api/apps/com.youmusic.magictiles',
#  'http://localhost:3000/api/apps/com.free.solitaire.games',
#  'http://localhost:3000/api/apps/com.miniclip.soccerstars',
#  'http://localhost:3000/api/apps/com.gregacucnik.fishingpoints',
#  'http://localhost:3000/api/apps/com.microsoft.microsoftsolitairecollection',
#  'http://localhost:3000/api/apps/com.techhubgames.modern.car.wash.service.driving.school',
#  'http://localhost:3000/api/apps/com.sega.sonicboomandroid',
#  'http://localhost:3000/api/apps/com.deltadental.HealthApp',
#  'http://localhost:3000/api/apps/com.vividseats.android',
#  'http://localhost:3000/api/apps/com.el.ez.marshmello.pianotilesdj',
#  'http://localhost:3000/api/apps/com.calm.deep.meditation',
#  'http://localhost:3000/api/apps/com.physics.sim.game.savecats',
#  'http://localhost:3000/api/apps/com.beachbody.bod',
#  'http://localhost:3000/api/apps/com.bigbluebubble.singingmonsters.full',
#  'http://localhost:3000/api/apps/ocean.nomad.survival.simulator',
#  'http://localhost:3000/api/apps/com.bitmango.go.linepuzzlepipeart',
#  'http://localhost:3000/api/apps/com.bushiroad.en.bangdreamgbp',
#  'http://localhost:3000/api/apps/com.mcdo.mcdonalds',
#  'http://localhost:3000/api/apps/com.foxsports.videogo',
#  'http://localhost:3000/api/apps/com.hutchgames.hotwheels',
#  'http://localhost:3000/api/apps/app.mywed.android',
#  'http://localhost:3000/api/apps/com.bestgame.theimpossiblequiznew',
#  'http://localhost:3000/api/apps/ma.ki.ki',
#  'http://localhost:3000/api/apps/com.bbtv.cwc',
#  'http://localhost:3000/api/apps/com.macrovideo.v380s',
#  'http://localhost:3000/api/apps/com.BestGames.PoliceDriverSimulator',
#  'http://localhost:3000/api/apps/com.labcorp.patientportal',
#  'http://localhost:3000/api/apps/com.luckystars.hairstylesstepbystep',
#  'http://localhost:3000/api/apps/jp.konami.duellinks',
#  'http://localhost:3000/api/apps/com.canva.editor',
#  'http://localhost:3000/api/apps/com.ipsy.mobile.production',
#  'http://localhost:3000/api/apps/com.spilgames.operatenow.animal.hospital',
#  'http://localhost:3000/api/apps/org.findmykids.app',
#  'http://localhost:3000/api/apps/com.police.car.transporter.truck',
#  'http://localhost:3000/api/apps/yamayka.apps.NailsTutorial',
#  'http://localhost:3000/api/apps/com.wendys.nutritiontool',
#  'http://localhost:3000/api/apps/com.pinners2018.mn',
#  'http://localhost:3000/api/apps/com.bitmango.go.bubblepop',
#  'http://localhost:3000/api/apps/com.robtopx.geometryjumplite',
#  'http://localhost:3000/api/apps/com.xs.pooltd',
#  'http://localhost:3000/api/apps/com.mobirix.parkingking',
#  'http://localhost:3000/api/apps/com.myfitnesspal.android',
#  'http://localhost:3000/api/apps/com.cars.android',
#  'http://localhost:3000/api/apps/com.instacart.client',
#  'http://localhost:3000/api/apps/com.babycenter.pregnancytracker',
#  'http://localhost:3000/api/apps/quess.song.music.pop.quiz',
#  'http://localhost:3000/api/apps/com.wombatapps.carbmanager',
#  'http://localhost:3000/api/apps/com.google.vr.cardboard.apps.designlab',
#  'http://localhost:3000/api/apps/com.pixelperfectdude.htdrive',
#  'http://localhost:3000/api/apps/com.tutotoons.app.amysanimalhairsalon.free',
#  'http://localhost:3000/api/apps/com.BabyName.start',
#  'http://localhost:3000/api/apps/com.spilgames.ThrillRush1',
#  'http://localhost:3000/api/apps/com.magicposernew',
#  'http://localhost:3000/api/apps/com.threed.battleground.fire.survival.strike.shooting.game',
#  'http://localhost:3000/api/apps/com.hapogames.FreeCell',
#  'http://localhost:3000/api/apps/com.fiogonia.spades',
#  'http://localhost:3000/api/apps/com.aa.Car.Driving.GT.Stunts.Racing2',
#  'http://localhost:3000/api/apps/com.hatchbaby.rest',
#  'http://localhost:3000/api/apps/com.fgz.us.police.transform.flying.robot.bike.game',
#  'http://localhost:3000/api/apps/uk.free.books.read.listen',
#  'http://localhost:3000/api/apps/com.appgame7.jigsaw.free',
#  'http://localhost:3000/api/apps/com.rappidstudios.simulatorbattle',
#  'http://localhost:3000/api/apps/solitaire.cardgames.solitairegames.free.klondike',
#  'http://localhost:3000/api/apps/trends.beauty.split.camera.collage.maker',
#  'http://localhost:3000/api/apps/com.playgendary.partymasters',
#  'http://localhost:3000/api/apps/com.miniclip.basketballstars',
#  'http://localhost:3000/api/apps/com.americanwell.android.member.wellpoint',
#  'http://localhost:3000/api/apps/com.dl.app.div.dri',
#  'http://localhost:3000/api/apps/com.gameinsight.gplay.mmanor',
#  'http://localhost:3000/api/apps/com.games.ballsout',
#  'http://localhost:3000/api/apps/com.productions.akshitsehgal.planitouteventplanner',
#  'http://localhost:3000/api/apps/emoji.background.photo.editor',
#  'http://localhost:3000/api/apps/com.sirma.mobile.bible.android',
#  'http://localhost:3000/api/apps/com.concretesoftware.golf',
#  'http://localhost:3000/api/apps/com.mtib.bloomsday',
#  'http://localhost:3000/api/apps/com.umi.feudlive',
#  'http://localhost:3000/api/apps/com.smilerlee.klondike',
#  'http://localhost:3000/api/apps/com.wb.goog.hothands',
#  'http://localhost:3000/api/apps/com.manualslib.app',
#  'http://localhost:3000/api/apps/com.africanwomenhairstyle.lonodev',
#  'http://localhost:3000/api/apps/io.voodoo.holeio',
#  'http://localhost:3000/api/apps/com.noodlecake.ssg4',
#  'http://localhost:3000/api/apps/com.brilliantgamez.us.army.flying.horse.unicorn.robot',
#  'http://localhost:3000/api/apps/com.darden.mobile.olivegarden',
#  'http://localhost:3000/api/apps/com.cocoplay.gymnastics.acrobat',
#  'http://localhost:3000/api/apps/com.crazylabs.tricky.traps.game',
#  'http://localhost:3000/api/apps/com.spungegames.failybrakes',
#  'http://localhost:3000/api/apps/com.eyesthegame.eyes',
#  'http://localhost:3000/api/apps/com.grand.robot.transform.tech.comic.topusrobot.policecarshooting.transform.cityrescue.battle.game',
#  'http://localhost:3000/api/apps/leagueofmonkeys.torqueburnout',
#  'http://localhost:3000/api/apps/com.pictarine.photoprint',
#  'http://localhost:3000/api/apps/com.Nightingale.Solitaire.Card.Games.Free',
#  'http://localhost:3000/api/apps/com.freeletics.lite',
#  'http://localhost:3000/api/apps/com.naver.linewebtoon',
#  'http://localhost:3000/api/apps/macrostudios.howwelldoyouknowme',
#  'http://localhost:3000/api/apps/com.parking.game',
#  'http://localhost:3000/api/apps/com.greetingsisland.sam',
#  'http://localhost:3000/api/apps/com.gvapps.psychologyfacts',
#  'http://localhost:3000/api/apps/com.postmates.android',
#  'http://localhost:3000/api/apps/com.tutotoons.app.sweetbabygirlmermaidlife.free',
#  'http://localhost:3000/api/apps/com.dolphingames.monstertruck.crashstunts',
#  'http://localhost:3000/api/apps/com.StefMorojna.SpaceflightSimulator',
#  'http://localhost:3000/api/apps/com.playgendary.tanks',
#  'http://localhost:3000/api/apps/com.caremark.caremark',
#  'http://localhost:3000/api/apps/com.vrchat.anime.avatars.online',
#  'http://localhost:3000/api/apps/com.gigago.wild.elephant.family.survival',
#  'http://localhost:3000/api/apps/com.pianomarshmello.pianotilesdj',
#  'http://localhost:3000/api/apps/com.shophush.hush',
#  'http://localhost:3000/api/apps/com.webruli.edmdjgame',
#  'http://localhost:3000/api/apps/com.gohopscotch.android.ticketpop',
#  'http://localhost:3000/api/apps/trends.beauty.sweet.snap',
#  'http://localhost:3000/api/apps/com.apc.impossible.mega.dangerous.ramp.stunt',
#  'http://localhost:3000/api/apps/com.opentable',
#  'http://localhost:3000/api/apps/com.theathletic',
#  'http://localhost:3000/api/apps/com.tap2fun.survivor.prision.escape.breakthejail.prisonstorm',
#  'http://localhost:3000/api/apps/com.ss.smart.police.car.parking.mania',
#  'http://localhost:3000/api/apps/com.google.samples.apps.cardboarddemo',
#  'http://localhost:3000/api/apps/org.nanobit.mystory',
#  'http://localhost:3000/api/apps/com.sinyee.babybus.toilet',
#  'http://localhost:3000/api/apps/air.com.spilgames.trollfacequesthorror2.scary.adventure',
#  'http://localhost:3000/api/apps/com.mobirix.throwball',
#  'http://localhost:3000/api/apps/com.sandbox.numbercoloring.pixelart',
#  'http://localhost:3000/api/apps/net.peakgames.ginrummyplus',
#  'http://localhost:3000/api/apps/games.mini.sports.soccer.revolution',
#  'http://localhost:3000/api/apps/com.subway.mobile.subwayapp03',
#  'http://localhost:3000/api/apps/com.connection.wireless.wirelessconnectortv',
#  'http://localhost:3000/api/apps/com.mobilityware.PyramidFree',
#  'http://localhost:3000/api/apps/com.teamapp.teamapp',
#  'http://localhost:3000/api/apps/com.drugscom.app',
#  'http://localhost:3000/api/apps/com.hp.babyapp',
#  'http://localhost:3000/api/apps/com.sonic.sonicdrivein',
#  'http://localhost:3000/api/apps/com.sec.penup',
#  'http://localhost:3000/api/apps/com.wb.goog.ellen.gameofgames',
#  'http://localhost:3000/api/apps/com.hdmi.app',
#  'http://localhost:3000/api/apps/com.etermax.preguntados.lite',
#  'http://localhost:3000/api/apps/com.garmin.android.apps.connectmobile',
#  'http://localhost:3000/api/apps/com.fanduel.android.self',
#  'http://localhost:3000/api/apps/com.drpanda.restaurant3',
#  'http://localhost:3000/api/apps/com.amanotes.pamainfinitybounce',
#  'http://localhost:3000/api/apps/com.XTechStudios.snakeIO',
#  'http://localhost:3000/api/apps/com.sega.sonicdash',
#  'http://localhost:3000/api/apps/com.papajohns.android',
#  'http://localhost:3000/api/apps/com.ansangha.drdriving',
#  'http://localhost:3000/api/apps/evolution.music.tiles.challenge',
#  'http://localhost:3000/api/apps/archery.elite.shooting.free.game.android',
#  'http://localhost:3000/api/apps/city.russ.alltrackerfamily',
#  'http://localhost:3000/api/apps/sba.english.spanish',
#  'http://localhost:3000/api/apps/com.robot.speed.hero',
#  'http://localhost:3000/api/apps/com.crowdcomms.elements',
#  'http://localhost:3000/api/apps/com.mashaapps.Happy.Birthday.songs.NamePhotooncake',
#  'http://localhost:3000/api/apps/com.sonypicturestelevision.millionaire',
#  'http://localhost:3000/api/apps/com.lemongame.klondike.solitaire',
#  'http://localhost:3000/api/apps/com.tailskinsear',
#  'http://localhost:3000/api/apps/com.aa.extreme.city.gt.car.stunts',
#  'http://localhost:3000/api/apps/com.ovuline.pregnancy',
#  'http://localhost:3000/api/apps/com.playmini.miniworld',
#  'http://localhost:3000/api/apps/lemmingsatwork.quiz',
#  'http://localhost:3000/api/apps/com.carmax.carmax',
#  'http://localhost:3000/api/apps/com.deercatgames.tunnelrush',
#  'http://localhost:3000/api/apps/com.sir.racing.ultimatecardrivingsimulator',
#  'http://localhost:3000/api/apps/com.piupiuapps.hairstyles',
#  'http://localhost:3000/api/apps/com.tgs.AirPortSimulator.GroundFlightStaff',
#  'http://localhost:3000/api/apps/games.mini.sports.bodybuilder.fighting.gym',
#  'http://localhost:3000/api/apps/mhl2.tvcon.nector.hmi',
#  'http://localhost:3000/api/apps/com.tinyco.potter',
#  'http://localhost:3000/api/apps/com.amanotes.beathopper',
#  'http://localhost:3000/api/apps/com.uefa.ucl',
#  'http://localhost:3000/api/apps/com.herogame.gplay.magicminecraft.mmorpg',
#  'http://localhost:3000/api/apps/com.specialyg.ippro3',
#  'http://localhost:3000/api/apps/com.game.jadedclan.trainsimgames',
#  'http://localhost:3000/api/apps/dto.ee.dmv.genius',
#  'http://localhost:3000/api/apps/com.barabapps.drinkjuicejoke',
#  'http://localhost:3000/api/apps/com.swagmasha.genres',
#  'http://localhost:3000/api/apps/org.rethinkgroup.ocattendee',
#  'http://localhost:3000/api/apps/com.doctorondemand.android.patient',
#  'http://localhost:3000/api/apps/solitaire.card.games.free.klondike.solitaire.fishdom.fish',
#  'http://localhost:3000/api/apps/com.deliveryclub',
#  'http://localhost:3000/api/apps/com.dominospizza',
#  'http://localhost:3000/api/apps/com.audubon.mobile.android',
#  'http://localhost:3000/api/apps/com.untappdllc.app',
#  'http://localhost:3000/api/apps/com.mealime',
#  'http://localhost:3000/api/apps/com.sony.psexp2016',
#  'http://localhost:3000/api/apps/com.jackintheboxinc.JackMobileApp',
#  'http://localhost:3000/api/apps/com.venuenext.churchilldowns',
#  'http://localhost:3000/api/apps/com.selfhealing.chakrasnumber1',
#  'http://localhost:3000/api/apps/com.dodreams.driveahead',
#  'http://localhost:3000/api/apps/com.horseplayertoolkit.horseplayer',
#  'http://localhost:3000/api/apps/com.spilgames.UphillRush',
#  'http://localhost:3000/api/apps/us.hiphopbeatmaker.xxxtentacion',
#  'http://localhost:3000/api/apps/com.huckleberry_labs.app',
#  'http://localhost:3000/api/apps/google.free.icequeen.peachygamesllc',
#  'http://localhost:3000/api/apps/com.carvana.carvana',
#  'http://localhost:3000/api/apps/com.ftt.boxingstar.gl.aos',
#  'http://localhost:3000/api/apps/light.crown.face.camera',
#  'http://localhost:3000/api/apps/com.freakingfreegames.anaconda.snake.sim',
#  'http://localhost:3000/api/apps/com.zocdoc.android',
#  'http://localhost:3000/api/apps/com.orange.coloring.learn.kids',
#  'http://localhost:3000/api/apps/com.concretesoftware.rapala',
#  'http://localhost:3000/api/apps/com.mobilityware.spider',
#  'http://localhost:3000/api/apps/com.leodesol.games.classic.maze.labyrinth',
#  'http://localhost:3000/api/apps/com.mw.adultblock',
#  'http://localhost:3000/api/apps/net.peakgames.toonblast',
#  'http://localhost:3000/api/apps/com.Meromsoft.SchoolGirlsSimulator',
#  'http://localhost:3000/api/apps/com.quizup.core',
#  'http://localhost:3000/api/apps/com.GoldHelmGames.MasterBassAngler',
#  'http://localhost:3000/api/apps/unicorn.white.pink.piano.tiles',
#  'http://localhost:3000/api/apps/com.KidsFreeGame.Piano.Rhymes.Rhymes',
#  'http://localhost:3000/api/apps/com.grubhub.android',
#  'http://localhost:3000/api/apps/com.yhi.real.cruise.ship.transport.simulator.driving.game',
#  'http://localhost:3000/api/apps/com.ea.gp.nbamobile',
#  'http://localhost:3000/api/apps/com.frenzygames.motorbike.beach.stunts.master',
#  'http://localhost:3000/api/apps/com.music.game.bluesky.fnaf',
#  'http://localhost:3000/api/apps/com.Home.Diy.Ideas',
#  'http://localhost:3000/api/apps/com.bilkon.easypiano',
#  'http://localhost:3000/api/apps/com.mapmywalk.android2',
#  'http://localhost:3000/api/apps/com.tutotoons.app.sweetbabygirlcleanup6.free',
#  'http://localhost:3000/api/apps/com.usbconnector.totvhdmi',
#  'http://localhost:3000/api/apps/com.resmed.myair',
#  'http://localhost:3000/api/apps/com.right.to.develop.jungle.commando.Shooter.game',
#  'http://localhost:3000/api/apps/com.ludia.jurassicworld',
#  'http://localhost:3000/api/apps/com.bigneon.mobile',
#  'http://localhost:3000/api/apps/com.audible.application',
#  'http://localhost:3000/api/apps/game.puzzle.blockpuzzle',
#  'http://localhost:3000/api/apps/com.superbinogo.jungleboyadventure',
#  'http://localhost:3000/api/apps/com.ayogamez.sketchcartoon',
#  'http://localhost:3000/api/apps/sixpack.sixpackabs.absworkout',
#  'http://localhost:3000/api/apps/org.nanobit.hollywood',
#  'http://localhost:3000/api/apps/com.magmic.android.squash',
#  'http://localhost:3000/api/apps/com.sega.sprint',
#  'http://localhost:3000/api/apps/com.budgestudios.googleplay.ThomasAndFriendsMagicalTracks',
#  'http://localhost:3000/api/apps/com.colorup.game',
#  'http://localhost:3000/api/apps/com.gamesbypost.spadescardclassic',
#  'http://localhost:3000/api/apps/com.bigframes.color_road',
#  'http://localhost:3000/api/apps/com.Fashion.Nails.Girls.Game',
#  'http://localhost:3000/api/apps/com.materialviewinc.drawcutefamous',
#  'http://localhost:3000/api/apps/com.audiobooks.androidapp',
#  'http://localhost:3000/api/apps/com.missileattack.ultimatewar.truckgames.jk',
#  'http://localhost:3000/api/apps/com.instacart.client.publix',
#  'http://localhost:3000/api/apps/smartowlapps.com.quiz360',
#  'http://localhost:3000/api/apps/com.todaytix.TodayTix',
#  'http://localhost:3000/api/apps/com.amitech.allevents',
#  'http://localhost:3000/api/apps/com.cy.blaze.fantasy',
#  'http://localhost:3000/api/apps/solitaire.solitairemaker.solitaire.klondike.card',
#  'http://localhost:3000/api/apps/an.SpanishTranslate',
#  'http://localhost:3000/api/apps/com.blogspot.euapps.marshmelloalonelaunchpad',
#  'http://localhost:3000/api/apps/com.ndemiccreations.rebelinc',
#  'http://localhost:3000/api/apps/com.freegame.solitaire.basic2',
#  'http://localhost:3000/api/apps/com.wgt.android.golf',
#  'http://localhost:3000/api/apps/com.baritastic.view',
#  'http://localhost:3000/api/apps/com.getsomeheadspace.android',
#  'http://localhost:3000/api/apps/com.rotation5.smoresup',
#  'http://localhost:3000/api/apps/com.sephora',
#  'http://localhost:3000/api/apps/com.mytona.seekersnotes.android',
#  'http://localhost:3000/api/apps/ru.mobiledimension.kbr',
#  'http://localhost:3000/api/apps/com.jamesots.android.contractiontimer',
#  'http://localhost:3000/api/apps/com.bigcake.android.solitairedaily',
#  'http://localhost:3000/api/apps/com.escapefun.the100roomiv',
#  'http://localhost:3000/api/apps/com.colorjoy.Learn.to.draw.glow.cartoon',
#  'http://localhost:3000/api/apps/de.motain.iliga',
#  'http://localhost:3000/api/apps/androidgecko.com.himommy',
#  'http://localhost:3000/api/apps/losebellyfat.flatstomach.absworkout.fatburning',
#  'http://localhost:3000/api/apps/com.gs.city.police.car.prisoners.transport',
#  'http://localhost:3000/api/apps/com.yhi.police.truck.city.cop.extreme.real.gangster.chase',
#  'http://localhost:3000/api/apps/com.kasacapital.bitesquad',
#  'http://localhost:3000/api/apps/org.nyulmc.clinical.mychart',
#  'http://localhost:3000/api/apps/com.fitnow.loseit',
#  'http://localhost:3000/api/apps/com.sinyee.babybus.homesafe.global',
#  'http://localhost:3000/api/apps/com.doubletapsoftware.basketballbattle',
#  'http://localhost:3000/api/apps/light.crown.editor',
#  'http://localhost:3000/api/apps/com.wellpoint.consumer.ABCBS',
#  'http://localhost:3000/api/apps/com.notdoppler.earntodie2',
#  'http://localhost:3000/api/apps/com.alltrails.alltrails',
#  'http://localhost:3000/api/apps/com.notdoppler.crashofcars',
#  'http://localhost:3000/api/apps/com.puzzles.game.fd.two',
#  'http://localhost:3000/api/apps/net.braincake.pixl.pixl',
#  'http://localhost:3000/api/apps/com.us.wouldyourather.trivia.quiz',
#  'http://localhost:3000/api/apps/com.teamsnap.teamsnap',
#  'http://localhost:3000/api/apps/com.evilclicker.evilclicker',
#  'http://localhost:3000/api/apps/com.iposedon.bricksbreakerballs',
#  'http://localhost:3000/api/apps/games.wsa.tag.team.wrestling',
#  'http://localhost:3000/api/apps/com.zlamanit.blood.pressure',
#  'http://localhost:3000/api/apps/com.YovoGames.babycare',
#  'http://localhost:3000/api/apps/com.threed.bowling',
#  'http://localhost:3000/api/apps/com.tensquaregames.letsfish2',
#  'http://localhost:3000/api/apps/com.matchington.mansion',
#  'http://localhost:3000/api/apps/com.frogmind.rumblestars',
#  'http://localhost:3000/api/apps/com.vitusvet.android',
#  'http://localhost:3000/api/apps/com.msint.weddingplanner',
#  'http://localhost:3000/api/apps/org.jw.jwevent',
#  'http://localhost:3000/api/apps/net.mobilecraft.realbasketball',
#  'http://localhost:3000/api/apps/com.stubhub',
#  'http://localhost:3000/api/apps/com.frenzygames.fgs.offroad.farm.animal.transport.trailer.truck',
#  'http://localhost:3000/api/apps/com.boombitgames.DrivingSchoolParking',
#  'http://localhost:3000/api/apps/com.neighbfav.neighborfavor',
#  'http://localhost:3000/api/apps/com.funnyplaygames.monstertruck.real',
#  'http://localhost:3000/api/apps/order.food.online.delivery.offers.deals',
#  'http://localhost:3000/api/apps/pl.planmieszkania.android',
#  'http://localhost:3000/api/apps/com.optimumbrewlab.invitationcardmaker',
#  'http://localhost:3000/api/apps/game.puzzle.woodypuzzle',
#  'http://localhost:3000/api/apps/com.hdmimhlll.miirrortotv',
#  'http://localhost:3000/api/apps/com.amazon.awsmarketingevents',
#  'http://localhost:3000/api/apps/invaders.os.galaxy.space.shooter.attack.classic',
#  'http://localhost:3000/api/apps/com.july.univision',
#  'http://localhost:3000/api/apps/com.freakingfreegames.miami.beach.car.driver',
#  'http://localhost:3000/api/apps/com.macrovideo.v380pro',
#  'http://localhost:3000/api/apps/com.naturalmotion.clumsyninja',
#  'http://localhost:3000/api/apps/com.hdmii.tvconnecttorr',
#  'http://localhost:3000/api/apps/com.chic.blacklight',
#  'http://localhost:3000/api/apps/com.amanotes.galaxyrun',
#  'http://localhost:3000/api/apps/com.becloser',
#  'http://localhost:3000/api/apps/com.tomdxs.symago',
#  'http://localhost:3000/api/apps/com.futureplay.boots',
#  'http://localhost:3000/api/apps/com.secretexit.turbodismount',
#  'http://localhost:3000/api/apps/hdmi.connector.five',
#  'http://localhost:3000/api/apps/co.qeepsake.qeepsakeApp',
#  'http://localhost:3000/api/apps/com.tutotoons.app.kikififihalloweensalon.free',
#  'http://localhost:3000/api/apps/com.beinsports.andcontent',
#  'http://localhost:3000/api/apps/com.waitrapp',
#  'http://localhost:3000/api/apps/se.ace.fishinc',
#  'http://localhost:3000/api/apps/com.dazn',
#  'http://localhost:3000/api/apps/com.os.colorball.push',
#  'http://localhost:3000/api/apps/com.bamnetworks.mobile.android.gameday.atbat',
#  'http://localhost:3000/api/apps/com.upjers.zoo2animalpark',
#  'http://localhost:3000/api/apps/com.dropdom.blockpuzzle.hwwgame',
#  'http://localhost:3000/api/apps/org.lds.ldssa',
#  'http://localhost:3000/api/apps/logoquiz.netiapps.com.logoquiz',
#  'http://localhost:3000/api/apps/com.freepuzzlegames.logoguessing.quiz',
#  'http://localhost:3000/api/apps/com.danpanichev.kmk',
#  'http://localhost:3000/api/apps/com.netease.lztgglobal',
#  'http://localhost:3000/api/apps/com.jima.car.stuntmaster.impossibletracks',
#  'http://localhost:3000/api/apps/com.gc.multi.transforming.jet.robots.war',
#  'http://localhost:3000/api/apps/com.gyatq.zsenbb',
#  'http://localhost:3000/api/apps/com.and.games505.Terraria',
#  'http://localhost:3000/api/apps/com.yummly.android',
#  'http://localhost:3000/api/apps/com.tpvapps.simpledrumsrock',
#  'http://localhost:3000/api/apps/com.hellofresh.androidapp',
#  'http://localhost:3000/api/apps/com.hwg.idlepainter',
#  'http://localhost:3000/api/apps/com.bytestorm.artflow',
#  'http://localhost:3000/api/apps/com.tiramisu.driftmax2',
#  'http://localhost:3000/api/apps/fitness.loseweight.absworkout.women',
#  'http://localhost:3000/api/apps/com.chipotle.ordering',
#  'http://localhost:3000/api/apps/com.overdrive.mobile.android.mediaconsole',
#  'http://localhost:3000/api/apps/com.clue.android',
#  'http://localhost:3000/api/apps/com.masomo.headball2',
#  'http://localhost:3000/api/apps/com.magjg.roundhit',
#  'http://localhost:3000/api/apps/com.mattel.thomasbigadventure',
#  'http://localhost:3000/api/apps/com.obikecoco.bubbleshootergame.pandaFirefox',
#  'http://localhost:3000/api/apps/com.energysh.drawshow',
#  'http://localhost:3000/api/apps/com.robtopx.geometrydashsubzero',
#  'http://localhost:3000/api/apps/com.prettysimple.cctheconspiracyandroid',
#  'http://localhost:3000/api/apps/com.playway.cms2017',
#  'http://localhost:3000/api/apps/yamayka.apps.BeautifulHairstyle',
#  'http://localhost:3000/api/apps/kjv.bible.kingjamesbible',
#  'http://localhost:3000/api/apps/com.bentostudio.ballsvsblocks',
#  'http://localhost:3000/api/apps/com.spotlightsix.zentimerlite2',
#  'http://localhost:3000/api/apps/com.mylaps.eventapp.sporthivelive',
#  'http://localhost:3000/api/apps/com.appclose.androidapp',
#  'http://localhost:3000/api/apps/com.fuzzymobilegames.spades',
#  'http://localhost:3000/api/apps/com.generamobile.logomania',
#  'http://localhost:3000/api/apps/com.winrgames.solitaire',
#  'http://localhost:3000/api/apps/com.glow.android.nurture',
#  'http://localhost:3000/api/apps/com.fishbrain.app',
#  'http://localhost:3000/api/apps/com.xacte.eventapp.indymini',
#  'http://localhost:3000/api/apps/dk.spatifo.dublo',
#  'http://localhost:3000/api/apps/com.clearcare.clearcareconnect',
#  'http://localhost:3000/api/apps/com.evertechsandbox',
#  'http://localhost:3000/api/apps/com.firsttouchgames.smp',
#  'http://localhost:3000/api/apps/com.mastercomlimited.cardriving_t',
#  'http://localhost:3000/api/apps/com.absolute.bingo',
#  'http://localhost:3000/api/apps/com.brokenreality.planemerger.android',
#  'http://localhost:3000/api/apps/com.tutotoons.app.sweetbabygirlcleanup5.free',
#  'http://localhost:3000/api/apps/com.coparenter.coparenterandroid',
#  'http://localhost:3000/api/apps/com.emn8.mobilem8.nativeapp.popeyes',
#  'http://localhost:3000/api/apps/com.virtualsim.mega.ramp.bmx.bike.racing',
#  'http://localhost:3000/api/apps/com.mindy.grap1',
#  'http://localhost:3000/api/apps/com.glow.android.baby',
#  'http://localhost:3000/api/apps/com.firsttouchgames.story',
#  'http://localhost:3000/api/apps/com.sched',
#  'http://localhost:3000/api/apps/com.makeup3d.camera.photo.editor',
#  'http://localhost:3000/api/apps/com.king.bubblewitch3',
#  'http://localhost:3000/api/apps/com.tvazteca.deportes',
#  'http://localhost:3000/api/apps/com.ea.gp.fifamobile',
#  'http://localhost:3000/api/apps/uk.co.aifactory.spadesfree',
#  'http://localhost:3000/api/apps/com.playstation.knowledge',
#  'http://localhost:3000/api/apps/com.amazon.kindle',
#  'http://localhost:3000/api/apps/com.chickfila.cfaflagship',
#  'http://localhost:3000/api/apps/com.ludia.jw2',
#  'http://localhost:3000/api/apps/com.hutchgames.cccg',
#  'http://localhost:3000/api/apps/com.extreme.games.production.offroad.mud.truck.simulator.truckdrive',
#  'http://localhost:3000/api/apps/com.love.poly.puzzle.game',
#  'http://localhost:3000/api/apps/com.webcomics.manga',
#  'http://localhost:3000/api/apps/com.NikSanTech.FireDots3D',
#  'http://localhost:3000/api/apps/com.ada.app',
#  'http://localhost:3000/api/apps/es.socialpoint.MonsterLegends',
#  'http://localhost:3000/api/apps/com.birchbox.birchbox',
#  'http://localhost:3000/api/apps/com.ea.game.pegglex_row',
#  'http://localhost:3000/api/apps/com.ndonna.plantesmedicinales',
#  'http://localhost:3000/api/apps/com.scimob.ninetyfour.percent',
#  'http://localhost:3000/api/apps/com.drivetime.MobileOnline',
#  'http://localhost:3000/api/apps/com.alubuski.hairstylestepbystep',
#  'http://localhost:3000/api/apps/com.goodbaby.babycam',
#  'http://localhost:3000/api/apps/com.hypermania.crush.soft.things',
#  'http://localhost:3000/api/apps/com.adobe.spark.post',
#  'http://localhost:3000/api/apps/com.hp.pregnancy.lite',
#  'http://localhost:3000/api/apps/com.nbstudio.towercolor',
#  'http://localhost:3000/api/apps/com.supertapx.drawin',
#  'http://localhost:3000/api/apps/com.fortune.sim.game.cash',
#  'http://localhost:3000/api/apps/com.revolverolver.fliptrickster',
#  'http://localhost:3000/api/apps/air.Air4Android',
#  'http://localhost:3000/api/apps/com.gigantic.clawee',
#  'http://localhost:3000/api/apps/com.infokombinat.hairstyle2',
#  'http://localhost:3000/api/apps/com.bodyfast',
#  'http://localhost:3000/api/apps/com.sinyee.babybus.shopping',
#  'http://localhost:3000/api/apps/com.szyk.myheart',
#  'http://localhost:3000/api/apps/com.buzzfeed.tasty',
#  'http://localhost:3000/api/apps/com.miniclip.eightballpool',
#  'http://localhost:3000/api/apps/com.Trendoutfits.ForGirls',
#  'http://localhost:3000/api/apps/dk.mymovies.mymoviesforandroidfree',
#  'http://localhost:3000/api/apps/com.orangenose.trick',
#  'http://localhost:3000/api/apps/com.upjers.newzealandfarmer',
#  'http://localhost:3000/api/apps/com.sportngin.android',
#  'http://localhost:3000/api/apps/com.BestGames.FlyingCarSimulatorDriver',
#  'http://localhost:3000/api/apps/com.rimkah.zedg',
#  'http://localhost:3000/api/apps/com.battlecreek.offroadoutlaws',
#  'http://localhost:3000/api/apps/com.noahcube.ufoio',
#  'http://localhost:3000/api/apps/com.differencetenderwhite.skirt',
#  'http://localhost:3000/api/apps/com.jagex.oldscape.android',
#  'http://localhost:3000/api/apps/com.brightsolid.trivialist',
#  'http://localhost:3000/api/apps/com.gc.teammanager',
#  'http://localhost:3000/api/apps/com.gmail.troylyndon.PlayTrivia',
#  'http://localhost:3000/api/apps/us.kr.baseball',
#  'http://localhost:3000/api/apps/com.bluewizard.f13puzzle',
#  'http://localhost:3000/api/apps/com.modiface.clairol.myshade',
#  'http://localhost:3000/api/apps/com.virtualsim.bike.car.robot.transform',
#  'http://localhost:3000/api/apps/com.panga.robot.wolf.hero.city.rampage',
#  'http://localhost:3000/api/apps/com.FDGEntertainment.redball4.gp',
#  'http://localhost:3000/api/apps/easy.drum.set.free.finger.drums.kit',
#  'http://localhost:3000/api/apps/com.nianticlabs.pokemongo',
#  'http://localhost:3000/api/apps/com.sevelina.icywedding',
#  'http://localhost:3000/api/apps/f2game.bubbleshooter.pandapop',
#  'http://localhost:3000/api/apps/com.laneone.consumer',
#  'http://localhost:3000/api/apps/com.ntg.solitaire.witch',
#  'http://localhost:3000/api/apps/com.dexcom.g6',
#  'http://localhost:3000/api/apps/com.supertapx.lovedots',
#  'http://localhost:3000/api/apps/com.littlecaesars',
#  'http://localhost:3000/api/apps/com.app.magicmoneyguest',
#  'http://localhost:3000/api/apps/com.musicpoweredgames.muzarcade',
#  'http://localhost:3000/api/apps/com.riseup.game',
#  'http://localhost:3000/api/apps/com.sentry.parental',
#  'http://localhost:3000/api/apps/com.freegame.mergeall',
#  'http://localhost:3000/api/apps/mytown.police',
#  'http://localhost:3000/api/apps/io.voodoo.crowdcity',
#  'http://localhost:3000/api/apps/com.robot.water.slide',
#  'http://localhost:3000/api/apps/com.goodrx',
#  'http://localhost:3000/api/apps/com.overwolf.statsroyale',
#  'http://localhost:3000/api/apps/air.com.nbcuni.com.nbcsports.liveextra',
#  'http://localhost:3000/api/apps/com.ketchapp.screamhero',
#  'http://localhost:3000/api/apps/com.bonibon.LongNails',
#  'http://localhost:3000/api/apps/com.wb.goog.sdmc',
#  'http://localhost:3000/api/apps/com.nbcuni.usie.seriesendless',
#  'http://localhost:3000/api/apps/com.prodigygame.prodigy',
#  'http://localhost:3000/api/apps/com.area120.studybuddy.sagaflutter',
#  'http://localhost:3000/api/apps/galaxys9ringtones.ringtonesfors9.notifications',
#  'http://localhost:3000/api/apps/com.trove',
#  'http://localhost:3000/api/apps/com.robtopx.geometrydashworld',
#  'http://localhost:3000/api/apps/com.xmonetize.quizzland',
#  'http://localhost:3000/api/apps/fluddokt.opsu.android',
#  'http://localhost:3000/api/apps/com.freerange.goosebumps',
#  'http://localhost:3000/api/apps/com.bello.shootingworld',
#  'http://localhost:3000/api/apps/com.edujoy.masha.games',
#  'http://localhost:3000/api/apps/com.codigames.market.idle.tycoon',
#  'http://localhost:3000/api/apps/filter.selfie.camera.photo.stickers',
#  'http://localhost:3000/api/apps/com.yiyou.game.newtricky',
#  'http://localhost:3000/api/apps/ma.oh.na',
#  'http://localhost:3000/api/apps/com.tmobile.familycontrols',
#  'http://localhost:3000/api/apps/com.adobe.creativeapps.sketch',
#  'http://localhost:3000/api/apps/com.bitguardian.parentalcontrol',
#  'http://localhost:3000/api/apps/com.vive.riderleague',
#  'http://localhost:3000/api/apps/com.surpriselol.lol',
#  'http://localhost:3000/api/apps/com.siplay.android_siplay',
#  'http://localhost:3000/api/apps/com.ticticgames.coloringbnails1',
#  'http://localhost:3000/api/apps/com.panga.shark.simulator.beach.sea.attack',
#  'http://localhost:3000/api/apps/com.rgs.grandmegaramp.mafiacriminal.gangshooting',
#  'http://localhost:3000/api/apps/com.tutotoons.app.pandalubabybearcare2.free',
#  'http://localhost:3000/api/apps/com.wordsmobile.RealBikeRacing',
#  'http://localhost:3000/api/apps/onxmaps.hunt',
#  'http://localhost:3000/api/apps/app.over.editor',
#  'http://localhost:3000/api/apps/pcm.art.heart.camera',
#  'http://localhost:3000/api/apps/com.gel.counter.terrorist.attack',
#  'http://localhost:3000/api/apps/org.familysearch.mobile',
#  'http://localhost:3000/api/apps/com.bitmango.go.blocktrianglepuzzletangram',
#  'http://localhost:3000/api/apps/com.pjmasks.timetobeahero',
#  'http://localhost:3000/api/apps/com.Spanish.Ringtones',
#  'http://localhost:3000/api/apps/com.grand.casino.robbery.game',
#  'http://localhost:3000/api/apps/com.bbumgames.spadesroyale',
#  'http://localhost:3000/api/apps/com.wsl.noom',
#  'http://localhost:3000/api/apps/com.themelab.launcher.cuteunicorn',
#  'http://localhost:3000/api/apps/com.educ8s.triviaquiz2015',
#  'http://localhost:3000/api/apps/com.gismart.realdrum2free',
#  'http://localhost:3000/api/apps/com.playdemic.golf.android',
#  ...}

# %%
from bs4 import BeautifulSoup

def get_similar_ids(app_id):
    print(app_id)
    sleep(0.1)
    page = requests.get("https://play.google.com/store/apps/details?id={}".format(app_id))
    soup = BeautifulSoup(page.content, 'html.parser')
    href = soup.find(class_='LkLjZd ScJHi U8Ww7d xjAeve nMZKrb id-track-click ')
    if href != None:
        href = href["href"]
        sleep(0.2)
        page = requests.get(href)
        soup = BeautifulSoup(page.content, 'html.parser')
        similars = []
        for link in soup.find_all(class_="JC71ub"):
            similars.append(link['href'].split("=")[1])
        return similars
    else:
        return []

# %%
def get_app_ids(top_free_apps):
    waiting_urls = list(top_free_apps)
    random.shuffle(waiting_urls)
    waiting_urls_unique_check = set([url for url in waiting_urls])
    app_ids = set()

    
    counter = 0
    start_time = time.time()
    while (len(app_ids) + len(waiting_urls)) < 100000:
        if counter % 10 == 0:
            elapsed_time = time.time() - start_time
            print("Total number of apps", len(app_ids) + len(waiting_urls))
            print("Collected app ids", len(app_ids))
            print("Elapsed time up to now is {}".format(elapsed_time))
        try:
            url = waiting_urls.pop()
            waiting_urls_unique_check.remove(url)
        except Exception:
            print("All linked applications are traversed")
            break

        #add apk id if it is free, popular, and has longer description than 500 characters
        response = requests.get(url)
        if response.status_code == 200:
            json = response.json()
            if json["minInstalls"] > 10000 and json["priceText"] == "Free" and len(json["description"]) > 500:
                if url.split('/')[-1] not in app_ids:
                    response = requests.get(url+"/permissions")
                    if response.status_code == 200:
                        json = response.json()
                        exist = False
                        for line in json["results"]:
                            if "record audio" in line["permission"]:
                                app_ids.add(url.split('/')[-1] )
                                application_id = url.split('/')[-1]
                                cat = get_app_category(application_id)
                                with open("RECORD_AUDIO/record_audio_{}.txt".format(cat), "a") as target:
                                    if application_id not in dowloaded_list:
                                        target.write(application_id + "\n")
                                

        #add similar app urls
        """
        response = requests.get(url + '/similar')
        similar_count = 0
        if response.status_code == 200:
            for app in response.json()["results"]:
                similar_count += 1
                if app["appId"] not in app_ids:
                    
                    if app["url"] not in waiting_urls_unique_check:
                        
                        waiting_urls_unique_check.add(app["url"])
                        waiting_urls.append(app["url"])
        else:
            print("ERROR")
        print("Similar count for {} is {}".format(url, similar_count))
        """
        for sim_id in get_similar_ids(url.split("/")[-1]):
            sim_id = "http://localhost:3000/api/apps/" + sim_id
            if sim_id not in waiting_urls_unique_check:
                waiting_urls_unique_check.add(sim_id)
                waiting_urls.append(sim_id)
        random.shuffle(waiting_urls)
        counter += 1

    for url in waiting_urls:
        response = requests.get(url)
        if response.status_code == 200:
            json = response.json()
            if json["minInstalls"] > 10000 and json["priceText"] == "Free" and len(json["description"]) > 500:
                if url.split('/')[-1] not in app_ids:
                    app_ids.add(url.split('/')[-1] )
                    cat = get_app_category(application_id)
                    with open("RECORD_AUDIO/record_audio_{}.txt".format(cat), "a") as target:
                        if application_id not in dowloaded_list:
                            target.write(application_id + "\n")

# %%
get_app_ids(top_free_apps)
# Out:
# Total number of apps 1320
# Collected app ids 0
# Elapsed time up to now is 2.384185791015625e-06
# com.mobilityware.CastleSolitaire
# com.brokenreality.planemerger.android
# com.hypermania.crush.soft.things
# net.braincake.pixl.pixl
# com.foxsports.android
# com.punchh.mod
# com.pnixgames.bowlingking
# com.dalcomsoft.ssb
# com.robtopx.geometrydashworld
# com.cyberlink.youperfect
# Total number of apps 1670
# Collected app ids 1
# Elapsed time up to now is 132.99754118919373
# com.us.police.cargo.transporter
# com.perfectcorp.amb
# com.yodo1.crossyroad
# com.aofl.adventureacademy
# com.miniclip.hockeystars
# com.vividgames.realboxing
# com.layout.style.picscollage
# com.olo.papamurphys
# com.gvapps.psychologyfacts
# com.ancestry.android.apps.ancestry
# Total number of apps 1946
# Collected app ids 3
# Elapsed time up to now is 249.38001155853271
# com.ea.games.r3_na
# com.fgol.HungrySharkEvolution
# com.sandbox.numbercoloring.pixelart
# com.bts.sticker
# com.halfbrick.jetpackjoyride
# com.lamadeleine.lamadeleine.android.app
# com.dolphingames.police.cargo.airplane
# com.puzzles.game.fd.two
# com.tutotoons.app.babytigercare.free
# freedom.bubble
# Total number of apps 2201
# Collected app ids 3
# Elapsed time up to now is 388.2559049129486
# com.futureplay.city
# com.etermax.trivia.preguntados2
# loseweight.weightloss.workout.fitness
# com.factory608.MI
# com.mobilemirror.app2018.mirror
# net.kairosoft.android.townshopsp
# com.pgz.city.taxi.driving.simulator
# com.klab.utapri.shininglive.global
# com.mapco.mymapco
# com.gen.betterwalking
# Total number of apps 2527
# Collected app ids 3
# Elapsed time up to now is 518.1215062141418
# com.abdelmonem.TattoPhoto
# com.alp.trainsimulatorgames
# com.photo.collage.maker.selfie.editor
# com.ingyomate.shakeit
# com.rishabhk.vocabbuilder
# com.magic.music.tiles.piano.dream
# com.mastercomlimited.cardriving_t
# heroes.bubble.galaxy
# bestringtones2019.topringtones2020.android
# com.nexttechgamesstudio.voxefy.color.by.number.sandbox.number.coloring.book
# Total number of apps 2798
# Collected app ids 4
# Elapsed time up to now is 657.7219061851501
# shooter.bubble.nano
# com.applegends.ringtones.free_songs
# photoeditor.beauty.selfiecamera.effect
# bubbles.blaze
# vsin.t16_funny_photo
# com.miniclip.soccerstars
# com.aetna.aetnahealth
# com.tocaboca.tocalifeworld
# periodtracker.pregnancy.ovulationtracker
# com.playgendary.sportmasters
# Total number of apps 3015
# Collected app ids 5
# Elapsed time up to now is 787.3616054058075
# com.hasbro.mlpcoreAPPSTORE
# com.lego.creator.creatorislands
# com.google.android.stardroid
# se.feomedia.quizkampen.de.lite
# com.pixelberrystudios.choices
# com.taplane.emojisquiz
# com.sinyee.babybus.repair
# com.SouthernPacificOceanFisher.VoiceToText_memo
# com.gpp.skistation
# com.entertainment.free.ringtone
# Total number of apps 3284
# Collected app ids 6
# Elapsed time up to now is 913.3213393688202
# nba.live
# com.Latest.Fashion.Trends
# com.themelab.launcher.cuteunicorn
# com.camera.x
# com.punchh.primanti
# com.dalcomsoft.ssb
# com.genesisblue01.verfutbolonlineguia
# com.futureplay.minecraft
# com.firsttouchgames.smp
# com.walmart.sparkCity
# Total number of apps 3509
# Collected app ids 8
# Elapsed time up to now is 1052.5084302425385
# com.findingrover.findingrover
# com.btows.photo
# com.paybyphone
# com.symcoding.widget.stickynotes
# mixerappco.heart.crown
# com.audiobooks.androidapp
# exercises.flexibility.training.workout.beginners.challenge.flexibilitat.flexibilite.flexibilidad.flessibilita.flexibilidade
# com.basketball.nba.scores.news.schedules
# com.PICCHAT.WeddingFlowerCrownPhoto
# com.grootersproductions.challenge
# Total number of apps 3790
# Collected app ids 8
# Elapsed time up to now is 1190.7400901317596
# com.danpanichev.kmk
# com.vive.riderleague
# com.hyperfame.train.simulator2019_free
# com.sunborn.girlsfrontline.en
# com.sentry.parental
# com.goodrx.krogerrxsc
# com.funnyring.ringtone_free.for_android
# ultimate.bubble.shooterr
# com.nopowerup.mergebattle
# com.appcard.appcard
# Total number of apps 3994
# Collected app ids 8
# Elapsed time up to now is 1311.3632707595825
# com.neighbfav.neighborfavor
# com.tocaboca.blocks
# com.new0.Ringtonesmate20
# com.connection.wireless.wirelessconnectortv
# com.appsclub.route.offline.navigation.localstreet.finder.satellite.free
# com.wachanga.womancalendar
# com.fortitude.shamsulkarim.ieltsfordory
# com.involta.womencalendar
# com.adobe.creativeapps.sketch
# com.ikeyboard.theme.cute.unicorn.girl.wreath
# Total number of apps 4271
# Collected app ids 8
# Elapsed time up to now is 1435.166913986206
# com.keyboard.theme.pinkqueen
# com.billiards.city.pool.nation.club
# com.ikeyboard.theme.spacedust
# com.yodo1.crossyroad
# com.wordsmobile.RealBikeRacing
# com.punchh.schlotzskys
# com.neowizgames.game.browndust.srpg.global
# com.roblox.client
# com.szckhd.jwgly.azyw
# com.nexon.axe.global
# Total number of apps 4456
# Collected app ids 11
# Elapsed time up to now is 1561.1477315425873
# com.wroclawstudio.puzzlealarmclock
# com.idt.impossible.offroad.jeep.stunt.drive
# com.brakefield.painter
# com.DreamonStudios.BouncyBasketball
# in.qtime.spokenenglishguru
# com.pinssible.fancykey.theme.butterfly
# com.dnddream.headboxing
# com.pennypop.dance
# com.jb.gosms.theme.getjar.fdbutterfly
# com.sourceapp.bru
# Total number of apps 4698
# Collected app ids 12
# Elapsed time up to now is 1689.7353048324585
# com.Strongest.ringtone3
# com.famousringtones2017.populartones.bestringtones
# com.crazylabs.hotel.transylvania.adventure
# com.sinyee.babybus.policemen
# com.milliongamesnew.sharksimulator2019
# fitness.loseweight.absworkout.women
# com.teladoc.members
# com.height.increase.workout.plan.tips.exercise
# com.galaxystudio.bts
# com.periodapp.period
# Total number of apps 4853
# Collected app ids 14
# Elapsed time up to now is 1825.8533308506012
# com.etermax.preguntados.lite
# bubble.universe
# org.lds.ldssa
# com.instagram.android
# com.creative.colorfit.mandala.coloring.book
# ak.alizandro.smartaudiobookplayer
# com.sinyee.babybus.expedition
# com.purefliptix
# com.storytoys.miffy.free.android.googleplay
# net.isitlove.cartercorp.colin
# Total number of apps 5019
# Collected app ids 16
# Elapsed time up to now is 1944.7499814033508
# com.bilkon.easypiano
# com.mc.crazystunt.impossiabletracks.cardriving.supercarracing2019.adventure.game.free3d
# com.asobimo.avabel_gp_b3
# com.gametaiwan.jiangdan
# pl.swiatquizu.disneyquiz.android
# com.pcvirt.ImageEditor
# com.safeway.client.android.albertsons
# com.sinyee.babybus.ant
# com.puzzles.game.halloweeen.one
# air.com.hypah.io.slither
# Total number of apps 5135
# Collected app ids 17
# Elapsed time up to now is 2075.3388242721558
# com.raybiztech.notesnow
# com.owngames.owncoffeeshop
# org.nanobit.perioddiary
# com.riversoft.android.mysword
# org.de_studio.diary
# com.etermax.wordcrack.lite
# com.ikeyboard.theme.blue.glass.water
# net.zedge.android
# com.kyz.games.hepyek
# com.miniclip.railrush
# Total number of apps 5397
# Collected app ids 18
# Elapsed time up to now is 2195.708381175995
# app.librivox.android
# com.threed.battleground.fire.survival.strike.shooting.game
# com.fingersoft.hillclimb
# com.mtvn.sbmigoogleplay
# br.com.tapps.vloggergoviral
# com.healthiestyou.app
# com.cedarfair.kingsisland
# ru.mobiledimension.kbr
# com.krsingentertainment.bts_songs_playlist_lyrics_offline_free
# com.jimmyjohns
# Total number of apps 5565
# Collected app ids 18
# Elapsed time up to now is 2296.4908447265625
# com.learnenglishinhindi.daily
# com.DynamicGames.HeavyTruckSimulator
# com.eyougame.smzg.en
# com.hdmimhlll.miirrortotv
# com.sentryapplications.alarmclock
# com.arcane.incognito
# com.ikeyboard.theme.blue.butterfly
# com.bebonozm.dreamie_planner
# com.sinyee.babybus.babyhospital
# com.tocaboca.tocalifefarm
# Total number of apps 5745
# Collected app ids 19
# Elapsed time up to now is 2409.7914979457855
# com.tudasoft.android.FacyCam
# com.ikeyboard.theme.sunset.sea.dolphin
# com.sinyee.babybus.adventure
# com.bossfye.bb
# com.disney.wdw.android
# com.webshinobis.changeyourthinking
# com.frenzycoders.microphoneblockerantispyware
# com.hutchgames.hilldash2
# com.crazy.police.car.driving
# gov.nasa.globe.observer
# Total number of apps 5908
# Collected app ids 20
# Elapsed time up to now is 2516.4045882225037
# com.szyk.myheart
# com.thanx.app
# com.kings.retailapp
# com.ikeyboard.theme.neon.wolf.galaxy
# com.playhardlab.factory
# com.curiosity.dailycuriosity
# com.damiapp.softdatacable
# com.mtvn.tmntrooftoprun
# com.patrickfranklin.touchbible
# com.touchfoo.swordigo
# Total number of apps 6108
# Collected app ids 21
# Elapsed time up to now is 2613.4980795383453
# com.idea.share
# com.jedigames.p20.googleplay
# com.baviux.pillreminder
# com.glu.deerhunt2
# in.mewho.meWhoLite
# com.disney.disneystore_goo
# com.royaltechapps.hiddencameradetector
# com.memd.memd
# com.withbuddies.diceellen
# com.Fashion.Nails.Girls.Game
# Total number of apps 6355
# Collected app ids 21
# Elapsed time up to now is 2752.638261079788
# com.kinpoint.takeaname
# com.tokarev.mafia
# com.jardogs.fmhmobile
# com.revolverolver.fliptrickster
# com.highscorehero.takedown
# com.iart.chromecastapps
# jp.naver.line.android
# com.teachco.TGCviewer
# com.krsingentertainment.blackpink_songs_playlist_lyrics_offline_free
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# OSError: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x7f11c2401470>: Failed to establish a new connection: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='play.google.com', port=443): Max retries exceeded with url: /store/apps/collection/cluster?clp=ogpSCBEqAggIMkoKRGNvbS5rcnNpbmdlbnRlcnRhaW5tZW50LmJsYWNrcGlua19zb25nc19wbGF5bGlzdF9seXJpY3Nfb2ZmbGluZV9mcmVlEAEYAw%3D%3D:S:ANO1ljKUofc&gsr=ClWiClIIESoCCAgySgpEY29tLmtyc2luZ2VudGVydGFpbm1lbnQuYmxhY2twaW5rX3NvbmdzX3BsYXlsaXN0X2x5cmljc19vZmZsaW5lX2ZyZWUQARgD:S:ANO1ljIHBnQ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f11c2401470>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-17-c301ab768dc9> in <module>
# ----> 1 get_app_ids(top_free_apps)
#
# <ipython-input-16-1d10a76722c6> in get_app_ids(top_free_apps)
#      58         print("Similar count for {} is {}".format(url, similar_count))
#      59         """
# ---> 60         for sim_id in get_similar_ids(url.split("/")[-1]):
#      61             sim_id = "http://localhost:3000/api/apps/" + sim_id
#      62             if sim_id not in waiting_urls_unique_check:
#
# <ipython-input-15-c3d8ea46048c> in get_similar_ids(app_id)
#      10         href = href["href"]
#      11         sleep(0.2)
# ---> 12         page = requests.get(href)
#      13         soup = BeautifulSoup(page.content, 'html.parser')
#      14         similars = []
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='play.google.com', port=443): Max retries exceeded with url: /store/apps/collection/cluster?clp=ogpSCBEqAggIMkoKRGNvbS5rcnNpbmdlbnRlcnRhaW5tZW50LmJsYWNrcGlua19zb25nc19wbGF5bGlzdF9seXJpY3Nfb2ZmbGluZV9mcmVlEAEYAw%3D%3D:S:ANO1ljKUofc&gsr=ClWiClIIESoCCAgySgpEY29tLmtyc2luZ2VudGVydGFpbm1lbnQuYmxhY2twaW5rX3NvbmdzX3BsYXlsaXN0X2x5cmljc19vZmZsaW5lX2ZyZWUQARgD:S:ANO1ljIHBnQ (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7f11c2401470>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
